# %%
import os

# %%
import numpy

# %%
import sys

# %%
import csv

# %%
import pandas as pd

# %%
csvfile = pd.DataFrame()

# %%
files = os.listdir('.')
#print('files',files)
for filename in files:
    portion = os.path.splitext(filename)
    if portion[1] == ".dat":  

        newname = portion[0] + ".txt"   
        os.rename(filename,newname)

# %%
ls
# Out:
# DAFIFT_0610_ed6.zip*              distil_dafif.awk*
# Delete useless information.ipynb  distil_gad.awk*
# airlines.txt*                     import data.ipynb
# airports-dafif.txt*               map-2048.png*
# airports.txt*                     map-routes.php*
# arm/                              merge-airports.sh*
# backup.ftp*                       routes.txt*
# countries.txt*                    timezones.php*

# %%
a = open('routes.txt','r')

# %%
a.close()
a
# Out:
# <_io.TextIOWrapper name='routes.txt' mode='r' encoding='UTF-8'>

# %%
with open('routes.txt', 'r') as a:
    while True:
        line = a.readline()     
        if not line:
            break
        print(line)
# Out:
# 0D,1983,FCO,1555,LUG,1675,,0,S20
#
# 0D,1983,FCO,1555,RMI,1546,,0,S20
#
# 0D,1983,FOG,1502,MXP,1524,,0,S20
#
# 0D,1983,FOG,1502,PMO,1512,,0,S20
#
# 0D,1983,FOG,1502,TRN,1526,,0,S20
#
# 0D,1983,GVA,1665,LUG,1675,,0,S20
#
# 0D,1983,LUG,1675,FCO,1555,,0,S20
#
# 0D,1983,LUG,1675,GVA,1665,,0,S20
#
# 0D,1983,MXP,1524,FOG,1502,,0,S20
#
# 0D,1983,PMO,1512,FOG,1502,,0,S20
#
# 0D,1983,RMI,1546,FCO,1555,,0,S20
#
# 0D,1983,TRN,1526,FOG,1502,,0,S20
#
# 2E,\N,HOM,3664,SOV,\N,,0,CNC
#
# 2E,\N,PGM,\N,SOV,\N,,0,CNC
#
# 2E,\N,SOV,\N,HOM,3664,,0,CNC
#
# 2E,\N,SOV,\N,PGM,\N,,0,CNC
#
# 2I,8359,ANS,2787,LIM,2789,,0,141
#
# 2I,8359,AQP,2802,CUZ,2812,,0,141
#
# 2I,8359,AQP,2802,JUL,2792,,0,142
#
# 2I,8359,AQP,2802,LIM,2789,,0,142
#
# 2I,8359,AYP,2786,LIM,2789,,0,141 142
#
# 2I,8359,CIX,2785,LIM,2789,,0,142
#
# 2I,8359,CIX,2785,TRU,2804,,0,142
#
# 2I,8359,CUZ,2812,AQP,2802,,0,141
#
# 2I,8359,CUZ,2812,JUL,2792,,0,141
#
# 2I,8359,CUZ,2812,LIM,2789,,0,141 142
#
# 2I,8359,CUZ,2812,PEM,2808,,0,142
#
# ...

# %%
line=a.readline()

# %%
line

# %%
# Out:
# ''
