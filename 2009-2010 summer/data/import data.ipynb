# %%
import os

# %%
import numpy

# %%
import sys

# %%
import csv

# %%
import pandas as pd

# %%
csvfile = pd.DataFrame()

# %%
files = os.listdir('.')
#print('files',files)
for filename in files:
    portion = os.path.splitext(filename)
    if portion[1] == ".txt":  

        newname = portion[0] + ".csv"   
        os.rename(filename,newname)

# %%
ls

# %%
a = open('routes.txt','r')

# %%
a.close()
a
# Out:
# <_io.TextIOWrapper name='routes.txt' mode='r' encoding='UTF-8'>

# %%
with open('routes.txt', 'r') as a:
    while True:
        line = a.readline()     
        if not line:
            break
        print(line)
# Out:
# 0B	AGP	BBU		0	733
#
# 0B	ARW	BBU		0	733
#
# 0B	ARW	REU		0	733
#
# 0B	ARW	VLC		0	733
#
# 0B	ARW	VRN		0	733
#
# 0B	BBU	AGP		0	733
#
# 0B	BBU	ARW		0	733
#
# 0B	BBU	BCN		0	733
#
# 0B	BBU	BGY		0	733
#
# 0B	BBU	BLQ		0	733
#
# 0B	BBU	BRU		0	733
#
# 0B	BBU	BVA		0	733
#
# 0B	BBU	CGN		0	733
#
# 0B	BBU	CTA		0	733
#
# 0B	BBU	CUF		0	733
#
# 0B	BBU	FCO		0	733
#
# 0B	BBU	LCA		0	733
#
# 0B	BBU	LIS		0	733
#
# 0B	BBU	LYS		0	733
#
# 0B	BBU	MAD		0	733
#
# 0B	BBU	NAP		0	733
#
# 0B	BBU	SBZ		0	733
#
# 0B	BBU	SKG		0	733
#
# 0B	BBU	STN		0	733
#
# 0B	BBU	TXL		0	733
#
# 0B	BBU	VLC		0	733
#
# 0B	BBU	VRN		0	733
#
# 0B	BCM	BGY		0	733
#
# 0B	BCM	BLQ		0	733
#
# 0B	BCM	CUF		0	733
#
# 0B	BCM	FCO		0	733
#
# 0B	BCM	LTN		0	733
#
# 0B	BCM	SBZ		0	733
#
# 0B	BCM	VLC		0	733
#
# 0B	BCN	BBU		0	733
#
# 0B	BGY	BBU		0	733
#
# 0B	BGY	BCM		0	733
#
# 0B	BLQ	BBU		0	733
#
# 0B	BLQ	BCM		0	733
#
# 0B	BRU	BBU		0	733
#
# 0B	BRU	CND		0	733
#
# 0B	BVA	BBU		0	733
#
# 0B	CGN	BBU		0	733
#
# 0B	CGN	SBZ		0	733
#
# 0B	CND	BRU		0	733
#
# 0B	CTA	BBU		0	733
#
# 0B	CUF	BBU		0	733
#
# 0B	CUF	BCM		0	733
#
# 0B	FCO	BBU		0	733
#
# 0B	FCO	BCM		0	733
#
# 0B	FCO	SBZ		0	733
#
# 0B	LCA	BBU		0	733
#
# 0B	LIS	BBU		0	733
#
# 0B	LTN	BCM		0	733
#
# 0B	LYS	BBU		0	733
#
# 0B	MAD	BBU		0	733
#
# 0B	MAD	SBZ		0	733
#
# 0B	NAP	BBU		0	733
#
# 0B	PFO	SKG		0	733
#
# 0B	REU	ARW		0	733
#
# 0B	SBZ	BBU		0	733
#
# 0B	SBZ	CGN		0	733
#
# 0B	SBZ	FCO		0	733
#
# 0B	SBZ	MAD		0	733
#
# 0B	SBZ	STR		0	733
#
# 0B	SKG	BBU		0	733
#
# 0B	SKG	PFO		0	733
#
# 0B	STN	BBU		0	733
#
# 0B	STR	SBZ		0	733
#
# 0B	TXL	BBU		0	733
#
# 0B	VLC	ARW		0	733
#
# 0B	VLC	BBU		0	733
#
# 0B	VLC	BCM		0	733
#
# 0B	VRN	ARW		0	733
#
# 0B	VRN	BBU		0	733
#
# 0D	BRN	PMI		0	S20
#
# 0D	CAG	LUG		0	S20
#
# 0D	FCO	LUG		0	S20
#
# 0D	GVA	LUG		0	S20
#
# 0D	LUG	CAG		0	S20
#
# 0D	LUG	FCO		0	S20
#
# 0D	LUG	GVA		0	S20
#
# 0D	LUG	OLB		0	S20
#
# 0D	OLB	LUG		0	S20
#
# 0D	PMI	BRN		0	S20
#
# 2B	ALP	BAH		0	320
#
# 2B	ALY	BAH		0	320
#
# 2B	AMM	BAH		0	320
#
# 2B	AUH	BAH		0	320
#
# 2B	BAH	ALP		0	320
#
# 2B	BAH	ALY		0	320
#
# 2B	BAH	AMM		0	320
#
# 2B	BAH	AUH		0	320
#
# 2B	BAH	BEY		0	320
#
# 2B	BAH	CCJ		0	320
#
# 2B	BAH	COK		0	320
#
# 2B	BAH	DAM		0	320
#
# 2B	BAH	DOH		0	320
#
# 2B	BAH	DXB		0	320
#
# 2B	BAH	JED		0	320
#
# 2B	BAH	KRT		0	320
#
# 2B	BAH	KTM		0	320
#
# 2B	BAH	KWI		0	320
#
# 2B	BEY	BAH		0	320
#
# 2B	BEY	KWI		0	320
#
# 2B	CCJ	BAH		0	320
#
# 2B	COK	BAH		0	320
#
# 2B	DAM	BAH		0	320
#
# 2B	DOH	BAH		0	320
#
# 2B	DXB	BAH		0	320
#
# 2B	DXB	KRT		0	320
#
# 2B	JED	BAH		0	320
#
# 2B	KRT	DXB		0	320
#
# 2B	KTM	BAH		0	320
#
# 2B	KWI	BAH		0	320
#
# 2B	KWI	BEY		0	320
#
# 2B	LXR	BAH		0	320
#
# 2E	HOM	SOV		0	CN1
#
# 2E	PGM	SOV		0	CN1
#
# 2E	SOV	HOM		0	CN1
#
# 2E	SOV	PGM		0	CN1
#
# 2F	ABL	OTZ		0	CNT
#
# 2F	ABL	SHG		0	CNT CNC
#
# 2F	AET	FAI		0	BE1
#
# 2F	AIN	ATK		0	CNC
#
# 2F	AIN	BRW		0	CNC
#
# 2F	AKI	TLT		0	CNA
#
# 2F	AKP	AET		0	BE1
#
# 2F	ANC	ANI		0	BE1
#
# 2F	ANC	DLG		0	BE1
#
# 2F	ANC	FAI		0	BE1
#
# 2F	ANC	KSM		0	BE1
#
# 2F	ANC	UNK		0	BE1
#
# 2F	ANI	ANC		0	BE1
#
# 2F	ANI	CHU		0	CN1
#
# 2F	ANI	HCR		0	CNC
#
# 2F	ANI	KLG		0	CN1 CNC
#
# 2F	ANI	KSM		0	BE1
#
# 2F	ANI	SHX		0	CNC
#
# 2F	ANV	HCR		0	CNC
#
# 2F	ANV	KGX		0	CNC
#
# 2F	ATK	BRW		0	CNC
#
# 2F	ATT	BET		0	CN1 CNA
#
# 2F	BET	EEK		0	CNC CNA
#
# 2F	BET	KLG		0	CNC
#
# 2F	BET	KUK		0	CN1 CNA
#
# 2F	BET	KWK		0	CNC
#
# 2F	BET	KWT		0	CNA
#
# 2F	BET	MLL		0	CNC
#
# 2F	BET	NME		0	CNC
#
# 2F	BET	OOK		0	CNT CNC
#
# 2F	BET	PQS		0	CNC
#
# 2F	BET	VAK		0	CNT CNC
#
# 2F	BET	WTL		0	CNC
#
# 2F	BKC	DRG		0	CNC
#
# 2F	BKC	OTZ		0	CNC
#
# 2F	BRW	AIN		0	CNC
#
# 2F	BRW	ATK		0	CNC
#
# 2F	BRW	FAI		0	BE1
#
# 2F	BRW	NUI		0	CNC BE1
#
# 2F	BRW	PIZ		0	CNC
#
# 2F	BTI	FAI		0	BE1
#
# 2F	BTI	SCC		0	BE1
#
# 2F	CHU	CKD		0	CN1
#
# 2F	CKD	RDV		0	CN1
#
# 2F	DLG	ANC		0	BE1
#
# 2F	DRG	BKC		0	CNC
#
# 2F	DRG	OTZ		0	CNC
#
# 2F	EEK	KWN		0	CNC CNA
#
# 2F	ELI	KKA		0	PAG
#
# 2F	ELI	OME		0	PAG
#
# 2F	EMK	ANC		0	BE1
#
# 2F	EMK	KSM		0	BE1
#
# 2F	FAI	AKP		0	BE1
#
# 2F	FAI	ANC		0	BE1
#
# 2F	FAI	BTI		0	BE1
#
# 2F	FAI	FYU		0	PAG BE1
#
# 2F	FAI	GAL		0	BE1
#
# 2F	FAI	OTZ		0	BE1
#
# 2F	FAI	RBY		0	PAG
#
# 2F	FYU	FAI		0	PAG BE1
#
# 2F	GAL	FAI		0	PAG BE1
#
# 2F	GAL	HSL		0	PAG
#
# 2F	GAL	KAL		0	PAG
#
# 2F	GAL	KYU		0	PAG
#
# 2F	GAL	NUL		0	BE1
#
# 2F	GAL	OME		0	BE1
#
# 2F	GAL	RBY		0	PAG
#
# 2F	GAM	OME		0	CNT
#
# 2F	GAM	SVA		0	CNT
#
# 2F	GLV	ELI		0	PAG
#
# 2F	GLV	OME		0	PAG
#
# 2F	GLV	WMO		0	PAG
#
# 2F	HCR	ANI		0	CNC
#
# 2F	HCR	ANV		0	CNC
#
# 2F	HPB	SCM		0	CNT CNC
#
# 2F	HSL	GAL		0	PAG
#
# 2F	IAN	ORV		0	CNC
#
# 2F	IAN	OTZ		0	CNC
#
# 2F	KAL	GAL		0	BE1
#
# 2F	KAL	NUL		0	PAG
#
# 2F	KGX	ANV		0	CNC
#
# 2F	KGX	SHX		0	CNC
#
# 2F	KKA	ELI		0	PAG
#
# 2F	KKA	OME		0	PAG
#
# 2F	KKA	SKK		0	PAG
#
# 2F	KKA	UNK		0	CN1 CNC
#
# 2F	KKH	KWK		0	CNC
#
# 2F	KKH	WTL		0	CNC
#
# 2F	KKI	AKI		0	CNA
#
# 2F	KLG	ANI		0	CNC
#
# 2F	KLG	BET		0	CNC
#
# 2F	KLG	RSH		0	CN1
#
# 2F	KPN	BET		0	CNC
#
# 2F	KPN	BET		1	CNC
#
# 2F	KSM	ANC		0	BE1
#
# 2F	KSM	EMK		0	BE1
#
# 2F	KSM	MOU		0	CNC CN1
#
# 2F	KSM	PQS		0	CN1
#
# 2F	KTS	TLA		0	PAG
#
# 2F	KTS	WAA		0	PAG
#
# 2F	KUK	NUP		0	CN1 CNA
#
# 2F	KVL	OTZ		0	PAG
#
# 2F	KVL	PHO		0	PAG
#
# 2F	KWK	BET		0	CNC
#
# 2F	KWK	KKH		0	CNC
#
# 2F	KWK	KPN		0	CNC
#
# 2F	KWN	BET		0	CNC CNA
#
# 2F	KWT	KKI		0	CNA
#
# 2F	KYU	GAL		0	PAG
#
# 2F	MLL	RSH		0	CNC
#
# 2F	MOU	KSM		0	CNC CN1
#
# 2F	MOU	PQS		0	CNC
#
# 2F	MYU	BET		0	CNT CNC
#
# 2F	NME	OOK		0	CNC
#
# 2F	NME	TNK		0	CNC
#
# 2F	NUI	BRW		0	CNC BE1
#
# 2F	NUI	SCC		0	CNC BE1
#
# 2F	NUL	KAL		0	BE1
#
# 2F	NUL	KYU		0	PAG
#
# 2F	NUP	ATT		0	CN1 CNA
#
# 2F	OBU	ABL		0	CNT
#
# 2F	OBU	OTZ		0	CNT CNC
#
# 2F	OME	ELI		0	PAG
#
# 2F	OME	FAI		0	BE1
#
# 2F	OME	GAL		0	PAG
#
# 2F	OME	GAM		0	CNT
#
# 2F	OME	GLV		0	PAG
#
# 2F	OME	KTS		0	PAG
#
# 2F	OME	OTZ		0	PAG
#
# 2F	OME	SHH		0	PAG CNT
#
# 2F	OME	SKK		0	PAG
#
# 2F	OME	SVA		0	CNT
#
# 2F	OME	TLA		0	PAG
#
# 2F	OME	UNK		0	PAG
#
# 2F	OME	WAA		0	PAG
#
# 2F	OME	WBB		0	PAG
#
# 2F	OME	WMO		0	PAG
#
# 2F	OOK	MYU		0	CNT CNC
#
# 2F	OOK	TNK		0	CNC
#
# 2F	ORV	IAN		0	CNC
#
# 2F	ORV	OTZ		0	CNC
#
# 2F	ORV	WLK		0	CNC
#
# 2F	OTZ	ABL		0	CNT CNC
#
# 2F	OTZ	BKC		0	CNC
#
# 2F	OTZ	DRG		0	CNC
#
# 2F	OTZ	FAI		0	BE1
#
# 2F	OTZ	IAN		0	CNC
#
# 2F	OTZ	KVL		0	PAG
#
# 2F	OTZ	OME		0	PAG
#
# 2F	OTZ	ORV		0	CNC
#
# 2F	OTZ	PHO		0	CNC PAG BE1
#
# 2F	OTZ	SHG		0	CNT
#
# 2F	OTZ	WLK		0	CNC
#
# 2F	OTZ	WTK		0	PAG
#
# 2F	PHO	KVL		0	PAG
#
# 2F	PHO	OTZ		0	CNC PAG BE1
#
# 2F	PHO	PIZ		0	CNC
#
# 2F	PIZ	BRW		0	CNC
#
# 2F	PIZ	PHO		0	CNC
#
# 2F	PQS	BET		0	CNC
#
# 2F	PQS	KSM		0	CN1
#
# 2F	PQS	MOU		0	CNC
#
# 2F	RBY	FAI		0	PAG
#
# 2F	RBY	GAL		0	PAG
#
# 2F	RDV	SLQ		0	CN1
#
# 2F	RSH	ANI		0	CN1
#
# 2F	RSH	BET		0	CNC
#
# 2F	SCC	BTI		0	BE1
#
# 2F	SCC	NUI		0	CNC BE1
#
# 2F	SCM	BET		0	CNT CNC
#
# 2F	SHG	OBU		0	CNT CNC
#
# 2F	SHH	OME		0	PAG
#
# 2F	SHH	WAA		0	CNT
#
# 2F	SHX	ANI		0	CNC
#
# 2F	SHX	KGX		0	CNC
#
# 2F	SKK	KKA		0	PAG CN1 CNC
#
# 2F	SKK	OME		0	PAG
#
# 2F	SLQ	SRV		0	CN1
#
# 2F	SMK	UNK		0	PAG
#
# 2F	SMK	WBB		0	PAG CNA CNC
#
# 2F	SRV	ANI		0	CN1
#
# 2F	SVA	GAM		0	CNT
#
# 2F	SVA	OME		0	CNT
#
# 2F	TLA	KTS		0	PAG
#
# 2F	TLA	OME		0	PAG
#
# 2F	TLT	BET		0	CNA
#
# 2F	TNK	WWT		0	CNC
#
# 2F	UNK	SKK		0	PAG CN1 CNC
#
# 2F	UNK	SMK		0	PAG CNA CNC
#
# 2F	VAK	HPB		0	CNT CNC
#
# 2F	WAA	KTS		0	PAG
#
# 2F	WAA	OME		0	CNT PAG
#
# 2F	WBB	OME		0	PAG
#
# 2F	WBB	SMK		0	PAG
#
# 2F	WBB	UNK		0	CNA CNC
#
# 2F	WLK	OTZ		0	CNC
#
# 2F	WMO	GLV		0	PAG
#
# 2F	WMO	OME		0	PAG
#
# 2F	WTK	OTZ		0	PAG
#
# 2F	WTK	PHO		0	PAG
#
# 2F	WTL	BET		0	CNC
#
# 2F	WTL	KKH		0	CNC
#
# 2F	WWT	BET		0	CNC
#
# 2I	CJA	LIM		0	732
#
# 2I	CUZ	LIM		0	732
#
# 2I	CUZ	PEM		0	732
#
# 2I	IQT	LIM		0	732
#
# 2I	IQT	PCL		0	732
#
# 2I	IQT	TPP		0	732
#
# 2I	LIM	CJA		0	732
#
# 2I	LIM	CUZ		0	732
#
# 2I	LIM	IQT		0	732
#
# 2I	LIM	PCL		0	732
#
# 2I	LIM	TPP		0	732
#
# 2I	PCL	IQT		0	732
#
# 2I	PCL	LIM		0	732
#
# 2I	PEM	CUZ		0	732
#
# 2I	TPP	IQT		0	732
#
# 2I	TPP	LIM		0	732
#
# 2J	ABJ	ACC		0	M87
#
# 2J	ABJ	BKO	*	0	M87 M88
#
# 2J	ABJ	BOY		0	M87
#
# 2J	ABJ	COO	*	0	M87
#
# 2J	ABJ	LFW	*	0	M87
#
# 2J	ABJ	OUA		0	M87
#
# 2J	ABJ	OUA		1	S20 M87
#
# 2J	ABJ	OUA	*	0	F28
#
# 2J	ACC	ABJ		0	M87
#
# 2J	ACC	OUA		0	S20 M87
#
# 2J	BKO	ABJ	*	0	M87
#
# 2J	BKO	CKY	*	0	M87
#
# 2J	BKO	COO	*	0	M87
#
# 2J	BKO	DKR	*	0	M87 M88
#
# 2J	BKO	OUA		0	319
#
# 2J	BKO	OUA	*	0	319
#
# 2J	BOY	ABJ		0	M87
#
# 2J	BOY	OUA		0	S20 M87
#
# 2J	BZV	DLA	*	0	M87
#
# 2J	CKY	BKO	*	0	M87
#
# 2J	CKY	DKR	*	0	M87
#
# 2J	COO	ABJ	*	0	M87
#
# 2J	COO	ACC		0	M87
#
# 2J	COO	BKO	*	0	M87
#
# 2J	COO	DLA	*	0	M87
#
# 2J	COO	LBV	*	0	M87
#
# 2J	COO	LFW		0	M87
#
# 2J	COO	OUA		0	M87
#
# 2J	COO	OUA		1	M87
#
# 2J	DKR	BKO	*	0	M87
#
# 2J	DKR	CKY	*	0	M87
#
# 2J	DKR	OUA		0	M87 F28
#
# 2J	DLA	BZV	*	0	M87
#
# 2J	DLA	COO	*	0	M87
#
# 2J	LBV	COO	*	0	M87
#
# 2J	LBV	LFW	*	0	M87
#
# 2J	LFW	ABJ	*	0	M87
#
# 2J	LFW	COO		0	M87
#
# 2J	LFW	LBV	*	0	M87
#
# 2J	LFW	OUA		0	M87
#
# 2J	NIM	ABJ		0	M87
#
# 2J	ORY	BKO	*	0	319
#
# 2J	ORY	OUA		0	319
#
# 2J	OUA	ABJ		0	M87
#
# 2J	OUA	ABJ		1	S20
#
# 2J	OUA	ABJ	*	0	319 F28
#
# 2J	OUA	ACC		0	S20 M87
#
# 2J	OUA	BKO		0	319
#
# 2J	OUA	BKO	*	0	319
#
# 2J	OUA	BOY		0	S20 M87
#
# 2J	OUA	COO		0	M87
#
# 2J	OUA	COO		1	M87
#
# 2J	OUA	DKR		0	M87
#
# 2J	OUA	LFW		0	M87
#
# 2J	OUA	NIM		0	S20 M87
#
# 2J	OUA	ORY		0	319
#
# 2K	BOG	UIO		0	732
#
# 2K	CUE	GYE		0	732
#
# 2K	CUE	UIO		0	732
#
# 2K	GPS	GYE		0	722
#
# 2K	GYE	CUE		0	732
#
# 2K	GYE	GPS		0	722
#
# 2K	GYE	MIA		0	752
#
# 2K	GYE	SCY		0	722
#
# 2K	GYE	UIO		0	732 722 752
#
# 2K	MDE	UIO		0	732
#
# 2K	MEC	UIO		0	732
#
# 2K	MIA	GYE		0	752
#
# 2K	SCY	GYE		0	722
#
# 2K	UIO	BOG		0	732
#
# 2K	UIO	CUE		0	732
#
# 2K	UIO	GYE		0	732 722 752
#
# 2K	UIO	MDE		0	732
#
# 2K	UIO	MEC		0	732
#
# 2L	BDS	ZRH		0	100
#
# 2L	OHD	ZRH		0	100
#
# 2L	OLB	ZRH		0	100
#
# 2L	PUY	ZRH		0	100
#
# 2L	RJK	ZRH		0	100
#
# 2L	SKP	ZRH		0	100
#
# 2L	SKP	ZRH	*	0	100
#
# 2L	XRY	ZRH		0	100
#
# 2L	ZRH	BDS		0	100
#
# 2L	ZRH	OHD		0	100
#
# 2L	ZRH	OLB		0	100
#
# 2L	ZRH	PUY		0	100
#
# 2L	ZRH	RJK		0	100
#
# 2L	ZRH	SKP		0	100
#
# 2L	ZRH	SKP	*	0	100
#
# 2L	ZRH	XRY		0	100
#
# 2M	BUD	KIV		0	S20
#
# 2M	KIV	BUD		0	S20
#
# 2M	KIV	TSR	*	0	100
#
# 2M	TSR	KIV	*	0	100
#
# 2N	AJR	LYC		0	ATP
#
# 2N	ARN	GEV		0	ATP
#
# 2N	ARN	HFS		0	BEH
#
# 2N	ARN	KRF		0	SF3
#
# 2N	ARN	LYC		0	ATP
#
# 2N	ARN	MXX		0	BEH
#
# 2N	ARN	VHM		0	ATP
#
# 2N	BMA	OSD		0	SF3
#
# 2N	CPH	LPI		0	SF3
#
# 2N	EVG	MXX		0	BEH
#
# 2N	GEV	ARN		0	ATP
#
# 2N	HFS	ARN		0	BEH
#
# 2N	HFS	TYF		0	BEH
#
# 2N	KRF	ARN		0	SF3
#
# 2N	LLA	UME		0	SF3
#
# 2N	LPI	CPH		0	SF3
#
# 2N	LPI	ORB		0	SF3
#
# 2N	LYC	AJR		0	ATP
#
# 2N	LYC	ARN		0	ATP
#
# 2N	MXX	ARN		0	BEH
#
# 2N	MXX	EVG		0	BEH
#
# 2N	ORB	LPI		0	SF3
#
# 2N	OSD	BMA		0	SF3
#
# 2N	OSD	UME		0	SF3
#
# 2N	TYF	HFS		0	BEH
#
# 2N	UME	LLA		0	SF3
#
# 2N	UME	OSD		0	SF3
#
# 2N	VHM	ARN		0	ATP
#
# 2O	ADQ	KLN		0	BNI
#
# 2O	ADQ	KOZ		0	BNI
#
# 2O	KLN	KYK		0	BNI
#
# 2O	KOZ	ORI		0	BNI
#
# 2P	BCD	CEB	*	0	DH4
#
# 2P	BXU	CEB	*	0	DH3
#
# 2P	CEB	BCD	*	0	DH4
#
# 2P	CEB	BXU	*	0	DH3
#
# 2P	CEB	CGY	*	0	DH4
#
# 2P	CEB	DPL	*	0	DH4
#
# 2P	CEB	DVO		0	737
#
# 2P	CEB	DVO	*	0	DH4
#
# 2P	CEB	GES	*	0	DH4
#
# 2P	CEB	ILO		0	737
#
# 2P	CEB	MPH	*	0	DH3
#
# 2P	CEB	OZC	*	0	DH4
#
# 2P	CEB	PPS	*	0	DH4
#
# 2P	CEB	TAC	*	0	DH4
#
# 2P	CEB	ZAM	*	0	DH4
#
# 2P	CGY	CEB	*	0	DH4
#
# 2P	CGY	MNL		0	737
#
# 2P	CRM	MNL	*	0	DH4
#
# 2P	CYP	MNL	*	0	DH4
#
# 2P	DPL	CEB	*	0	DH4
#
# 2P	DVO	CEB		0	737
#
# 2P	DVO	ZAM	*	0	DH4
#
# 2P	GES	CEB	*	0	DH4
#
# 2P	ILO	CEB		0	737
#
# 2P	ILO	MNL		0	737
#
# 2P	MNL	CGY		0	737
#
# 2P	MNL	CRM	*	0	DH4
#
# 2P	MNL	CYP	*	0	DH4
#
# 2P	MNL	ILO		0	737
#
# 2P	MNL	MPH	*	0	DH3
#
# 2P	MNL	OMC	*	0	DH4
#
# 2P	MNL	OZC		0	737
#
# 2P	MNL	PPS		0	737
#
# 2P	MNL	SJI	*	0	DH4
#
# 2P	MNL	SUG	*	0	DH4
#
# 2P	MNL	TUG	*	0	DH4
#
# 2P	MNL	USU	*	0	DH4
#
# 2P	MNL	VRC	*	0	DH4
#
# 2P	MNL	WNP		0	737
#
# 2P	MPH	CEB	*	0	DH3
#
# 2P	MPH	MNL	*	0	DH3
#
# 2P	OMC	MNL	*	0	DH4
#
# 2P	OZC	CEB	*	0	DH4
#
# 2P	OZC	MNL		0	737
#
# 2P	PPS	CEB	*	0	DH4
#
# 2P	PPS	MNL		0	737
#
# 2P	SJI	MNL	*	0	DH4
#
# 2P	SUG	MNL	*	0	DH4
#
# 2P	TAC	CEB	*	0	DH4
#
# 2P	TUG	MNL	*	0	DH4
#
# 2P	USU	MNL	*	0	DH4
#
# 2P	VRC	MNL	*	0	DH4
#
# 2P	WNP	MNL		0	737
#
# 2P	ZAM	CEB	*	0	DH4
#
# 2P	ZAM	DVO	*	0	DH4
#
# 2Q	AGH	BMA		0	AT7 S20
#
# 2Q	AGH	VBY		0	SF3
#
# 2Q	ARN	MHQ		0	SF3
#
# 2Q	BGO	SKE		0	SF3
#
# 2Q	BMA	AGH		0	AT7 S20
#
# 2Q	BMA	KLR		0	SF3
#
# 2Q	BMA	RNB		0	S20
#
# 2Q	BMA	SDL		0	S20
#
# 2Q	BMA	SKE		0	SF3
#
# 2Q	BMA	VBY		0	AT7 SF3
#
# 2Q	BMA	VXO		0	SF3
#
# 2Q	HEL	MHQ		0	SF3
#
# 2Q	KLR	BMA		0	SF3
#
# 2Q	MHQ	ARN		0	SF3
#
# 2Q	MHQ	HEL		0	SF3
#
# 2Q	NYO	VBY		0	SF3
#
# 2Q	OUL	TMP		0	SF3
#
# 2Q	RNB	BMA		0	S20
#
# 2Q	SDL	BMA		0	S20
#
# 2Q	SKE	BGO		0	SF3
#
# 2Q	SKE	BMA		0	SF3
#
# 2Q	SKE	SVG		0	SF3
#
# 2Q	SVG	SKE		0	SF3
#
# 2Q	TKU	TMP		0	SF3
#
# 2Q	TMP	OUL		0	SF3
#
# 2Q	TMP	TKU		0	SF3
#
# 2Q	TXL	VXO		0	SF3
#
# 2Q	VBY	AGH		0	SF3
#
# 2Q	VBY	BMA		0	AT7 SF3
#
# 2Q	VBY	NYO		0	SF3
#
# 2Q	VXO	BMA		0	SF3
#
# 2Q	VXO	TXL		0	SF3
#
# 2T	AKF	BEN		0	722
#
# 2T	BEN	AKF		0	722
#
# 2T	BEN	TIP		0	722
#
# 2T	SEB	TIP		0	722
#
# 2T	TIP	BEN		0	722
#
# 2T	TIP	SEB		0	722
#
# 2U	TLV	ZAG		0	757
#
# 2U	ZAG	TLV		0	757
#
# 2W	GOT	HAJ		0	D38
#
# 2W	GOT	SVG		0	D38
#
# 2W	GRZ	INN		0	D38
#
# 2W	GRZ	OLB		0	D38
#
# 2W	HAJ	GOT		0	D38
#
# 2W	HAJ	INN		0	D38
#
# 2W	INN	GRZ		0	D38
#
# 2W	INN	HAJ		0	D38
#
# 2W	INN	NCE		0	D38
#
# 2W	NCE	INN		0	D38
#
# 2W	NCE	OLB		0	D38
#
# 2W	OLB	INN		0	D38
#
# 2W	OLB	NCE		0	D38
#
# 2W	SVG	GOT		0	D38
#
# 3B	OSR	VIE		0	SF3
#
# 3B	VIE	OSR		0	SF3
#
# 3F	CGA	HYL		0	DHP
#
# 3F	CGA	KTN		0	DHP
#
# 3F	HYL	CGA		0	DHP
#
# 3F	HYL	KTN		0	DHP
#
# 3F	KTB	KTN		0	DHP
#
# 3F	KTN	CGA		0	DHP
#
# 3F	KTN	HYL		0	DHP
#
# 3F	KTN	KTB		0	DHP
#
# 3F	KTN	MTM		0	DHP
#
# 3F	MTM	KTN		0	DHP
#
# 3H	AKV	YIK		0	DHT
#
# 3H	AKV	YPX		0	DHT
#
# 3H	XGR	YVP		0	BE1 DHT
#
# 3H	YGL	YGW		0	DHT
#
# 3H	YGL	YPX		0	DH8
#
# 3H	YGL	YUL		0	DH8
#
# 3H	YGW	YGL		0	DHT
#
# 3H	YGW	YPH		0	DH8
#
# 3H	YGW	YSK		0	DHT
#
# 3H	YGW	YUD		0	DH8
#
# 3H	YGW	YUL		0	DH8
#
# 3H	YIK	AKV		0	DHT
#
# 3H	YIK	YZG		0	DHT
#
# 3H	YKG	YPJ		0	DHT DH8
#
# 3H	YKG	YQC		0	DH8
#
# 3H	YKG	YVP		0	DHT DH8
#
# 3H	YKL	YQB		0	DH8
#
# 3H	YKL	YVP		0	BE1 DH8
#
# 3H	YKL	YWK		0	BE1
#
# 3H	YKL	YZV		0	BE1
#
# 3H	YPH	YGW		0	DH8
#
# 3H	YPH	YPX		0	BE1 DH8
#
# 3H	YPH	YUD		0	DH8
#
# 3H	YPJ	YKG		0	DHT DH8
#
# 3H	YPJ	YTQ		0	DHT DH8
#
# 3H	YPJ	YVP		0	BE1 DHT
#
# 3H	YPX	AKV		0	DHT
#
# 3H	YPX	YGL		0	DH8
#
# 3H	YPX	YPH		0	DH8
#
# 3H	YPX	YVP		0	BE1
#
# 3H	YPX	YZG		0	DH8
#
# 3H	YQB	YKL		0	DH8
#
# 3H	YQB	YUL		0	DH8
#
# 3H	YQC	YKG		0	DH8
#
# 3H	YQC	YWB		0	DH8
#
# 3H	YSK	YGW		0	DHT
#
# 3H	YTQ	YPJ		0	BE1 DHT DH8
#
# 3H	YTQ	YVP		0	DHT DH8
#
# 3H	YUD	YGW		0	DH8
#
# 3H	YUD	YPH		0	DH8
#
# 3H	YUL	YGL		0	DH8
#
# 3H	YUL	YGW		0	DH8
#
# 3H	YUL	YQB		0	DH8
#
# 3H	YVP	XGR		0	BE1 DHT
#
# 3H	YVP	YKG		0	DH8
#
# 3H	YVP	YKL		0	BE1 DH8
#
# 3H	YVP	YPH		0	BE1
#
# 3H	YVP	YPX		0	BE1
#
# 3H	YVP	YTQ		0	BE1 DHT DH8
#
# 3H	YWB	YQC		0	DH8
#
# 3H	YWB	YZG		0	DH8
#
# 3H	YWK	YKL		0	BE1
#
# 3H	YWK	YZV		0	BE1
#
# 3H	YZG	YIK		0	DHT
#
# 3H	YZG	YPX		0	DH8
#
# 3H	YZG	YWB		0	DH8
#
# 3H	YZV	YKL		0	BE1
#
# 3H	YZV	YWK		0	BE1
#
# 3K	BKI	SIN		0	320
#
# 3K	BKK	SIN		0	320
#
# 3K	HKG	SIN		0	320
#
# 3K	KCH	SIN		0	320
#
# 3K	KUL	SIN		0	320
#
# 3K	MFM	SIN		0	320
#
# 3K	MNL	SIN		0	320
#
# 3K	PNH	SIN		0	320
#
# 3K	REP	PNH		0	320
#
# 3K	RGN	SIN		0	320
#
# 3K	SGN	SIN		0	320
#
# 3K	SIN	BKI		0	320
#
# 3K	SIN	BKK		0	320
#
# 3K	SIN	HKG		0	320
#
# 3K	SIN	KCH		0	320
#
# 3K	SIN	KUL		0	320
#
# 3K	SIN	MFM		0	320
# 3K	SIN	MNL		0	320
#
# 3K	SIN	PNH		0	320
#
# 3K	SIN	REP		0	320
#
# 3K	SIN	RGN		0	320
#
# 3K	SIN	SGN		0	320
#
# 3K	SIN	TPE		0	320
#
# 3K	TPE	SIN		0	320
#
# 3L	BIA	FDH		0	DH3
#
# 3L	CDG	FDH		0	DH3
#
# 3L	CGN	FDH		0	DH3
#
# 3L	DRS	FDH		0	DH3
#
# 3L	EBA	FDH		0	DH3
#
# 3L	EBA	MUC		0	DH3
#
# 3L	EBA	ZRH		0	DH3
#
# 3L	FDH	BIA		0	DH3
#
# 3L	FDH	CDG		0	DH3
#
# 3L	FDH	CGN		0	DH3
#
# 3L	FDH	DRS		0	DH3
#
# 3L	FDH	EBA		0	DH3
#
# 3L	FDH	FMO		0	DH3
#
# 3L	FDH	GRZ		0	DH3
#
# 3L	FDH	HAM		0	DH3
#
# 3L	FDH	NCE		0	DH3
#
# 3L	FDH	OLB		0	DH3
#
# 3L	FDH	PUY		0	DH3
#
# 3L	FDH	SPU		0	DH3
#
# 3L	FDH	TXL		0	DH3
#
# 3L	FDH	VIE		0	DH3
#
# 3L	FDH	ZAD		0	DH3
#
# 3L	FMO	FDH		0	DH3
#
# 3L	GRZ	FDH		0	DH3
#
# 3L	GRZ	SPU		0	DH3
#
# 3L	GRZ	TXL		0	DH3
#
# 3L	HAM	FDH		0	DH3
#
# 3L	MUC	EBA		0	DH3
#
# 3L	NCE	FDH		0	DH3
#
# 3L	OLB	FDH		0	DH3
#
# 3L	PUY	FDH		0	DH3
#
# 3L	SPU	FDH		0	DH3
#
# 3L	SPU	GRZ		0	DH3
#
# 3L	TXL	FDH		0	DH3
#
# 3L	TXL	GRZ		0	DH3
#
# 3L	VIE	FDH		0	DH3
#
# 3L	ZAD	FDH		0	DH3
#
# 3L	ZRH	EBA		0	DH3
#
# 3M	FLL	MIA		0	BE1
#
# 3P	AUA	BON		0	SH6
#
# 3P	AUA	CUR		0	SH6
#
# 3P	AUA	LSP		0	SH6
#
# 3P	BON	AUA		0	SH6
#
# 3P	CUR	AUA		0	SH6
#
# 3P	LSP	AUA		0	SH6
#
# 3R	AZN	DME		0	TU5
#
# 3R	BHK	DME		0	TU5
#
# 3R	DME	SKD		0	TU5
#
# 3R	NMA	DME		0	TU5
#
# 3R	SKD	DME		0	TU5
#
# 3R	TMJ	DME		0	TU5
#
# 3T	DME	KVD		0	TU5
#
# 3T	GYD	KSY		0	TU5
#
# 3T	GYD	SVX		0	TU5
#
# 3T	KSY	GYD		0	TU5
#
# 3T	KVD	DME		0	TU5
#
# 3T	KVD	SAW		0	TU5
#
# 3T	SAW	KVD		0	TU5
#
# 3T	SVX	GYD		0	TU5
#
# 3U	CAN	CKG		0	320
#
# 3U	CAN	CTU		0	320 321
#
# 3U	CGO	CGQ		0	319
#
# 3U	CGO	CTU		0	319
#
# 3U	CGQ	CGO		0	319
#
# 3U	CKG	CAN		0	320
#
# 3U	CKG	CSX		0	320
#
# 3U	CKG	CTU		0	320
#
# 3U	CKG	DYG		0	320
#
# 3U	CKG	HGH		0	320
#
# 3U	CKG	JZH		0	319
#
# 3U	CKG	KMG		0	320 319
#
# 3U	CKG	KWL		0	320
#
# 3U	CKG	LJG		0	319
#
# 3U	CKG	LXA		0	319
#
# 3U	CKG	NKG		0	320
#
# 3U	CKG	PEK		0	320
#
# 3U	CKG	PVG		0	320
#
# 3U	CKG	SYX		0	320
#
# 3U	CKG	SZX		0	320
#
# 3U	CKG	TNA		0	319
#
# 3U	CKG	TSA		0	320
#
# 3U	CKG	WNZ		0	320
#
# 3U	CKG	XIY		0	319
#
# 3U	CKG	YIH		0	320
#
# 3U	CSX	CKG		0	320
#
# 3U	CSX	CTU		0	320
#
# 3U	CSX	FOC		0	320
#
# 3U	CSX	XMN		0	320
#
# 3U	CTU	CAN		0	320 321
#
# 3U	CTU	CGO		0	319
#
# 3U	CTU	CKG		0	320
#
# 3U	CTU	CSX		0	320
#
# 3U	CTU	HAK		0	320
#
# 3U	CTU	HET		0	319
#
# 3U	CTU	HFE		0	319
#
# 3U	CTU	HGH		0	320
#
# 3U	CTU	INC		0	320
#
# 3U	CTU	JZH		0	319
#
# 3U	CTU	KHN		0	320
#
# 3U	CTU	KMG		0	319 320
#
# 3U	CTU	KWE		0	320
#
# 3U	CTU	KWL		0	320
#
# 3U	CTU	LHW		0	320
#
# 3U	CTU	LJG		0	319
#
# 3U	CTU	LXA		0	319
#
# 3U	CTU	NKG		0	320
#
# 3U	CTU	PEK		0	321 320
#
# 3U	CTU	PVG		0	321
#
# 3U	CTU	PZI		0	319
#
# 3U	CTU	SYX		0	320
#
# 3U	CTU	SZX		0	320
#
# 3U	CTU	TAO		0	320
#
# 3U	CTU	TNA		0	321 319
#
# 3U	CTU	TSA		0	320
#
# 3U	CTU	TSN		0	319
#
# 3U	CTU	URC		0	319
#
# 3U	CTU	WNZ		0	321
#
# 3U	CTU	WUH		0	319
#
# 3U	CTU	WUX		0	320
#
# 3U	CTU	XIC		0	320
#
# 3U	CTU	XIY		0	321
#
# 3U	CTU	XMN		0	319
#
# 3U	CTU	XNN		0	320
#
# 3U	CTU	XUZ		0	319
#
# 3U	CTU	YIH		0	320
#
# 3U	DLC	TNA		0	321
#
# 3U	DLC	XUZ		0	319
#
# 3U	DYG	CKG		0	320
#
# 3U	FOC	CSX		0	320
#
# 3U	HAK	CTU		0	320
#
# 3U	HET	CTU		0	319
#
# 3U	HFE	CTU		0	319
#
# 3U	HGH	CKG		0	320
#
# 3U	HGH	CTU		0	320
#
# 3U	HRB	NKG		0	320
#
# 3U	HRB	TNA		0	319
#
# 3U	INC	CTU		0	320
#
# 3U	JHG	KMG		0	319
#
# 3U	JZH	CKG		0	319
#
# 3U	JZH	CTU		0	319
#
# 3U	JZH	XIY		0	319
#
# 3U	KHN	CTU		0	320
#
# 3U	KHN	NGB		0	320
#
# 3U	KMG	CKG		0	320 319
#
# 3U	KMG	CTU		0	319 320
#
# 3U	KMG	JHG		0	319
#
# 3U	KMG	WXN		0	319
#
# 3U	KWE	CTU		0	320
#
# 3U	KWL	CKG		0	320
#
# 3U	KWL	CTU		0	320
#
# 3U	KWL	XMN		0	320
#
# 3U	LHW	CTU		0	320
#
# 3U	LJG	CKG		0	319
#
# 3U	LJG	CTU		0	319
#
# 3U	LXA	CKG		0	319
#
# 3U	LXA	CTU		0	319
#
# 3U	NGB	KHN		0	320
#
# 3U	NKG	CKG		0	320
#
# 3U	NKG	CTU		0	320
#
# 3U	NKG	HRB		0	320
#
# 3U	NTG	WUH		0	319
#
# 3U	PEK	CKG		0	320
#
# 3U	PEK	CTU		0	321 320
#
# 3U	PEK	WXN		0	319
#
# 3U	PVG	CKG		0	320
#
# 3U	PVG	CTU		0	321 320
#
# 3U	PZI	CTU		0	319
#
# 3U	SHE	TSN		0	319
#
# 3U	SYX	CKG		0	320
#
# 3U	SYX	CTU		0	320
#
# 3U	SZX	CKG		0	320
#
# 3U	SZX	CTU		0	320
#
# 3U	TAO	CTU		0	320
#
# 3U	TNA	CKG		0	319
#
# 3U	TNA	CTU		0	321 319
#
# 3U	TNA	DLC		0	321
#
# 3U	TNA	HRB		0	319
#
# 3U	TSA	CKG		0	320
#
# 3U	TSA	CTU		0	320
#
# 3U	TSN	CTU		0	319
#
# 3U	TSN	SHE		0	319
#
# 3U	URC	CTU		0	319
#
# 3U	WNZ	CKG		0	320
#
# 3U	WNZ	CTU		0	321
#
# 3U	WUH	CTU		0	319
#
# 3U	WUH	NTG		0	319
#
# 3U	WUX	CTU		0	320
#
# 3U	WXN	KMG		0	319
#
# 3U	WXN	PEK		0	319
#
# 3U	XIC	CTU		0	320
#
# 3U	XIY	CKG		0	319
#
# 3U	XIY	CTU		0	321
#
# 3U	XIY	JZH		0	319
#
# 3U	XMN	CSX		0	320
#
# 3U	XMN	CTU		0	319
#
# 3U	XMN	KWL		0	320
#
# 3U	XNN	CTU		0	320
#
# 3U	XUZ	CTU		0	319
#
# 3U	XUZ	DLC		0	319
#
# 3U	YIH	CKG		0	320
#
# 3U	YIH	CTU		0	320
#
# 3Z	AET	FAI		0	PAG
#
# 3Z	AKP	AET		0	PAG
#
# 3Z	ARC	WBQ		0	PAG
#
# 3Z	BTT	AKP		0	PAG
#
# 3Z	EAA	FAI		0	PAG
#
# 3Z	FAI	BTT		0	PAG
#
# 3Z	FAI	EAA		0	PAG
#
# 3Z	FAI	FYU		0	PAG
#
# 3Z	FAI	LMA		0	PAG
#
# 3Z	FYU	VEE		0	PAG
#
# 3Z	LMA	FAI		0	PAG
#
# 3Z	VEE	ARC		0	PAG
#
# 3Z	WBQ	FAI		0	PAG
#
# 4A	CGP	CXB		0	DH8
#
# 4A	CGP	DAC		0	DH8
#
# 4A	CXB	CGP		0	DH8
#
# 4A	CXB	DAC		0	DH8
#
# 4A	DAC	CGP		0	DH8
#
# 4A	DAC	CXB		0	DH8
#
# 4A	DAC	JSR		0	DH8
#
# 4A	DAC	SPD		0	DH8
#
# 4A	DAC	ZYL		0	DH8
#
# 4A	JSR	DAC		0	DH8
#
# 4A	SPD	DAC		0	DH8
#
# 4A	ZYL	DAC		0	DH8
#
# 4C	APO	EOH		0	DH8
#
# 4C	AUA	BAQ		0	DH8
#
# 4C	AXM	BOG		0	DH8
#
# 4C	AXM	EOH		0	DH8
#
# 4C	BAQ	AUA		0	DH8
#
# 4C	BAQ	CTG		0	DH8
#
# 4C	BAQ	CUR		0	DH8
#
# 4C	BAQ	MAR		0	DH8
#
# 4C	BAQ	MTR		0	DH8
#
# 4C	BAQ	PTY		0	DH8
#
# 4C	BAQ	VUP		0	DH8
#
# 4C	BGA	CUC		0	DH8
#
# 4C	BGA	EOH		0	DH8
#
# 4C	BGA	EYP		0	DH8
#
# 4C	BOG	AXM		0	DH8
#
# 4C	BOG	EYP		0	DH8
#
# 4C	BOG	FLA		0	DH8
#
# 4C	BOG	IBE		0	DH8
#
# 4C	BOG	MAR		0	DH8
#
# 4C	BOG	MZL		0	DH8
#
# 4C	BOG	NVA		0	DH8
#
# 4C	BOG	PPN		0	DH8
#
# 4C	BOG	UIB		0	DH8
#
# 4C	BOG	VVC		0	DH8
#
# 4C	CLO	PEI		0	DH8
#
# 4C	CTG	BAQ		0	DH8
#
# 4C	CTG	MAR		0	DH8
#
# 4C	CTG	MTR		0	DH8
#
# 4C	CTG	PTY		0	DH8
#
# 4C	CUC	BGA		0	DH8
#
# 4C	CUR	BAQ		0	DH8
#
# 4C	EOH	APO		0	DH8
#
# 4C	EOH	AXM		0	DH8
#
# 4C	EOH	BGA		0	DH8
#
# 4C	EOH	BOG		0	DH8
#
# 4C	EOH	IBE		0	DH8
#
# 4C	EOH	MTR		0	DH8
#
# 4C	EOH	MZL		0	DH8
#
# 4C	EOH	PEI		0	DH8
#
# 4C	EOH	UIB		0	DH8
#
# 4C	EYP	BGA		0	DH8
#
# 4C	EYP	BOG		0	DH8
#
# 4C	FLA	BOG		0	DH8
#
# 4C	FLA	NVA		0	DH8
#
# 4C	IBE	BOG		0	DH8
#
# 4C	IBE	EOH		0	DH8
#
# 4C	MAR	BAQ		0	DH8
#
# 4C	MAR	BOG		0	DH8
#
# 4C	MAR	CTG		0	DH8
#
# 4C	MTR	BAQ		0	DH8
#
# 4C	MTR	CTG		0	DH8
#
# 4C	MTR	EOH		0	DH8
#
# 4C	MZL	BOG		0	DH8
#
# 4C	MZL	EOH		0	DH8
#
# 4C	NVA	BOG		0	DH8
#
# 4C	NVA	FLA		0	DH8
#
# 4C	NVA	PUU		0	DH8
#
# 4C	PEI	CLO		0	DH8
#
# 4C	PEI	EOH		0	DH8
#
# 4C	PEI	PTY		0	DH8
#
# 4C	PPN	BOG		0	DH8
#
# 4C	PTY	BAQ		0	DH8
#
# 4C	PTY	CTG		0	DH8
#
# 4C	PTY	PEI		0	DH8
#
# 4C	PUU	NVA		0	DH8
#
# 4C	UIB	BOG		0	DH8
#
# 4C	UIB	EOH		0	DH8
#
# 4C	VUP	BAQ		0	DH8
#
# 4C	VVC	BOG		0	DH8
#
# 4D	CAI	TLV		0	735
#
# 4D	TLV	CAI		0	735
#
# 4E	MCG	NIB		0	PAG
#
# 4E	MCG	TCT		0	PAG
#
# 4E	NIB	MCG		0	PAG
#
# 4E	TCT	TLJ		0	PAG
#
# 4E	TLJ	MCG		0	PAG
#
# 4G	AER	VKO		0	YK4
#
# 4G	EGO	NUX		0	TU5
#
# 4G	EGO	VKO		0	YK4
#
# 4G	EYK	KRR		0	YK4
#
# 4G	EYK	VKO		0	YK4
#
# 4G	KRR	EYK		0	YK4
#
# 4G	KRR	OVS		0	YK4
#
# 4G	KUF	NUX		0	YK4
#
# 4G	KUF	TJM		0	YK4
#
# 4G	KUF	VKO		0	YK4
#
# 4G	LED	VKO		0	YK4
#
# 4G	NCU	VKO		0	YK4
#
# 4G	NUX	EGO		0	TU5
#
# 4G	NUX	KUF		0	YK4
#
# 4G	NUX	VKO		0	YK4
#
# 4G	NYM	OVS		0	YK4
#
# 4G	NYM	VKO		0	TU5
#
# 4G	OVS	AAQ		0	YK4
#
# 4G	OVS	AER		0	YK4
#
# 4G	OVS	KRR		0	YK4
#
# 4G	OVS	NYM		0	YK4
#
# 4G	OVS	VKO		0	YK4
#
# 4G	TJM	KUF		0	YK4
#
# 4G	TOF	VKO		0	TU5
#
# 4G	VKO	AER		0	YK4
#
# 4G	VKO	EGO		0	TU5
#
# 4G	VKO	EYK		0	YK4
#
# 4G	VKO	KUF		0	YK4
#
# 4G	VKO	LED		0	YK4
#
# 4G	VKO	NCU		0	YK4
#
# 4G	VKO	NUX		0	YK4
#
# 4G	VKO	NYM		0	YK4 TU5
#
# 4G	VKO	OVS		0	YK4
#
# 4G	VKO	TOF		0	TU5
#
# 4H	BZL	DAC		0	DH8
#
# 4H	CGP	DAC		0	DH8
#
# 4H	CXB	DAC		0	DH8
#
# 4H	DAC	BZL		0	DH8
#
# 4H	DAC	CGP		0	DH8
#
# 4H	DAC	CXB		0	DH8
#
# 4H	DAC	JSR		0	DH8
#
# 4H	DAC	ZYL		0	DH8
#
# 4H	JSR	DAC		0	DH8
#
# 4H	ZYL	DAC		0	DH8
#
# 4K	YGZ	YRB		0	DHT
#
# 4K	YRB	YGZ		0	DHT
#
# 4M	EZE	MIA		0	763
#
# 4M	EZE	PUJ		0	763
#
# 4M	MIA	EZE		0	763
#
# 4M	MIA	PUJ		0	763
#
# 4M	PUJ	EZE		0	763
#
# 4M	PUJ	MIA		0	763
#
# 4N	FAI	YDA		0	HS7
#
# 4N	YDA	YEV		0	HS7
#
# 4N	YDA	YOC		0	HS7
#
# 4N	YDA	YXY		0	HS7
#
# 4N	YEG	YXY		0	737
#
# 4N	YEV	YDA		0	HS7
#
# 4N	YEV	YOC		0	HS7
#
# 4N	YOC	FAI		0	HS7
#
# 4N	YOC	YDA		0	HS7
#
# 4N	YOC	YEV		0	HS7
#
# 4N	YVR	YXY		0	737
#
# 4N	YXY	YDA		0	HS7
#
# 4N	YXY	YVR		0	737
#
# 4N	YXY	YYC		0	737
#
# 4N	YYC	YEG		0	737
#
# 4O	ACA	MEX		0	320
#
# 4O	ACA	TLC		0	320
#
# 4O	CEN	MEX		0	320
#
# 4O	CJS	MEX		0	320
#
# 4O	CME	MEX		0	320
#
# 4O	CUL	MEX		0	320
#
# 4O	CUN	MEX		0	320
#
# 4O	CUN	MTY		0	320
#
# 4O	CUN	TLC		0	320
#
# 4O	CUU	TLC		0	320
#
# 4O	DGO	MEX		0	320
#
# 4O	DGO	TIJ		0	320
#
# 4O	GDL	MEX		0	320
#
# 4O	GDL	MTY		0	320
#
# 4O	GDL	SJD		0	320
#
# 4O	GDL	TIJ		0	320
#
# 4O	GDL	TLC		0	320
#
# 4O	HMO	MEX		0	320
#
# 4O	HUX	MEX		0	320
#
# 4O	LMM	MEX		0	320
#
# 4O	MEX	ACA		0	320
#
# 4O	MEX	CEN		0	320
#
# 4O	MEX	CJS		0	320
#
# 4O	MEX	CME		0	320
#
# 4O	MEX	CUL		0	320
#
# 4O	MEX	CUN		0	320
#
# 4O	MEX	DGO		0	320
#
# 4O	MEX	GDL		0	320
#
# 4O	MEX	HMO		0	320
#
# 4O	MEX	HUX		0	320
#
# 4O	MEX	LMM		0	320
#
# 4O	MEX	MTY		0	320
#
# 4O	MEX	SJD		0	320
#
# 4O	MEX	TAM		0	320
#
# 4O	MEX	TGZ		0	320
#
# 4O	MEX	TIJ		0	320
#
# 4O	MEX	VER		0	320
#
# 4O	MEX	ZIH		0	320
#
# 4O	MTY	CUN		0	320
#
# 4O	MTY	GDL		0	320
#
# 4O	MTY	MEX		0	320
#
# 4O	MTY	TLC		0	320
#
# 4O	PVR	TLC		0	320
#
# 4O	SJD	GDL		0	320
#
# 4O	SJD	MEX		0	320
#
# 4O	SJD	TLC		0	320
#
# 4O	TAM	MEX		0	320
#
# 4O	TGZ	MEX		0	320
#
# 4O	TIJ	DGO		0	320
#
# 4O	TIJ	GDL		0	320
#
# 4O	TIJ	MEX		0	320
#
# 4O	TLC	ACA		0	320
#
# 4O	TLC	CUN		0	320
#
# 4O	TLC	CUU		0	320
#
# 4O	TLC	GDL		0	320
#
# 4O	TLC	MTY		0	320
#
# 4O	TLC	PVR		0	320
#
# 4O	TLC	SJD		0	320
#
# 4O	TLC	ZIH		0	320
#
# 4O	VER	MEX		0	320
#
# 4O	ZIH	MEX		0	320
#
# 4O	ZIH	TLC		0	320
#
# 4P	BEY	CPH		0	M83
#
# 4P	CPH	BEY		0	M83
#
# 4Q	DXB	KBL		0	762
#
# 4Q	KBL	DXB		0	762
#
# 4U	ADB	CGN		0	319
#
# 4U	ADB	STR		0	319
#
# 4U	AGP	STR		0	319
#
# 4U	ARN	CGN		0	319
#
# 4U	ARN	SXF		0	319
#
# 4U	ATH	CGN		0	319
#
# 4U	ATH	STR		0	319
#
# 4U	AYT	CGN		0	319
#
# 4U	AYT	STR		0	319
#
# 4U	BBU	CGN		0	319
#
# 4U	BBU	STR		0	319
#
# 4U	BBU	SXF		0	319
#
# 4U	BCN	CGN		0	737
#
# 4U	BCN	STR		0	319
#
# 4U	BEG	CGN		0	319
#
# 4U	BEG	STR		0	319
#
# 4U	BIA	CGN		0	319
#
# 4U	BIA	STR		0	319
#
# 4U	BIA	SXF		0	319
#
# 4U	BLQ	CGN		0	319
#
# 4U	BUD	CGN		0	319
#
# 4U	BUD	STR		0	319
#
# 4U	CFU	CGN		0	319
#
# 4U	CFU	DRS		0	319
#
# 4U	CFU	HAM		0	319
#
# 4U	CFU	STR		0	319
#
# 4U	CGN	ADB		0	319
#
# 4U	CGN	ARN		0	319
#
# 4U	CGN	ATH		0	319
#
# 4U	CGN	AYT		0	319
#
# 4U	CGN	BBU		0	319
#
# 4U	CGN	BCN		0	737
#
# 4U	CGN	BEG		0	319
#
# 4U	CGN	BIA		0	319
#
# 4U	CGN	BLQ		0	319
#
# 4U	CGN	BUD		0	319
#
# 4U	CGN	CFU		0	319
#
# 4U	CGN	DBV		0	319
#
# 4U	CGN	DRS		0	319
#
# 4U	CGN	DUB		0	319
#
# 4U	CGN	EDI		0	319
#
# 4U	CGN	FAO		0	319
#
# 4U	CGN	FCO		0	319
#
# 4U	CGN	HER		0	319
#
# 4U	CGN	IBZ		0	319
#
# 4U	CGN	JMK		0	319
#
# 4U	CGN	KBP		0	319
#
# 4U	CGN	KEF		0	319
#
# 4U	CGN	KGS		0	319
#
# 4U	CGN	KTW		0	319
#
# 4U	CGN	KVA		0	319
#
# 4U	CGN	LED		0	319
#
# 4U	CGN	LEJ		0	319
#
# 4U	CGN	LIS		0	319
#
# 4U	CGN	MRS		0	319
#
# 4U	CGN	MUC		0	319
#
# 4U	CGN	MXP		0	319
#
# 4U	CGN	NCE		0	319
#
# 4U	CGN	PMI		0	737 319
#
# 4U	CGN	PRG		0	319
#
# 4U	CGN	PRN		0	319
#
# 4U	CGN	PUY		0	319
#
# 4U	CGN	RHO		0	737
#
# 4U	CGN	RLG		0	319
#
# 4U	CGN	SAW		0	319
#
# 4U	CGN	SJJ		0	319
#
# 4U	CGN	SKG		0	319
#
# 4U	CGN	SKP		0	319
#
# 4U	CGN	SOF		0	319
#
# 4U	CGN	SPU		0	319
#
# 4U	CGN	STN		0	319
#
# 4U	CGN	SUF		0	319
#
# 4U	CGN	SXF		0	319
#
# 4U	CGN	VIE		0	319
#
# 4U	CGN	VKO		0	319
#
# 4U	CGN	VRN		0	319
#
# 4U	CGN	WAW		0	319
#
# 4U	CGN	ZAD		0	319
#
# 4U	CGN	ZAG		0	319
#
# 4U	CGN	ZRH		0	319
#
# 4U	DBV	CGN		0	319
#
# 4U	DBV	SXF		0	319
#
# 4U	DRS	CFU		0	319
#
# 4U	DRS	CGN		0	319
#
# 4U	DRS	STR		0	319
#
# 4U	DTM	MUC		0	319
#
# 4U	DTM	PMI		0	319
#
# 4U	DTM	SPU		0	319
#
# 4U	DUB	CGN		0	319
#
# 4U	EDI	CGN		0	319
#
# 4U	FAO	CGN		0	319
#
# 4U	FAO	STR		0	319
#
# 4U	FCO	CGN		0	319
#
# 4U	FCO	STR		0	319
#
# 4U	HAM	CFU		0	319
#
# 4U	HAM	PRN		0	319
#
# 4U	HAM	SPU		0	319
#
# 4U	HAM	STR		0	319
#
# 4U	HAM	TLS		0	319
#
# 4U	HER	CGN		0	319
#
# 4U	HER	STR		0	319
#
# 4U	HER	SXF		0	319
#
# 4U	IBZ	CGN		0	319
#
# 4U	IBZ	STR		0	319
#
# 4U	JMK	CGN		0	319
#
# 4U	KBP	CGN		0	319
#
# 4U	KEF	CGN		0	319
#
# 4U	KEF	STR		0	319
#
# 4U	KGS	CGN		0	319
#
# 4U	KTW	CGN		0	319
#
# 4U	KTW	STR		0	319
#
# 4U	KVA	CGN		0	319
#
# 4U	KVA	STR		0	319
#
# 4U	LED	CGN		0	319
#
# 4U	LEJ	CGN		0	319
#
# 4U	LEJ	STR		0	319
#
# 4U	LIS	CGN		0	319
#
# 4U	LIS	STR		0	319
#
# 4U	MAD	STR		0	319
#
# 4U	MRS	CGN		0	319
#
# 4U	MUC	CGN		0	319
#
# 4U	MUC	DTM		0	319
#
# 4U	MUC	SXF		0	319
#
# 4U	MXP	CGN		0	319
#
# 4U	NCE	CGN		0	319
#
# 4U	PMI	CGN		0	737 319
#
# 4U	PMI	DTM		0	319
#
# 4U	PMI	STR		0	319
#
# 4U	PRG	CGN		0	319
#
# 4U	PRN	CGN		0	319
#
# 4U	PRN	HAM		0	319
#
# 4U	PRN	STR		0	319
#
# 4U	PUY	CGN		0	319
#
# 4U	PUY	SXF		0	319
#
# 4U	RHO	CGN		0	737
#
# 4U	RLG	CGN		0	319
#
# 4U	RLG	STR		0	319
#
# 4U	SAW	CGN		0	319
#
# 4U	SAW	STR		0	319
#
# 4U	SJJ	CGN		0	319
#
# 4U	SJJ	STR		0	319
#
# 4U	SKG	CGN		0	319
#
# 4U	SKG	STR		0	319
#
# 4U	SKP	CGN		0	319
#
# 4U	SOF	CGN		0	319
#
# 4U	SPU	CGN		0	319
#
# 4U	SPU	DTM		0	319
#
# 4U	SPU	HAM		0	319
#
# 4U	SPU	STR		0	319
#
# 4U	SPU	SXF		0	319
#
# 4U	STN	CGN		0	319
#
# 4U	STN	STR		0	319
#
# 4U	STR	ADB		0	319
#
# 4U	STR	AGP		0	319
#
# 4U	STR	ATH		0	319
#
# 4U	STR	AYT		0	319
#
# 4U	STR	BBU		0	319
#
# 4U	STR	BCN		0	319
#
# 4U	STR	BEG		0	319
#
# 4U	STR	BIA		0	319
#
# 4U	STR	BUD		0	319
#
# 4U	STR	CFU		0	319
#
# 4U	STR	DRS		0	319
#
# 4U	STR	FAO		0	319
#
# 4U	STR	FCO		0	319
#
# 4U	STR	HAM		0	319
#
# 4U	STR	HER		0	319
#
# 4U	STR	IBZ		0	319
#
# 4U	STR	KEF		0	319
#
# 4U	STR	KTW		0	319
#
# 4U	STR	KVA		0	319
#
# 4U	STR	LEJ		0	319
#
# 4U	STR	LIS		0	319
#
# 4U	STR	MAD		0	319
#
# 4U	STR	PMI		0	319
#
# 4U	STR	PRN		0	319
#
# 4U	STR	RLG		0	319
#
# 4U	STR	SAW		0	319
#
# 4U	STR	SJJ		0	319
#
# 4U	STR	SKG		0	319
#
# 4U	STR	SPU		0	319
#
# 4U	STR	STN		0	319
#
# 4U	STR	SUF		0	319
#
# 4U	STR	SXF		0	319
#
# 4U	STR	VIE		0	319
#
# 4U	STR	VKO		0	319
#
# 4U	STR	WAW		0	319
#
# 4U	STR	ZAD		0	319
#
# 4U	STR	ZAG		0	319
#
# 4U	SUF	CGN		0	319
#
# 4U	SUF	STR		0	319
#
# 4U	SXF	ARN		0	319
#
# 4U	SXF	BBU		0	319
#
# 4U	SXF	BIA		0	319
#
# 4U	SXF	CGN		0	319
#
# 4U	SXF	DBV		0	319
#
# 4U	SXF	HER		0	319
#
# 4U	SXF	MUC		0	319
#
# 4U	SXF	PUY		0	319
#
# 4U	SXF	SPU		0	319
#
# 4U	SXF	STR		0	319
#
# 4U	SXF	VKO		0	319
#
# 4U	SXF	ZAD		0	319
#
# 4U	SXF	ZAG		0	319
#
# 4U	SXF	ZQW		0	319
#
# 4U	TLS	HAM		0	319
#
# 4U	VIE	CGN		0	319
#
# 4U	VIE	STR		0	319
#
# 4U	VKO	CGN		0	319
#
# 4U	VKO	STR		0	319
#
# 4U	VKO	SXF		0	319
#
# 4U	VRN	CGN		0	319
#
# 4U	WAW	CGN		0	319
#
# 4U	WAW	STR		0	319
#
# 4U	ZAD	CGN		0	319
#
# 4U	ZAD	STR		0	319
#
# 4U	ZAD	SXF		0	319
#
# 4U	ZAG	CGN		0	319
#
# 4U	ZAG	STR		0	319
#
# 4U	ZAG	SXF		0	319
#
# 4U	ZQW	SXF		0	319
#
# 4U	ZRH	CGN		0	319
#
# 4W	AET	AKP		0	PAG
#
# 4W	AKP	BTT		0	PAG
#
# 4W	AKP	FAI		0	PAG
#
# 4W	BTT	FAI		0	PAG
#
# 4W	CEM	IRC		0	PAG
#
# 4W	CIK	FYU		0	PAG
#
# 4W	FAI	AET		0	PAG
#
# 4W	FAI	CEM		0	PAG
#
# 4W	FAI	FYU		0	PAG
#
# 4W	FAI	GAL		0	PAG
#
# 4W	FAI	HSL		0	PAG
#
# 4W	FAI	HUS		0	PAG
#
# 4W	FAI	KAL		0	PAG
#
# 4W	FAI	KYU		0	PAG
#
# 4W	FAI	MLY		0	CNA
#
# 4W	FAI	RMP		0	CNA
#
# 4W	FAI	SVS		0	PAG
#
# 4W	FAI	TAL		0	PAG
#
# 4W	FAI	VEE		0	CNA
#
# 4W	FAI	WBQ		0	CNA
#
# 4W	FYU	CIK		0	PAG
#
# 4W	FYU	FAI		0	PAG
#
# 4W	GAL	FAI		0	PAG
#
# 4W	GAL	HSL		0	PAG
#
# 4W	GAL	KAL		0	PAG
#
# 4W	GAL	KYU		0	PAG
#
# 4W	GAL	RBY		0	PAG
#
# 4W	HSL	FAI		0	PAG
#
# 4W	HSL	GAL		0	PAG
#
# 4W	HSL	HUS		0	PAG
#
# 4W	HUS	FAI		0	PAG
#
# 4W	HUS	FAI		1	PAG
#
# 4W	HUS	HSL		0	PAG
#
# 4W	IRC	FAI		0	PAG
#
# 4W	KAL	NUL		0	PAG
#
# 4W	KYU	GAL		0	PAG
#
# 4W	KYU	NUL		0	PAG
#
# 4W	MLY	MNT		0	CNA
#
# 4W	MNT	FAI		0	CNA
#
# 4W	NUL	KAL		0	PAG
#
# 4W	NUL	KYU		0	PAG
#
# 4W	RBY	FAI		0	100
#
# 4W	RBY	GAL		0	PAG
#
# 4W	RBY	TAL		0	PAG
#
# 4W	SVS	FAI		0	CNA
#
# 4W	TAL	FAI		0	PAG
#
# 4W	TAL	RBY		0	PAG
#
# 4W	VEE	FAI		0	CNA
#
# 4W	WBQ	VEE		0	CNA
#
# 5B	ABV	LOS		0	732
#
# 5B	ABV	PHC		0	732
#
# 5B	KAD	LOS		0	732
#
# 5B	LOS	ABV		0	732
#
# 5B	LOS	KAD		0	732
#
# 5B	LOS	PHC		0	732
#
# 5B	LOS	QOW		0	732
#
# 5B	PHC	ABV		0	732
#
# 5B	PHC	LOS		0	732
#
# 5B	QOW	LOS		0	732
#
# 5C	FON	LIR		0	DHT
#
# 5C	FON	LIR		1	DHT
#
# 5C	FON	SYQ		0	DHT
#
# 5C	GLF	SYQ		0	DHT
#
# 5C	LIR	FON		0	DHT
#
# 5C	LIR	NOB		0	DHT
#
# 5C	LIR	SYQ		0	DHT
#
# 5C	LIR	TNO		0	DHT
#
# 5C	NOB	LIR		0	DHT
#
# 5C	NOB	PBP		0	DHT
#
# 5C	PBP	NOB		0	DHT
#
# 5C	PBP	SYQ		0	DHT
#
# 5C	PJM	GLF		0	DHT
#
# 5C	PJM	SYQ		0	DHT
#
# 5C	PJM	XQP		0	DHT
#
# 5C	PMZ	SYQ		0	DHT
#
# 5C	PMZ	XQP		0	DHT
#
# 5C	SYQ	FON		0	DHT
#
# 5C	SYQ	LIR		0	DHT
#
# 5C	SYQ	PBP		0	DHT
#
# 5C	SYQ	PJM		0	DHT
#
# 5C	SYQ	PJM		2	DHT
#
# 5C	SYQ	PMZ		0	DHT
#
# 5C	SYQ	PMZ		3	DHT
#
# 5C	SYQ	TMU		0	DHT
#
# 5C	SYQ	TNO		0	DHT
#
# 5C	SYQ	TTQ		0	DHT
#
# 5C	SYQ	XQP		0	DHT
#
# 5C	SYQ	XQP		2	DHT
#
# 5C	TMU	SYQ		0	DHT
#
# 5C	TNO	LIR		0	DHT
#
# 5C	TNO	SYQ		0	DHT
#
# 5C	TTQ	SYQ		0	DHT
#
# 5C	XQP	PMZ		0	DHT
#
# 5C	XQP	SYQ		0	DHT
#
# 5E	CEI	CNX		0	CNC
#
# 5E	CNX	CEI		0	CNC
#
# 5E	CNX	HGN		0	CNC
#
# 5E	CNX	PYY		0	CNC
#
# 5E	HGN	CNX		0	CNC
#
# 5E	PYY	CNX		0	CNC
#
# 5H	EBB	NBO		0	ATR
#
# 5H	EDL	KTL		0	DH8
#
# 5H	EDL	NBO		0	ATR DH8 BE1
#
# 5H	JRO	NBO		0	BE1
#
# 5H	KIS	EDL		0	ATR
#
# 5H	KIS	NBO		0	ATR
#
# 5H	KTL	EDL		0	DH8
#
# 5H	LAU	MYD		0	ATR
#
# 5H	MBA	MRE		0	DH8
#
# 5H	MBA	MYD		0	DH8 ATR
#
# 5H	MBA	NBO		0	ATR
#
# 5H	MBA	ZNZ		0	ATR
#
# 5H	MRE	MBA		0	DH8
#
# 5H	MRE	NBO		0	DH8
#
# 5H	MYD	LAU		0	ATR
#
# 5H	MYD	MBA		0	ATR
#
# 5H	MYD	NBO		0	ATR DH8
#
# 5H	NBO	EBB		0	ATR
#
# 5H	NBO	EDL		0	DH8 BE1
#
# 5H	NBO	JRO		0	BE1
#
# 5H	NBO	KIS		0	ATR
#
# 5H	NBO	MBA		0	ATR DH8
#
# 5H	NBO	MRE		0	DH8
#
# 5H	NBO	MYD		0	ATR
#
# 5H	ZNZ	MBA		0	ATR
#
# 5J	BCD	CEB		0	ATR
#
# 5J	BCD	MNL		0	320 319
#
# 5J	BKI	MNL		0	319
#
# 5J	BKK	CRK		0	319
#
# 5J	BKK	MNL		0	319
#
# 5J	BXU	CEB		0	319
#
# 5J	BXU	MNL		0	319 320
#
# 5J	CAN	MNL		0	319
#
# 5J	CBO	CEB		0	ATR
#
# 5J	CBO	MNL		0	319
#
# 5J	CEB	BCD		0	ATR
#
# 5J	CEB	BXU		0	319
#
# 5J	CEB	CBO		0	ATR
#
# 5J	CEB	CGY		0	ATR
#
# 5J	CEB	CRK		0	ATR
#
# 5J	CEB	DGT		0	320
#
# 5J	CEB	DPL		0	ATR
#
# 5J	CEB	DVO		0	319
#
# 5J	CEB	GES		0	319
#
# 5J	CEB	HKG		0	319
#
# 5J	CEB	ILO		0	ATR
#
# 5J	CEB	LGP		0	ATR
#
# 5J	CEB	MNL		0	319 320
#
# 5J	CEB	MPH		0	ATR
#
# 5J	CEB	OZC		0	ATR
#
# 5J	CEB	PPS		0	319
#
# 5J	CEB	SIN		0	319
#
# 5J	CEB	SUG		0	ATR
#
# 5J	CEB	TAC		0	ATR
#
# 5J	CEB	ZAM		0	ATR
#
# 5J	CGK	MNL		0	319
#
# 5J	CGY	CEB		0	ATR
#
# 5J	CGY	MNL		0	320
#
# 5J	CRK	BKK		0	319
#
# 5J	CRK	CEB		0	ATR
#
# 5J	CRK	HKG		0	319
#
# 5J	CRK	MFM		0	319
#
# 5J	CRK	SIN		0	319
#
# 5J	CRM	MNL		0	ATR
#
# 5J	CYP	MNL		0	ATR
#
# 5J	CYZ	MNL		0	ATR
#
# 5J	DGT	CEB		0	ATR
#
# 5J	DGT	MNL		0	319
#
# 5J	DPL	CEB		0	ATR
#
# 5J	DPL	MNL		0	319
#
# 5J	DVO	CEB		0	319
#
# 5J	DVO	ILO		0	319
#
# 5J	DVO	MNL		0	320 319
#
# 5J	DVO	ZAM		0	ATR
#
# 5J	GES	CEB		0	319
#
# 5J	GES	MNL		0	320
#
# 5J	HKG	CEB		0	319
#
# 5J	HKG	CRK		0	319
#
# 5J	HKG	MNL		0	319 320
#
# 5J	ILO	CEB		0	ATR
#
# 5J	ILO	DVO		0	319
#
# 5J	ILO	MNL		0	320
#
# 5J	KHH	MNL		0	319
#
# 5J	KIX	MNL		0	320
#
# 5J	KLO	MNL		0	320 ATR
#
# 5J	KUL	MNL		0	320
#
# 5J	LAO	MNL		0	ATR
#
# 5J	LGP	CEB		0	ATR
#
# 5J	LGP	MNL		0	320
#
# 5J	MFM	CRK		0	319
#
# 5J	MFM	MNL		0	320
#
# 5J	MNL	BCD		0	320 319
#
# 5J	MNL	BKI		0	319
#
# 5J	MNL	BKK		0	320
#
# 5J	MNL	BXU		0	319 320
#
# 5J	MNL	CAN		0	319
#
# 5J	MNL	CBO		0	319
#
# 5J	MNL	CEB		0	320 319
#
# 5J	MNL	CGK		0	319
#
# 5J	MNL	CGY		0	320
#
# 5J	MNL	CRM		0	ATR
#
# 5J	MNL	CYP		0	ATR
#
# 5J	MNL	CYZ		0	ATR
#
# 5J	MNL	DGT		0	319
#
# 5J	MNL	DPL		0	319
#
# 5J	MNL	DVO		0	320 319
#
# 5J	MNL	GES		0	320
#
# 5J	MNL	HKG		0	319 320
#
# 5J	MNL	ILO		0	320
#
# 5J	MNL	KHH		0	319
#
# 5J	MNL	KIX		0	320
#
# 5J	MNL	KLO		0	320 ATR
#
# 5J	MNL	KUL		0	320
#
# 5J	MNL	LAO		0	ATR
#
# 5J	MNL	LGP		0	320
#
# 5J	MNL	MFM		0	320
#
# 5J	MNL	MPH		0	ATR
#
# 5J	MNL	PPS		0	320 319
#
# 5J	MNL	RXS		0	319
#
# 5J	MNL	SGN		0	319
#
# 5J	MNL	SIN		0	320
#
# 5J	MNL	SJI		0	ATR
#
# 5J	MNL	TAC		0	320
#
# 5J	MNL	TAG		0	319
#
# 5J	MNL	TPE		0	319
#
# 5J	MNL	TUG		0	ATR
#
# 5J	MNL	USU		0	ATR
#
# 5J	MNL	VRC		0	ATR
#
# 5J	MNL	WNP		0	ATR
#
# 5J	MNL	ZAM		0	319
#
# 5J	MPH	CEB		0	ATR
#
# 5J	MPH	MNL		0	ATR
#
# 5J	OZC	CEB		0	ATR
#
# 5J	PPS	CEB		0	319
#
# 5J	PPS	MNL		0	320 319
#
# 5J	RXS	MNL		0	319
#
# 5J	SGN	MNL		0	319
#
# 5J	SIN	CEB		0	319
#
# 5J	SIN	MNL		0	320
#
# 5J	SJI	MNL		0	ATR
#
# 5J	SUG	CEB		0	ATR
#
# 5J	TAC	CEB		0	ATR
#
# 5J	TAC	MNL		0	320
#
# 5J	TAG	MNL		0	319
#
# 5J	TPE	MNL		0	319
#
# 5J	TUG	MNL		0	ATR
#
# 5J	USU	MNL		0	ATR
#
# 5J	VRC	MNL		0	ATR
#
# 5J	WNP	MNL		0	ATR
#
# 5J	ZAM	CEB		0	ATR
#
# 5J	ZAM	DVO		0	ATR
#
# 5J	ZAM	MNL		0	319
#
# 5L	ASU	VVI		0	732
#
# 5L	CBB	LPB		0	72S
#
# 5L	CBB	TJA		0	73S
#
# 5L	CBB	VVI		0	72S 732
#
# 5L	CIJ	LPB		0	72S
#
# 5L	CUZ	LPB		0	732
#
# 5L	EZE	VVI		0	732
#
# 5L	GRU	VVI		0	767
#
# 5L	LPB	CBB		0	72S
#
# 5L	LPB	CIJ		0	72S
#
# 5L	LPB	CUZ		0	732
#
# 5L	LPB	SRE		0	72S
#
# 5L	LPB	SRZ		0	72S
#
# 5L	LPB	TJA		0	72S
#
# 5L	LPB	VVI		0	72S 732
#
# 5L	MAD	VVI		0	747 330
#
# 5L	MIA	VVI		0	767
#
# 5L	PSZ	VVI		0	732
#
# 5L	SLA	VVI		0	732
#
# 5L	SLA	VVI		1	732
#
# 5L	SRE	LPB		0	72S
#
# 5L	SRE	SRZ		0	72S
#
# 5L	SRZ	LPB		0	72S
#
# 5L	TJA	CBB		0	732
#
# 5L	TJA	LPB		0	732
#
# 5L	TJA	VVI		0	72S
#
# 5L	VVI	ASU		0	732
#
# 5L	VVI	CBB		0	72S 747 732
#
# 5L	VVI	EZE		0	73S
#
# 5L	VVI	GRU		0	767
#
# 5L	VVI	LPB		0	72S 732
#
# 5L	VVI	MAD		0	747 330
#
# 5L	VVI	MIA		0	767
#
# 5L	VVI	PSZ		0	732
#
# 5L	VVI	SLA		0	732
#
# 5L	VVI	SRE		0	72S
#
# 5L	VVI	TJA		0	72S
#
# 5N	ARH	CSH		0	AN4
#
# 5N	ARH	KSZ		0	AN4
#
# 5N	ARH	LDG		0	AN4
#
# 5N	ARH	LED		0	735
#
# 5N	ARH	MMK		0	AN4
#
# 5N	ARH	NNM		0	TU3 735
#
# 5N	ARH	SVO		0	735
#
# 5N	ARH	USK		0	AN4
#
# 5N	CSH	ARH		0	AN4
#
# 5N	EIK	SVO		0	TU3
#
# 5N	KSZ	ARH		0	AN4
#
# 5N	KVK	SVO		0	AN4
#
# 5N	LDG	ARH		0	AN4
#
# 5N	LED	ARH		0	735
#
# 5N	LED	MMK		0	735
#
# 5N	LED	PEE		0	735
#
# 5N	MMK	ARH		0	AN4
#
# 5N	MMK	LED		0	735
#
# 5N	MMK	SVO		0	735
#
# 5N	MMK	TOS		0	AN4
#
# 5N	NNM	ARH		0	TU3 735
#
# 5N	NNM	SVO		0	735
#
# 5N	OMS	SVO		0	735
#
# 5N	PEE	LED		0	735
#
# 5N	SCW	SVO		0	TU3
#
# 5N	SIP	SVO		0	735
#
# 5N	SVO	ARH		0	735
#
# 5N	SVO	EIK		0	TU3
#
# 5N	SVO	KVK		0	AN4
#
# 5N	SVO	MMK		0	735
#
# 5N	SVO	NNM		0	735
#
# 5N	SVO	OMS		0	735
#
# 5N	SVO	SCW		0	TU3
#
# 5N	SVO	SIP		0	735
#
# 5N	TOS	MMK		0	AN4
#
# 5N	USK	ARH		0	AN4
#
# 5Q	BKK	DAC		0	M83
#
# 5Q	DAC	BKK		0	M83
#
# 5Q	DAC	DXB		0	M83
#
# 5Q	DAC	KUL		0	M83
#
# 5Q	DXB	DAC		0	M83
#
# 5Q	KUL	DAC		0	M83
#
# 5Q	KUL	SIN		0	M83
#
# 5Q	SIN	DAC		0	M83
#
# 5T	YBB	YHK		0	DH8
#
# 5T	YBB	YYH		0	DH8
#
# 5T	YCB	YBB		0	DH8
#
# 5T	YCB	YCO		0	DH8
#
# 5T	YCB	YYH		0	DH8
#
# 5T	YCB	YZF		0	DH8
#
# 5T	YCO	YCB		0	DH8
#
# 5T	YCO	YZF		0	DH8
#
# 5T	YCY	YFB		0	DH8
#
# 5T	YCY	YIO		0	DH8
#
# 5T	YEG	YHY		0	DH8
#
# 5T	YEG	YVQ		0	737
#
# 5T	YEG	YYC		0	DH8 737
#
# 5T	YEG	YZF		0	737
#
# 5T	YEV	YEG		0	737
#
# 5T	YEV	YVQ		0	737
#
# 5T	YFB	YCY		0	DH8
#
# 5T	YFB	YGT		0	DH8
#
# 5T	YFB	YOW		0	737
#
# 5T	YFB	YRT		0	737
#
# 5T	YFB	YTE		0	DH8
#
# 5T	YFB	YUX		0	DH8
#
# 5T	YFB	YXP		0	DH8
#
# 5T	YGT	YFB		0	DH8
#
# 5T	YGT	YIO		0	DH8
#
# 5T	YGT	YUX		0	DH8
#
# 5T	YHK	YCB		0	DH8
#
# 5T	YHK	YYH		0	DH8
#
# 5T	YHK	YZF		0	DH8
#
# 5T	YHY	YEG		0	DH8
#
# 5T	YHY	YZF		0	DH8
#
# 5T	YIO	YCY		0	DH8
#
# 5T	YIO	YGT		0	DH8
#
# 5T	YOW	YFB		0	737
#
# 5T	YRT	YFB		0	737
#
# 5T	YRT	YZF		0	737
#
# 5T	YTE	YFB		0	DH8
#
# 5T	YUX	YFB		0	DH8
#
# 5T	YUX	YGT		0	DH8
#
# 5T	YVM	YXP		0	DH8
#
# 5T	YVQ	YEV		0	737
#
# 5T	YVQ	YZF		0	737
#
# 5T	YXP	YFB		0	DH8
#
# 5T	YXP	YVM		0	DH8
#
# 5T	YYC	YEG		0	DH8 737
#
# 5T	YYH	YBB		0	DH8
#
# 5T	YYH	YHK		0	DH8
#
# 5T	YYH	YZF		0	DH8
#
# 5T	YZF	YBB		0	DH8
#
# 5T	YZF	YCB		0	DH8
#
# 5T	YZF	YCO		0	DH8
#
# 5T	YZF	YEG		0	737
#
# 5T	YZF	YHK		0	DH8
#
# 5T	YZF	YHY		0	DH8
#
# 5T	YZF	YRT		0	737
#
# 5T	YZF	YVQ		0	737
#
# 5T	YZF	YYH		0	DH8
#
# 6A	ACA	MEX		0	732
#
# 6A	CJS	MTY		0	732
#
# 6A	CTM	MEX		0	732
#
# 6A	CUN	MEX		0	732 733
#
# 6A	CUN	MTY		0	732
#
# 6A	GDL	MEX		0	732 733
#
# 6A	GDL	MTY		0	732
#
# 6A	GDL	TIJ		0	733
#
# 6A	HMO	MEX		0	732
#
# 6A	LAS	MTY		0	732
#
# 6A	MEX	ACA		0	732
#
# 6A	MEX	CTM		0	732
#
# 6A	MEX	CUN		0	732 733
#
# 6A	MEX	GDL		0	733 732
#
# 6A	MEX	HMO		0	732
#
# 6A	MEX	MID		0	733 732
#
# 6A	MEX	MTY		0	732
#
# 6A	MEX	OAX		0	732
#
# 6A	MEX	PVR		0	732
#
# 6A	MEX	TAM		0	732
#
# 6A	MEX	TAP		0	732
#
# 6A	MEX	TGZ		0	732
#
# 6A	MEX	VER		0	732
#
# 6A	MEX	VSA		0	732
#
# 6A	MID	MEX		0	733 732
#
# 6A	MTY	CJS		0	732
#
# 6A	MTY	CUN		0	732
#
# 6A	MTY	GDL		0	732
#
# 6A	MTY	LAS		0	732
#
# 6A	MTY	MEX		0	732
#
# 6A	OAX	MEX		0	732
#
# 6A	PVR	MEX		0	732
#
# 6A	TAM	MEX		0	732
#
# 6A	TAP	MEX		0	732
#
# 6A	TGZ	MEX		0	732
#
# 6A	TIJ	GDL		0	733
#
# 6A	VER	MEX		0	732
#
# 6A	VSA	MEX		0	732
#
# 6D	EBB	JUB		0	EM2
#
# 6D	EBB	KIS		0	EM2
#
# 6D	JUB	EBB		0	EM2
#
# 6D	KIS	EBB		0	EM2
#
# 6E	AMD	BLR		0	320
#
# 6E	AMD	BOM		0	320
#
# 6E	AMD	CCU		0	320
#
# 6E	AMD	DEL		0	320
#
# 6E	AMD	JAI		0	320
#
# 6E	AMD	PNQ		0	320
#
# 6E	BBI	DEL		0	320
#
# 6E	BBI	HYD		0	320
#
# 6E	BDQ	BOM		0	320
#
# 6E	BDQ	DEL		0	320
#
# 6E	BLR	AMD		0	320
#
# 6E	BLR	BOM		0	320
#
# 6E	BLR	CCU		0	320
#
# 6E	BLR	DEL		0	320
#
# 6E	BLR	HYD		0	320
#
# 6E	BLR	MAA		0	320
#
# 6E	BLR	PNQ		0	320
#
# 6E	BOM	AMD		0	320
#
# 6E	BOM	BDQ		0	320
#
# 6E	BOM	BLR		0	320
#
# 6E	BOM	CCU		0	320
#
# 6E	BOM	DEL		0	320
#
# 6E	BOM	GOI		0	320
#
# 6E	BOM	HYD		0	320
#
# 6E	BOM	JAI		0	320
#
# 6E	BOM	MAA		0	320
#
# 6E	BOM	NAG		0	320
#
# 6E	CCU	AMD		0	320
#
# 6E	CCU	BLR		0	320
#
# 6E	CCU	BOM		0	320
#
# 6E	CCU	DEL		0	320
#
# 6E	CCU	GAU		0	320
#
# 6E	CCU	HYD		0	320
#
# 6E	CCU	IMF		0	320
#
# 6E	CCU	IXA		0	320
#
# 6E	CCU	JAI		0	320
#
# 6E	CCU	MAA		0	320
#
# 6E	CCU	NAG		0	320
#
# 6E	COK	HYD		0	320
#
# 6E	DEL	AMD		0	320
#
# 6E	DEL	BBI		0	320
#
# 6E	DEL	BDQ		0	320
#
# 6E	DEL	BLR		0	320
#
# 6E	DEL	BOM		0	320
#
# 6E	DEL	CCU		0	320
#
# 6E	DEL	GAU		0	320
#
# 6E	DEL	GOI		0	320
#
# 6E	DEL	HYD		0	320
#
# 6E	DEL	MAA		0	320
#
# 6E	DEL	NAG		0	320
#
# 6E	DEL	PNQ		0	320
#
# 6E	GAU	CCU		0	320
#
# 6E	GAU	DEL		0	320
#
# 6E	GAU	IMF		0	320
#
# 6E	GOI	BOM		0	320
#
# 6E	GOI	DEL		0	320
#
# 6E	HYD	BBI		0	320
#
# 6E	HYD	BLR		0	320
#
# 6E	HYD	BOM		0	320
#
# 6E	HYD	CCU		0	320
#
# 6E	HYD	COK		0	320
#
# 6E	HYD	DEL		0	320
#
# 6E	HYD	JAI		0	320
#
# 6E	HYD	MAA		0	320
#
# 6E	IMF	CCU		0	320
#
# 6E	IMF	GAU		0	320
#
# 6E	IMF	IXA		0	320
#
# 6E	IXA	CCU		0	320
#
# 6E	IXA	IMF		0	320
#
# 6E	JAI	AMD		0	320
#
# 6E	JAI	BOM		0	320
#
# 6E	JAI	CCU		0	320
#
# 6E	JAI	HYD		0	320
#
# 6E	MAA	BLR		0	320
#
# 6E	MAA	BOM		0	320
#
# 6E	MAA	CCU		0	320
#
# 6E	MAA	DEL		0	320
#
# 6E	MAA	HYD		0	320
#
# 6E	MAA	PNQ		0	320
#
# 6E	NAG	BOM		0	320
#
# 6E	NAG	CCU		0	320
#
# 6E	NAG	DEL		0	320
#
# 6E	NAG	PNQ		0	320
#
# 6E	PNQ	AMD		0	320
#
# 6E	PNQ	BLR		0	320
#
# 6E	PNQ	DEL		0	320
#
# 6E	PNQ	MAA		0	320
#
# 6E	PNQ	NAG		0	320
#
# 6J	BSA	GLK		0	IL8
#
# 6J	DXB	JIB		0	IL8
#
# 6J	GLK	JIB		0	IL8
#
# 6J	HGA	JIB		0	IL8
#
# 6J	JED	MGQ		0	IL8
#
# 6J	JIB	BSA		0	IL8
#
# 6J	JIB	DXB		0	IL8
#
# 6J	MGQ	HGA		0	IL8
#
# 6J	MGQ	JED		0	IL8
#
# 6L	LAK	YEV		0	DHT
#
# 6L	YEV	LAK		0	DHT
#
# 6L	YEV	YHI		0	DHT
#
# 6L	YEV	YPC		0	DHT
#
# 6L	YEV	YSY		0	DHT
#
# 6L	YEV	YUB		0	DHT
#
# 6L	YHI	YEV		0	DHT
#
# 6L	YPC	YEV		0	DHT
#
# 6L	YSY	YEV		0	DHT
#
# 6L	YUB	YEV		0	DHT
#
# 6M	GVR	PLU		0	EM2
#
# 6M	IPN	PLU		0	EM2
#
# 6M	PLU	GVR		0	EM2
#
# 6M	PLU	IPN		0	EM2
#
# 6M	PLU	UBA		0	EM2
#
# 6M	PLU	UDI		0	EM2
#
# 6M	UBA	PLU		0	EM2
#
# 6M	UBA	UDI		0	EM2
#
# 6M	UDI	PLU		0	EM2
#
# 6M	UDI	UBA		0	EM2
#
# 6T	AKY	RGN		0	ATR
#
# 6T	AKY	SNW		0	ATR
#
# 6T	HEH	MDL		0	ATR
#
# 6T	HEH	THL		0	ATR
#
# 6T	MDL	HEH		0	ATR
#
# 6T	MDL	RGN		0	ATR
#
# 6T	MGZ	RGN		0	ATR
#
# 6T	RGN	AKY		0	ATR
#
# 6T	RGN	MDL		0	ATR
#
# 6T	RGN	SNW		0	ATR
#
# 6T	RGN	TVY		0	ATR
#
# 6T	SNW	AKY		0	ATR
#
# 6T	SNW	RGN		0	ATR
#
# 6T	THL	HEH		0	ATR
#
# 6T	TVY	MGZ		0	ATR
#
# 6T	TVY	RGN		0	ATR
#
# 6T	TVY	RGN		1	ATR
#
# 6W	DME	LED		0	YK2
#
# 6W	DME	RTW		0	YK2
#
# 6W	EVN	RTW		0	YK2
#
# 6W	LED	DME		0	YK2
#
# 6W	RTW	DME		0	YK2
#
# 6W	RTW	EVN		0	YK2
#
# 7B	AER	KJA		0	TU5
#
# 7B	AER	OMS		0	TU5
#
# 7B	BHK	VKO		0	733
#
# 7B	BQS	KJA		0	TU5
#
# 7B	BRQ	VKO		0	733
#
# 7B	DYU	KJA		0	TU5
#
# 7B	DYU	KUF		0	TU5
#
# 7B	DYU	VKO		0	TU5
#
# 7B	FEG	VKO		0	733
#
# 7B	GYD	KUF		0	TU5
#
# 7B	GYD	VKO		0	733
#
# 7B	HTA	KJA		0	TU5
#
# 7B	IWA	VKO		0	EM2
#
# 7B	KJA	AER		0	TU5
#
# 7B	KJA	BQS		0	TU5
#
# 7B	KJA	DYU		0	TU5
#
# 7B	KJA	HTA		0	TU5
#
# 7B	KJA	KRR		0	TU5
#
# 7B	KJA	KUF		0	TU5
#
# 7B	KJA	LBD		0	TU5
#
# 7B	KJA	LED		0	TU5
#
# 7B	KJA	NSK		0	TU5
#
# 7B	KJA	TAS		0	TU5
#
# 7B	KJA	VKO		0	733 TU5
#
# 7B	KJA	VVO		0	TU5
#
# 7B	KJA	YKS		0	TU5
#
# 7B	KRR	KJA		0	TU5
#
# 7B	KUF	DYU		0	TU5
#
# 7B	KUF	GYD		0	TU5
#
# 7B	KUF	KJA		0	TU5
#
# 7B	KVD	VKO		0	TU5
#
# 7B	LBD	KJA		0	TU5
#
# 7B	LED	KJA		0	TU5
#
# 7B	LPX	VKO		0	EM2
#
# 7B	NSK	KJA		0	TU5
#
# 7B	OMS	AER		0	TU5
#
# 7B	PKV	VKO		0	EM2
#
# 7B	SKD	VKO		0	733
#
# 7B	SKG	VKO		0	733
#
# 7B	TAS	KJA		0	TU5
#
# 7B	TAS	VKO		0	733
#
# 7B	TIV	VKO		0	733
#
# 7B	VKO	BHK		0	733
#
# 7B	VKO	BRQ		0	733
#
# 7B	VKO	DYU		0	TU5
#
# 7B	VKO	FEG		0	733
#
# 7B	VKO	GYD		0	733
#
# 7B	VKO	IWA		0	EM2
#
# 7B	VKO	KJA		0	733 TU5
#
# 7B	VKO	KVD		0	TU5
#
# 7B	VKO	LPX		0	EM2
#
# 7B	VKO	PKV		0	EM2
#
# 7B	VKO	SKD		0	733
#
# 7B	VKO	SKG		0	733
#
# 7B	VKO	TAS		0	733
#
# 7B	VKO	TIV		0	733
#
# 7B	VVO	KJA		0	TU5
#
# 7B	YKS	KJA		0	TU5
#
# 7C	CJJ	CJU		0	DH4
#
# 7C	CJU	CJJ		0	DH4
#
# 7C	CJU	GMP		0	DH4 737
#
# 7C	CJU	PUS		0	DH4
#
# 7C	GMP	CJU		0	DH4 737
#
# 7C	ICN	KIX		0	738
#
# 7C	KIX	ICN		0	738
#
# 7C	PUS	CJU		0	DH4
#
# 7D	ATH	DOK		0	320
#
# 7D	DME	DOK		0	735
#
# 7D	DOK	ATH		0	320
#
# 7D	DOK	DME		0	735
#
# 7D	DOK	EVN		0	735
#
# 7D	DOK	GYD		0	735
#
# 7D	DOK	IST		0	320
#
# 7D	DOK	KBP		0	320 734
#
# 7D	DOK	LCA		0	320
#
# 7D	DOK	TBS		0	735
#
# 7D	EVN	DOK		0	735
#
# 7D	EVN	KBP		0	735
#
# 7D	GYD	DOK		0	735
#
# 7D	IST	DOK		0	320
#
# 7D	IST	ODS		0	734
#
# 7D	IST	SIP		0	320
#
# 7D	KBP	DOK		0	320 734 735
#
# 7D	KBP	EVN		0	735
#
# 7D	KBP	VNO		0	SF3
#
# 7D	LCA	DOK		0	320
#
# 7D	ODS	IST		0	734
#
# 7D	SIP	IST		0	320
#
# 7D	TBS	DOK		0	735
#
# 7D	VNO	KBP		0	SF3
#
# 7E	GWT	HAM		0	CNA
#
# 7E	HAM	GWT		0	CNA
#
# 7F	YBB	YHK		0	ATR
#
# 7F	YBB	YYH		0	ATR
#
# 7F	YBK	YRT		0	BET
#
# 7F	YCB	YCO		0	ATR
#
# 7F	YCB	YHK		0	ATR
#
# 7F	YCB	YRB		0	ATR
#
# 7F	YCB	YZF		0	ATR 73M
#
# 7F	YCO	YCB		0	ATR
#
# 7F	YCO	YHI		0	ATR
#
# 7F	YCO	YZF		0	ATR
#
# 7F	YCY	YFB		0	ATR
#
# 7F	YCY	YIO		0	ATR
#
# 7F	YEG	YZF		0	73M
#
# 7F	YEK	YRT		0	BET
#
# 7F	YEV	YZF		0	73M
#
# 7F	YFB	YCY		0	ATR
#
# 7F	YFB	YGT		0	ATR
#
# 7F	YFB	YIO		0	ATR
#
# 7F	YFB	YLC	*	0	DHT
#
# 7F	YFB	YOW		0	73M
#
# 7F	YFB	YRT		0	73M
#
# 7F	YFB	YSR		0	ATR
#
# 7F	YFB	YTE		0	ATR
#
# 7F	YFB	YUX		0	ATR
#
# 7F	YFB	YVP		0	73M
#
# 7F	YFB	YXP		0	HS7 ATR
#
# 7F	YFS	YXY		0	ATR
#
# 7F	YFS	YZF		0	ATR
#
# 7F	YGT	YFB		0	ATR
#
# 7F	YGT	YIO		0	ATR
#
# 7F	YGT	YUX		0	ATR
#
# 7F	YHI	YCO		0	ATR
#
# 7F	YHK	YBB		0	ATR
#
# 7F	YHK	YCB		0	ATR
#
# 7F	YHK	YYH		0	ATR
#
# 7F	YHK	YZF		0	ATR
#
# 7F	YHY	YZF		0	ATR
#
# 7F	YIO	YCY		0	ATR
#
# 7F	YIO	YFB		0	ATR
#
# 7F	YLC	YFB	*	0	DHT
#
# 7F	YOW	YFB		0	73M
#
# 7F	YRB	YCB		0	ATR
#
# 7F	YRB	YSR		0	ATR
#
# 7F	YRT	YBK		0	BET
#
# 7F	YRT	YEK		0	BET
#
# 7F	YRT	YFB		0	73M
#
# 7F	YRT	YWG		0	73M
#
# 7F	YRT	YZF		0	73M
#
# 7F	YSR	YFB		0	ATR
#
# 7F	YSR	YRB		0	ATR
#
# 7F	YTE	YFB		0	ATR
#
# 7F	YUL	YVP		0	73M
#
# 7F	YUX	YFB		0	ATR
#
# 7F	YUX	YGT		0	ATR
#
# 7F	YUX	YRB		0	ATR
#
# 7F	YVM	YXP		0	ATR
#
# 7F	YVP	YFB		0	73M
#
# 7F	YVP	YUL		0	73M
#
# 7F	YWG	YRT		0	73M
#
# 7F	YXP	YFB		0	HS7 ATR
#
# 7F	YXP	YVM		0	ATR
#
# 7F	YXY	YFS		0	ATR
#
# 7F	YYH	YBB		0	ATR
#
# 7F	YYH	YHK		0	ATR
#
# 7F	YYH	YZF		0	ATR
#
# 7F	YZF	YCB		0	ATR 73M
#
# 7F	YZF	YCO		0	ATR
#
# 7F	YZF	YEG		0	73M
#
# 7F	YZF	YEV		0	73M
#
# 7F	YZF	YFS		0	ATR
#
# 7F	YZF	YHK		0	ATR
#
# 7F	YZF	YHY		0	ATR
#
# 7F	YZF	YRT		0	73M
#
# 7F	YZF	YYH		0	ATR
#
# 7G	HND	KIX		0	320
#
# 7G	HND	KKJ		0	320
#
# 7G	KIX	HND		0	320
#
# 7G	KKJ	HND		0	320
#
# 7H	ADQ	ANC		0	DH8 BE1
#
# 7H	ANC	ADQ		0	DH8 BE1
#
# 7H	ANC	BET		0	BE1
#
# 7H	ANC	CDV		0	BE1
#
# 7H	ANC	ENA		0	BE1 DH8
#
# 7H	ANC	FAI		0	DH8 BE1
#
# 7H	ANC	HOM		0	BE1 DH8
#
# 7H	ANC	VDZ		0	DH8
#
# 7H	BET	ANC		0	BE1
#
# 7H	CDV	ANC		0	BE1
#
# 7H	ENA	ANC		0	BE1 DH8
#
# 7H	FAI	ANC		0	DH8 BE1
#
# 7H	HOM	ANC		0	BE1 DH8
#
# 7H	VDZ	ANC		0	DH8
#
# 7I	AUA	CUR		0	EMB
#
# 7I	BON	CUR		0	EMB
#
# 7I	CUR	AUA		0	EMB
#
# 7I	CUR	BON		0	EMB
#
# 7I	CUR	LSP		0	EMB
#
# 7I	CUR	MIA		0	M83
#
# 7I	CUR	PBM		0	M83
#
# 7I	CUR	SXM		0	M83
#
# 7I	CUR	VLN		0	M83
#
# 7I	LSP	CUR		0	EMB
#
# 7I	MIA	CUR		0	M83
#
# 7I	PAP	SXM		0	M83
#
# 7I	PBM	CUR		0	M83
#
# 7I	SDQ	SXM		0	M83
#
# 7I	SXM	CUR		0	M83
#
# 7I	SXM	PAP		0	M83
#
# 7I	SXM	SDQ		0	M83
#
# 7I	VLN	CUR		0	M83
#
# 7J	ALA	DYU		0	AN4
#
# 7J	DME	DYU		0	752 738
#
# 7J	DME	LBD		0	733
#
# 7J	DYU	ALA		0	AN4
#
# 7J	DYU	DME		0	752 738
#
# 7J	DYU	FRU		0	AN4
#
# 7J	DYU	IKA		0	738
#
# 7J	DYU	IST		0	738
#
# 7J	DYU	KUF		0	738
#
# 7J	DYU	LED		0	738
#
# 7J	DYU	OVB		0	TU5
#
# 7J	DYU	SHJ		0	TU5
#
# 7J	DYU	SVX		0	738
#
# 7J	FRU	DYU		0	AN4
#
# 7J	IKA	DYU		0	738
#
# 7J	IST	DYU		0	738
#
# 7J	KUF	DYU		0	738
#
# 7J	LBD	DME		0	733
#
# 7J	LBD	LED		0	TU5
#
# 7J	LBD	SVX		0	733
#
# 7J	LED	DYU		0	738
#
# 7J	LED	LBD		0	TU5
#
# 7J	OVB	DYU		0	TU5
#
# 7J	SHJ	DYU		0	TU5
#
# 7J	SVX	DYU		0	738
#
# 7J	SVX	LBD		0	733
#
# 7K	AAQ	SGC		0	TU5
#
# 7K	DME	KGP		0	TU3
#
# 7K	DME	SGC		0	TU5
#
# 7K	GYD	SGC		0	TU5
#
# 7K	KGP	DME		0	TU3
#
# 7K	KGP	UFA		0	TU5
#
# 7K	KRR	SGC		0	TU5
#
# 7K	MRV	SGC		0	TU5
#
# 7K	SGC	AAQ		0	TU5
#
# 7K	SGC	DME		0	TU5
#
# 7K	SGC	GYD		0	TU5
#
# 7K	SGC	KRR		0	TU5
#
# 7K	SGC	MRV		0	TU5
#
# 7K	SGC	SIP		0	TU5
#
# 7K	SIP	SGC		0	TU5
#
# 7K	UFA	KGP		0	TU5
#
# 7M	CUN	CZM		0	CN2
#
# 7M	CZM	CUN		0	CN2
#
# 7T	ARV	EGV		0	PA2
#
# 7T	ARV	PWK		0	PA2
#
# 7T	EGV	ARV		0	PA2
#
# 7T	EGV	PWK		0	PA2
#
# 7T	PWK	ARV		0	PA2
#
# 7T	PWK	EGV		0	PA2
#
# 7V	JNB	VNX		0	ATR
#
# 7V	MQP	VNX		0	ATR
#
# 7V	VNX	JNB		0	ATR
#
# 7W	ASB	KBP		0	738
#
# 7W	DME	KBP		0	E95
#
# 7W	KBP	ASB		0	738
#
# 7W	KBP	DME		0	E95
#
# 7W	KBP	TAS		0	738
#
# 7W	KBP	TSE		0	738
#
# 7W	TAS	KBP		0	738
#
# 7W	TSE	KBP		0	738
#
# 7Y	BEY	BGW		0	732
#
# 7Y	BEY	EBL		0	732
#
# 7Y	BEY	ISU		0	732
#
# 7Y	BGW	BEY		0	732
#
# 7Y	EBL	BEY		0	732
#
# 7Y	ISU	BEY		0	732
#
# 8A	AMS	NDR		0	734
#
# 8A	AMS	TNG		0	734
#
# 8A	BCN	RAK		0	734
#
# 8A	BCN	TNG		0	734
#
# 8A	BOD	RAK		0	734
#
# 8A	BRU	NDR		0	734
#
# 8A	BRU	OUD		0	734
#
# 8A	BRU	RAK		0	734
#
# 8A	BRU	TNG		0	734
# 8A	DUS	NDR		0	734
#
# 8A	FEZ	LGW		0	738
#
# 8A	FEZ	LYS		0	734
#
# 8A	FEZ	MRS		0	738
#
# 8A	FRA	NDR		0	734
#
# 8A	GVA	RAK		0	734
#
# 8A	LGW	FEZ		0	738
#
# 8A	LGW	RAK		0	738
#
# 8A	LYS	FEZ		0	734
#
# 8A	LYS	RAK		0	734
#
# 8A	MAD	RAK		0	734
#
# 8A	MRS	FEZ		0	738
#
# 8A	MRS	OUD		0	738
#
# 8A	MRS	RAK		0	738 734
#
# 8A	MXP	RAK		0	734
#
# 8A	NCE	RAK		0	734
#
# 8A	NDR	AMS		0	734
#
# 8A	NDR	BRU		0	734
#
# 8A	NDR	DUS		0	734
#
# 8A	NDR	FRA		0	734
#
# 8A	NTE	RAK		0	734
#
# 8A	ORY	OUD		0	734
#
# 8A	ORY	RAK		0	734
#
# 8A	ORY	TNG		0	734
#
# 8A	OUD	BRU		0	734
#
# 8A	OUD	MRS		0	738
#
# 8A	OUD	ORY		0	734
#
# 8A	RAK	BCN		0	734
#
# 8A	RAK	BOD		0	734
#
# 8A	RAK	BRU		0	734
#
# 8A	RAK	GVA		0	734
#
# 8A	RAK	LGW		0	738
#
# 8A	RAK	LYS		0	734
#
# 8A	RAK	MAD		0	734
#
# 8A	RAK	MRS		0	738
#
# 8A	RAK	MXP		0	734
#
# 8A	RAK	NCE		0	734
#
# 8A	RAK	NTE		0	734
#
# 8A	RAK	ORY		0	734
#
# 8A	RAK	TLS		0	734
#
# 8A	TLS	RAK		0	734
#
# 8A	TNG	AMS		0	734
#
# 8A	TNG	BCN		0	734
#
# 8A	TNG	BRU		0	734
#
# 8A	TNG	ORY		0	734
#
# 8D	ADQ	AKK		0	CNA
#
# 8D	ADQ	KOZ		0	CNA
#
# 8D	KOZ	ORI		0	CNA
#
# 8D	ORI	ADQ		0	CNA
#
# 8E	ABL	OTZ		0	CNA
#
# 8E	ABL	SHG		0	CNA
#
# 8E	BKC	DRG		0	CNA
#
# 8E	BKC	OTZ		0	CNA
#
# 8E	DRG	BKC		0	CNA
#
# 8E	DRG	OTZ		0	CNA
#
# 8E	ELI	GLV		0	CNA
#
# 8E	ELI	KKA		0	CNA
#
# 8E	ELI	OME		0	CNA
#
# 8E	GAM	OME		0	BE1
#
# 8E	GAM	SVA		0	BE1
#
# 8E	GLV	ELI		0	CNA
#
# 8E	GLV	WMO		0	CNA
#
# 8E	IAN	ORV		0	CNA
#
# 8E	IAN	OTZ		0	CNA
#
# 8E	KKA	OME		0	CNA
#
# 8E	KKA	SKK		0	CNA
#
# 8E	KPC	OME		0	CNA
#
# 8E	KTS	OME		0	CNA
#
# 8E	KTS	WAA		0	CNA
#
# 8E	KVL	OTZ		0	CNA
#
# 8E	KVL	PHO		0	CNA
#
# 8E	LUR	OTZ		0	CNA
#
# 8E	OBU	ABL		0	CNA
#
# 8E	OBU	OTZ		0	CNA
#
# 8E	OME	ELI		0	CNA
#
# 8E	OME	GAM		0	BE1
#
# 8E	OME	KKA		0	CNA
#
# 8E	OME	OTZ		0	BEC
#
# 8E	OME	SHH		0	CNA
#
# 8E	OME	SVA		0	BE1
#
# 8E	OME	TLA		0	CNA
#
# 8E	OME	UNK		0	PAG
#
# 8E	OME	WAA		0	CNA
#
# 8E	OME	WBB		0	PAG
#
# 8E	OME	WMO		0	CNA
#
# 8E	ORV	IAN		0	CNA
#
# 8E	ORV	OTZ		0	CNA
#
# 8E	OTZ	ABL		0	CNA
#
# 8E	OTZ	BKC		0	CNA
#
# 8E	OTZ	DRG		0	CNA
#
# 8E	OTZ	IAN		0	CNA
#
# 8E	OTZ	KVL		0	CNA
#
# 8E	OTZ	OME		0	BEC
#
# 8E	OTZ	ORV		0	CNA
#
# 8E	OTZ	PHO		0	CNA
#
# 8E	OTZ	SHG		0	CNA
#
# 8E	OTZ	WLK		0	CNA
#
# 8E	OTZ	WTK		0	CNA
#
# 8E	PHO	LUR		0	CNA
#
# 8E	PHO	OTZ		0	CNA
#
# 8E	SHG	OBU		0	CNA
#
# 8E	SHH	OME		0	CNA
#
# 8E	SKK	KKA		0	CNA
#
# 8E	SKK	UNK		0	CNA
#
# 8E	SMK	UNK		0	PAG
#
# 8E	SMK	WBB		0	CNA PAG
#
# 8E	SVA	GAM		0	BE1
#
# 8E	SVA	OME		0	BE1
#
# 8E	TLA	KTS		0	CNA
#
# 8E	TNC	KPC		0	CNA
#
# 8E	UNK	OME		0	PAG
#
# 8E	UNK	SKK		0	CNA
#
# 8E	UNK	SMK		0	CNA PAG
#
# 8E	WAA	OME		0	CNA
#
# 8E	WAA	SHH		0	CNA
#
# 8E	WAA	TNC		0	CNA
#
# 8E	WBB	OME		0	PAG
#
# 8E	WBB	SMK		0	PAG
#
# 8E	WBB	UNK		0	CNA
#
# 8E	WLK	OTZ		0	CNA
#
# 8E	WMO	GLV		0	CNA
#
# 8E	WMO	OME		0	CNA
#
# 8E	WTK	KVL		0	CNA
#
# 8E	WTK	OTZ		0	CNA
#
# 8H	BEB	SYY		0	J31
#
# 8H	COL	OBN		0	BNI
#
# 8H	COL	TRE		0	BNI
#
# 8H	CSA	OBN		0	BNI
#
# 8H	CWL	VLY		0	J31
#
# 8H	INV	SYY		0	J31
#
# 8H	OBN	COL		0	BNI
#
# 8H	OBN	CSA		0	BNI
#
# 8H	OBN	TRE		0	BNI
#
# 8H	SYY	BEB		0	J31
#
# 8H	SYY	INV		0	J31
#
# 8H	TRE	COL		0	BNI
#
# 8H	TRE	OBN		0	BNI
#
# 8H	VLY	CWL		0	J31
#
# 8I	AMS	BRI		0	CRJ
#
# 8I	AMS	RMI		0	320
#
# 8I	ATH	BRI		0	CRJ
#
# 8I	BBU	BGY		0	320
#
# 8I	BBU	BRI		0	CRJ
#
# 8I	BBU	CTA		0	320
#
# 8I	BBU	NAP		0	320
#
# 8I	BBU	RMI		0	320
#
# 8I	BBU	VCE		0	320
#
# 8I	BCN	BRI		0	CRJ
#
# 8I	BCN	VCE		0	CRJ
#
# 8I	BDS	CDG		0	CRJ
#
# 8I	BDS	GVA		0	CRJ
#
# 8I	BDS	MUC		0	CRJ
#
# 8I	BDS	VCE		0	CRJ
#
# 8I	BDS	VIE		0	CRJ
#
# 8I	BGY	BBU		0	320
#
# 8I	BGY	BRI		0	M80
#
# 8I	BGY	CTA		0	733
#
# 8I	BGY	NAP		0	M80
#
# 8I	BGY	PMO		0	733
#
# 8I	BGY	REG		0	M80
#
# 8I	BRI	AMS		0	CRJ
#
# 8I	BRI	ATH		0	CRJ
#
# 8I	BRI	BBU		0	CRJ
#
# 8I	BRI	BCN		0	CRJ
#
# 8I	BRI	BGY		0	M80
#
# 8I	BRI	BRU		0	CRJ
#
# 8I	BRI	CDG		0	CRJ
#
# 8I	BRI	CTA		0	CRJ
#
# 8I	BRI	GOA		0	CRJ
#
# 8I	BRI	MAD		0	CRJ
#
# 8I	BRI	SAW		0	M80
#
# 8I	BRI	VCE		0	CRJ
#
# 8I	BRU	BRI		0	CRJ
#
# 8I	CAG	VCE		0	M80
#
# 8I	CDG	BDS		0	CRJ
#
# 8I	CDG	RMI		0	320
#
# 8I	CTA	BBU		0	320
#
# 8I	CTA	BGY		0	733
#
# 8I	CTA	BRI		0	CRJ
#
# 8I	CTA	VCE		0	M80
#
# 8I	FOG	GVA		0	S20
#
# 8I	FOG	MXP		0	S20
#
# 8I	FOG	PMO		0	S20
#
# 8I	FOG	TRN		0	S20
#
# 8I	GOA	BRI		0	CRJ
#
# 8I	GVA	BDS		0	CRJ
#
# 8I	GVA	FOG		0	S20
#
# 8I	MAD	BRI		0	CRJ
#
# 8I	MUC	BDS		0	CRJ
#
# 8I	MXP	FOG		0	S20
#
# 8I	NAP	BBU		0	320
#
# 8I	NAP	BGY		0	M80
#
# 8I	OLB	VCE		0	CRJ
#
# 8I	ORY	VCE		0	CRJ
#
# 8I	PMO	BGY		0	733
#
# 8I	PMO	FOG		0	S20
#
# 8I	PMO	VCE		0	M80
#
# 8I	REG	BGY		0	M80
#
# 8I	RMI	AMS		0	320
#
# 8I	RMI	BBU		0	320
#
# 8I	RMI	CDG		0	320
#
# 8I	SAW	BRI		0	M80
#
# 8I	SOF	VCE		0	CRJ
#
# 8I	TRN	FOG		0	S20
#
# 8I	VCE	BBU		0	320
#
# 8I	VCE	BCN		0	CRJ
#
# 8I	VCE	BDS		0	CRJ
#
# 8I	VCE	BRI		0	CRJ
#
# 8I	VCE	CAG		0	M80
#
# 8I	VCE	CTA		0	M80
#
# 8I	VCE	OLB		0	CRJ
#
# 8I	VCE	ORY		0	CRJ
#
# 8I	VCE	PMO		0	M80
#
# 8I	VCE	SOF		0	CRJ
#
# 8I	VIE	BDS		0	CRJ
#
# 8J	AGA	ORY		0	737
#
# 8J	BLQ	CMN		0	737
#
# 8J	CDG	RAK		0	737
#
# 8J	CMN	BLQ		0	737
#
# 8J	CMN	CRL		0	737
#
# 8J	CMN	GVA		0	737
#
# 8J	CMN	LYS		0	737
#
# 8J	CMN	MRS		0	737
#
# 8J	CMN	MXP		0	737
#
# 8J	CMN	ORY		0	737
#
# 8J	CMN	TLS		0	737
#
# 8J	CRL	CMN		0	737
#
# 8J	FEZ	ORY		0	737
#
# 8J	GVA	CMN		0	737
#
# 8J	LYS	CMN		0	737
#
# 8J	MRS	CMN		0	737
#
# 8J	MXP	CMN		0	737
#
# 8J	ORY	AGA		0	737
#
# 8J	ORY	CMN		0	737
#
# 8J	ORY	FEZ		0	737
#
# 8J	ORY	OUD		0	737
#
# 8J	ORY	RAK		0	737
#
# 8J	ORY	RBA		0	737
#
# 8J	OUD	ORY		0	737
#
# 8J	RAK	CDG		0	737
#
# 8J	RAK	ORY		0	737
#
# 8J	RBA	ORY		0	737
#
# 8J	TLS	CMN		0	737
#
# 8L	BSD	KMG		0	737
#
# 8L	CKG	KMG		0	737
#
# 8L	CTU	KMG		0	737
#
# 8L	CTU	TSN		0	737
#
# 8L	DLC	WUH		0	319
#
# 8L	DLU	JHG		0	737
#
# 8L	DLU	KMG		0	737
#
# 8L	HFE	KMG		0	737
#
# 8L	JHG	DLU		0	737
#
# 8L	JHG	KMG		0	737
#
# 8L	JHG	LJG		0	737
#
# 8L	KMG	BSD		0	737
#
# 8L	KMG	CKG		0	737
#
# 8L	KMG	CTU		0	737
#
# 8L	KMG	DLU		0	737
#
# 8L	KMG	HFE		0	737
#
# 8L	KMG	JHG		0	737
#
# 8L	KMG	LJG		0	737
#
# 8L	KMG	LUM		0	737
#
# 8L	KMG	NGB		0	319
#
# 8L	KMG	NKG		0	737
#
# 8L	KMG	SYM		0	737
#
# 8L	KMG	SYX		0	737
#
# 8L	KMG	TNA		0	737
#
# 8L	KMG	TYN		0	319 737
#
# 8L	KMG	WNZ		0	737
#
# 8L	KMG	WUH		0	737 319
#
# 8L	KMG	XIY		0	737
#
# 8L	LJG	JHG		0	737
#
# 8L	LJG	KMG		0	737
#
# 8L	LUM	KMG		0	737
#
# 8L	NGB	KMG		0	319
#
# 8L	NKG	KMG		0	737
#
# 8L	NKG	WUH		0	737
#
# 8L	SHE	TNA		0	737
#
# 8L	SYM	KMG		0	737
#
# 8L	SYX	KMG		0	737
#
# 8L	TAO	WUH		0	737
#
# 8L	TNA	KMG		0	737
#
# 8L	TNA	SHE		0	737
#
# 8L	TSN	CTU		0	737
#
# 8L	TYN	KMG		0	319 737
#
# 8L	WNZ	KMG		0	737
#
# 8L	WUH	DLC		0	319
#
# 8L	WUH	KMG		0	737 319
#
# 8L	WUH	NKG		0	737
#
# 8L	WUH	TAO		0	737
#
# 8L	XIY	KMG		0	737
#
# 8M	BKK	RGN		0	320
#
# 8M	BKK	RGN	*	0	AB6
#
# 8M	KUL	RGN		0	320
#
# 8M	KUL	RGN	*	0	320
#
# 8M	RGN	BKK		0	320
#
# 8M	RGN	BKK	*	0	AB6 320
#
# 8M	RGN	KUL		0	320
#
# 8M	RGN	KUL	*	0	320
#
# 8M	RGN	SIN	*	0	320
#
# 8M	SIN	RGN	*	0	320
#
# 8N	LLA	PJA		0	BE2
#
# 8N	PJA	LLA		0	BE2
#
# 8O	CXH	YQQ		0	DHP
#
# 8O	CXH	YWH		0	DHP
#
# 8O	YHS	YVR		0	DHP
#
# 8O	YQQ	CXH		0	DHP
#
# 8O	YVR	YHS		0	DHP
#
# 8O	YWH	CXH		0	DHP
#
# 8O	YWH	YWS		0	DHP
#
# 8O	YWS	YWH		0	DHP
#
# 8P	QBC	YAA		0	BE1
#
# 8P	QBC	YVR		0	BE1
#
# ...
#
# YX	MKE	TPA	*	0	E70
#
# YX	MKE	YYZ	*	0	CRJ
#
# YX	MSN	MKE	*	0	CRJ
#
# YX	MSP	MKE	*	0	E70 CRJ
#
# YX	OMA	DCA	*	0	E70
#
# YX	OMA	MKE	*	0	E70 CRJ
#
# YX	PHL	MKE	*	0	CRJ
#
# YX	PHX	MKE		0	717
#
# YX	PIT	MKE	*	0	E70 CRJ
#
# YX	RDU	IND	*	0	CRJ
#
# YX	SEA	MCI		0	717
#
# YX	SFO	MCI		0	717
#
# YX	TPA	MKE	*	0	E70
#
# YX	YYZ	MKE	*	0	CRJ
#
# Z2	BCD	MNL		0	320
#
# Z2	CEB	MNL		0	320
#
# Z2	CRM	MNL		0	YN7
#
# Z2	CYP	MNL		0	YN7
#
# Z2	DVO	MNL		0	320
#
# Z2	ILO	MNL		0	320
#
# Z2	KLO	MNL		0	320
#
# Z2	LGP	MNL		0	YN7
#
# Z2	MNL	BCD		0	320
#
# Z2	MNL	CEB		0	320
#
# Z2	MNL	CRM		0	YN7
#
# Z2	MNL	CYP		0	YN7
#
# Z2	MNL	DVO		0	320
#
# Z2	MNL	ILO		0	320
#
# Z2	MNL	KLO		0	320
#
# Z2	MNL	LGP		0	YN7
#
# Z2	MNL	MPH		0	YN7
#
# Z2	MNL	MRQ		0	YN7
#
# Z2	MNL	PPS		0	YN7
#
# Z2	MNL	SJI		0	YN7
#
# Z2	MNL	TAC		0	320
#
# Z2	MNL	TAG		0	320
#
# Z2	MNL	USU		0	YN7
#
# Z2	MNL	VRC		0	YN7
#
# Z2	MNL	WNP		0	YN7
#
# Z2	MPH	MNL		0	YN7
#
# Z2	MRQ	MNL		0	YN7
#
# Z2	PPS	MNL		0	YN7
#
# Z2	SJI	MNL		0	YN7
#
# Z2	TAC	MNL		0	320
#
# Z2	TAG	MNL		0	320
#
# Z2	USU	MNL		0	YN7
#
# Z2	VRC	MNL		0	YN7
#
# Z2	WNP	MNL		0	YN7
#
# Z3	CGA	KTN		0	DHP
#
# Z3	HYL	KTB		0	DHP
#
# Z3	HYL	KTN		0	DHP
#
# Z3	KTB	HYL		0	DHP
#
# Z3	KTB	KTN		0	DHP
#
# Z3	KTN	CGA		0	DHP
#
# Z3	KTN	HYL		0	DHP
#
# Z3	KTN	KTB		0	DHP
#
# Z3	KTN	MTM		0	DHP
#
# Z3	MTM	KTN		0	DHP
#
# Z5	BKK	DAC		0	M80
#
# Z5	BKK	SIN		0	M80
#
# Z5	CCU	CGP		0	DH8
#
# Z5	CCU	DAC		0	DH8
#
# Z5	CGP	CCU		0	DH8
#
# Z5	CGP	CXB		0	DH8
#
# Z5	CGP	DAC		0	DH8
#
# Z5	CXB	CGP		0	DH8
#
# Z5	DAC	BKK		0	M80
#
# Z5	DAC	CCU		0	DH8
#
# Z5	DAC	CGP		0	DH8
#
# Z5	DAC	DEL		0	M80
#
# Z5	DAC	JSR		0	DH8
#
# Z5	DAC	KTM		0	M82
#
# Z5	DAC	KUL		0	M80
#
# Z5	DAC	ZYL		0	DH8
#
# Z5	DEL	DAC		0	M80
#
# Z5	DEL	DXB		0	M80
#
# Z5	DXB	DEL		0	M80
#
# Z5	JSR	DAC		0	DH8
#
# Z5	KTM	DAC		0	M82
#
# Z5	KUL	DAC		0	M80
#
# Z5	SIN	BKK		0	M80
#
# Z5	ZYL	DAC		0	DH8
#
# Z6	DME	DNK		0	ER4
#
# Z6	DME	IFO		0	ER4
#
# Z6	DME	SIP		0	737
#
# Z6	DNK	DME		0	ER4
#
# Z6	DNK	EVN		0	ER4
#
# Z6	DNK	IST		0	ER4
#
# Z6	DNK	KBP		0	ER4
#
# Z6	DNK	TBS		0	ER4
#
# Z6	DNK	VIE		0	ER4
#
# Z6	EVN	DNK		0	ER4
#
# Z6	HRK	KBP		0	ER4
#
# Z6	IFO	DME		0	ER4
#
# Z6	IFO	KBP		0	ER4
#
# Z6	IST	DNK		0	ER4
#
# Z6	KBP	DNK		0	ER4
#
# Z6	KBP	HRK		0	ER4
#
# Z6	KBP	IFO		0	ER4
#
# Z6	KBP	LWO		0	737
#
# Z6	KBP	ODS		0	ER4
#
# Z6	KBP	SIP		0	ER4 737
#
# Z6	KBP	UDJ		0	ER4
#
# Z6	KBP	VSG		0	ER4
#
# Z6	LWO	KBP		0	737
#
# Z6	ODS	KBP		0	ER4
#
# Z6	SIP	DME		0	737
#
# Z6	SIP	KBP		0	ER4 737
#
# Z6	TBS	DNK		0	ER4
#
# Z6	UDJ	KBP		0	ER4
#
# Z6	VIE	DNK		0	ER4
#
# Z6	VSG	KBP		0	ER4
#
# Z8	CBB	TDD	*	0	SWM
#
# Z8	CIJ	TDD		0	SWM
#
# Z8	GYA	TDD		0	SWM
#
# Z8	GYA	TDD	*	0	SWM
#
# Z8	LPB	RBQ		0	SWM
#
# Z8	LPB	TDD		0	SWM
#
# Z8	LPB	TDD	*	0	SWM
#
# Z8	RBQ	LPB		0	SWM
# Z8	RIB	TDD	*	0	SWM
#
# Z8	SRJ	TDD		0	SWM
#
# Z8	SRZ	TDD		0	SWM
#
# Z8	SRZ	TDD	*	0	SWM
#
# Z8	TDD	CBB	*	0	SWM
#
# Z8	TDD	CIJ		0	SWM
#
# Z8	TDD	GYA		0	SWM
#
# Z8	TDD	GYA	*	0	SWM
#
# Z8	TDD	LPB		0	SWM
#
# Z8	TDD	RIB		0	SWM
#
# Z8	TDD	RIB	*	0	SWM
#
# Z8	TDD	SRJ		0	SWM
#
# Z8	TDD	SRZ		0	SWM
#
# Z8	TDD	SRZ	*	0	SWM
#
# Z8	TDD	VVI	*	0	SWM
#
# Z8	TJA	SRZ	*	0	SWM
#
# Z8	VVI	TJA	*	0	SWM
#
# ZB	ACE	BHX		0	321
#
# ZB	ACE	LGW		0	321 AB6
#
# ZB	ACE	LTN		0	320
#
# ZB	ACE	MAN		0	763 321
#
# ZB	AGP	BHX		0	321
#
# ZB	AGP	LGW		0	321
#
# ZB	AGP	LTN		0	321
#
# ZB	AGP	MAN		0	321
#
# ZB	ALC	BHX		0	321
#
# ZB	ALC	LGW		0	321
#
# ZB	ALC	LTN		0	321 320
#
# ZB	ALC	MAN		0	320 321
#
# ZB	BCN	MAN		0	321
#
# ZB	BHX	ACE		0	321
#
# ZB	BHX	AGP		0	321
#
# ZB	BHX	ALC		0	321
#
# ZB	BHX	FAO		0	321
#
# ZB	BHX	IBZ		0	321
#
# ZB	BHX	LCA		0	321
#
# ZB	BHX	LEI		0	321
#
# ZB	BHX	MAH		0	321
#
# ZB	BHX	MJV		0	321
#
# ZB	BHX	PMI		0	321
#
# ZB	BHX	TFS		0	321
#
# ZB	FAO	BHX		0	321
#
# ZB	FAO	LGW		0	321
#
# ZB	FAO	LTN		0	321
#
# ZB	FAO	MAN		0	321
#
# ZB	GIB	LTN		0	320
#
# ZB	GIB	MAN		0	320
#
# ZB	IBZ	BHX		0	321
#
# ZB	IBZ	LGW		0	321
#
# ZB	IBZ	MAN		0	321 320
#
# ZB	LCA	BHX		0	321
#
# ZB	LCA	LGW		0	321 757
#
# ZB	LCA	LTN		0	320 321
#
# ZB	LCA	MAN		0	332 321
#
# ZB	LEI	BHX		0	321
#
# ZB	LEI	MAN		0	320
#
# ZB	LGW	ACE		0	321 AB6
#
# ZB	LGW	AGP		0	321
#
# ZB	LGW	ALC		0	321
#
# ZB	LGW	FAO		0	321
#
# ZB	LGW	IBZ		0	321
#
# ZB	LGW	LCA		0	757 321
#
# ZB	LGW	MAH		0	757 320
#
# ZB	LGW	MJV		0	321
#
# ZB	LGW	TFS		0	321
#
# ZB	LTN	ACE		0	320
#
# ZB	LTN	AGP		0	321
#
# ZB	LTN	ALC		0	321 320
#
# ZB	LTN	FAO		0	321
#
# ZB	LTN	GIB		0	320
#
# ZB	LTN	LCA		0	320 321
#
# ZB	LTN	MAH		0	320 321
#
# ZB	LTN	PMI		0	AB6 320
#
# ZB	LTN	TFS		0	321 320
#
# ZB	MAH	BHX		0	321
#
# ZB	MAH	LGW		0	757 320
#
# ZB	MAH	LTN		0	320 321
#
# ZB	MAH	MAN		0	321 320
#
# ZB	MAN	ACE		0	763 321
#
# ZB	MAN	AGP		0	321
#
# ZB	MAN	ALC		0	320 321
#
# ZB	MAN	BCN		0	321
#
# ZB	MAN	FAO		0	321
#
# ZB	MAN	GIB		0	320
#
# ZB	MAN	IBZ		0	321 320
#
# ZB	MAN	LCA		0	332 321
#
# ZB	MAN	LEI		0	320
#
# ZB	MAN	MAH		0	321 320
#
# ZB	MAN	MJV		0	320
#
# ZB	MAN	PMI		0	321 320 AB6
#
# ZB	MAN	TFS		0	320 321
#
# ZB	MJV	BHX		0	321
#
# ZB	MJV	LGW		0	321
#
# ZB	MJV	MAN		0	320
#
# ZB	PMI	BHX		0	321
#
# ZB	PMI	LTN		0	AB6 320
#
# ZB	PMI	MAN		0	321 320 AB6
#
# ZB	TFS	BHX		0	321
#
# ZB	TFS	LGW		0	321
#
# ZB	TFS	LTN		0	321 320
#
# ZB	TFS	MAN		0	320 321
#
# ZF	ATH	AXD		0	ER4
#
# ZF	ATH	CHQ		0	ER4
#
# ZF	ATH	HER		0	ER4
#
# ZF	ATH	JMK		0	ER4
#
# ZF	ATH	JTR		0	ER4
#
# ZF	ATH	KVA		0	ER4
#
# ZF	ATH	MJT		0	ER4
#
# ZF	ATH	SKG		0	ER4
#
# ZF	AXD	ATH		0	ER4
#
# ZF	CHQ	ATH		0	ER4
#
# ZF	HER	ATH		0	ER4
#
# ZF	JMK	ATH		0	ER4
#
# ZF	JTR	ATH		0	ER4
#
# ZF	KVA	ATH		0	ER4
#
# ZF	MJT	ATH		0	ER4
#
# ZF	SKG	ATH		0	ER4
#
# ZG	CGK	MFM		0	767
#
# ZG	MFM	CGK		0	767
#
# ZG	MFM	SGN		0	767
#
# ZG	MFM	SYD		0	767
#
# ZG	SGN	MFM		0	767
#
# ZG	SYD	MFM		0	767
#
# ZH	AEB	CAN		0	E90
#
# ZH	AEB	KWL		0	E90
#
# ZH	BAV	HET		0	733
#
# ZH	BHY	KWL		0	E90
#
# ZH	BKK	SZX		0	320
#
# ZH	CAN	AEB		0	E90
#
# ZH	CAN	BAV		0	733
#
# ZH	CAN	CGO		0	320 733
#
# ZH	CAN	CSX		0	733
#
# ZH	CAN	CZX		0	733
#
# ZH	CAN	DPS		0	738
#
# ZH	CAN	KHN		0	733
#
# ZH	CAN	KMG		0	320
#
# ZH	CAN	KWL		0	320
#
# ZH	CAN	NKG		0	733
#
# ZH	CAN	SHA		0	320
#
# ZH	CAN	TNA		0	738
#
# ZH	CAN	WUH		0	733
#
# ZH	CAN	WUX		0	733 320
#
# ZH	CAN	XIY		0	733
#
# ZH	CGD	SZX		0	319
#
# ZH	CGK	NNG		0	738
#
# ZH	CGO	CAN		0	320 733
#
# ZH	CGO	DLC		0	733
#
# ZH	CGO	HGH		0	738
#
# ZH	CGO	NNG		0	733
#
# ZH	CGO	PEK		0	738
#
# ZH	CGO	SHE		0	320
#
# ZH	CGO	SZX		0	738
#
# ZH	CGO	TSN		0	E90
#
# ZH	CGO	URC		0	738
#
# ZH	CGQ	DLC		0	73G
#
# ZH	CGQ	NKG		0	739
#
# ZH	CGQ	TSN		0	73G
#
# ZH	CGQ	WUH		0	733
#
# ZH	CKG	SZX		0	738 739
#
# ZH	CSX	CAN		0	733
#
# ZH	CSX	HRB		0	73G
#
# ZH	CSX	KMG		0	73G
#
# ZH	CSX	LHW		0	319
#
# ZH	CSX	SZX		0	319
#
# ZH	CSX	XNN		0	733
#
# ZH	CTU	NNG		0	738
#
# ZH	CTU	SZX		0	320 738
#
# ZH	CTU	WUX		0	738
#
# ZH	CZX	CAN		0	733
#
# ZH	CZX	HRB		0	733
#
# ZH	CZX	SHE		0	73G
#
# ZH	CZX	SZX		0	738
#
# ZH	CZX	XMN		0	738
#
# ZH	DLC	CGO		0	733
#
# ZH	DLC	CGQ		0	73G
#
# ZH	DLC	SZX		0	73G
#
# ZH	DLC	WUX		0	320
#
# ZH	DPS	CAN		0	738
#
# ZH	ENY	XIY		0	733
#
# ZH	FOC	KIX		0	320
#
# ZH	FOC	SZX		0	320
#
# ZH	FOC	TNA		0	320
#
# ZH	HET	CAN		0	733
#
# ZH	HET	WUH		0	320
#
# ZH	HFE	HRB		0	73G
#
# ZH	HFE	KMG		0	73G
#
# ZH	HFE	SZX		0	320
#
# ZH	HGH	CGO		0	738
#
# ZH	HGH	NNG		0	73G
#
# ZH	HGH	SHE		0	73G
#
# ZH	HGH	SZX		0	73G
#
# ZH	HRB	CSX		0	73G
#
# ZH	HRB	CZX		0	733
#
# ZH	HRB	HFE		0	73G
#
# ZH	HRB	JMU		0	E90
#
# ZH	HRB	MDG		0	E90
#
# ZH	HRB	NKG		0	738
#
# ZH	HRB	SHE		0	738
#
# ZH	HRB	SZX		0	738
#
# ZH	HRB	TNA		0	320
#
# ZH	HRB	TSN		0	E90
#
# ZH	ICN	SZX		0	738
#
# ZH	ICN	SZX	*	0	767
#
# ZH	INC	XIY		0	320
#
# ZH	JDZ	SHA		0	738
#
# ZH	JDZ	SZX		0	738
#
# ZH	JMU	HRB		0	E90
#
# ZH	JUZ	SZX		0	319
#
# ZH	KHN	CAN		0	733
#
# ZH	KIX	FOC		0	320
#
# ZH	KIX	WUX		0	738
#
# ZH	KMG	CAN		0	320
#
# ZH	KMG	CSX		0	73G
#
# ZH	KMG	HFE		0	73G
#
# ZH	KMG	SZX		0	73G 319
#
# ZH	KMG	WUH		0	738
#
# ZH	KUL	NNG		0	738
#
# ZH	KUL	SZX		0	738
#
# ZH	KWL	AEB		0	E90
#
# ZH	KWL	BHY		0	E90
#
# ZH	KWL	CAN		0	320
#
# ZH	KWL	NKG		0	73G
#
# ZH	KWL	NNG		0	E90
#
# ZH	LHW	CSX		0	319
#
# ZH	LJG	SZX		0	73G
#
# ZH	MDG	HRB		0	E90
#
# ZH	MFM	WUX		0	738
#
# ZH	NKG	CAN		0	733
#
# ZH	NKG	CGQ		0	739
#
# ZH	NKG	HRB		0	738
#
# ZH	NKG	KWL		0	73G
#
# ZH	NKG	NNG		0	738
#
# ZH	NKG	SZX		0	738 739 73G
#
# ZH	NKG	TAO		0	738
#
# ZH	NKG	TSN		0	73G
#
# ZH	NKG	TYN		0	738
#
# ZH	NNG	CGK		0	738
#
# ZH	NNG	CGO		0	733
#
# ZH	NNG	CTU		0	738
#
# ZH	NNG	HGH		0	73G
#
# ZH	NNG	KUL		0	738
#
# ZH	NNG	KWL		0	E90
#
# ZH	NNG	NKG		0	738
#
# ZH	NNG	PEK		0	739
#
# ZH	NNG	SHA		0	738
#
# ZH	NNG	SIN		0	738
#
# ZH	NTG	SZX		0	320
#
# ZH	PEK	CGO		0	738
#
# ZH	PEK	NNG		0	739
#
# ZH	PEK	SZX		0	739 738
#
# ZH	PEK	WUX		0	738
#
# ZH	PVG	SZX		0	738
#
# ZH	SGN	SZX		0	738
#
# ZH	SHA	CAN		0	320
#
# ZH	SHA	JDZ		0	738
#
# ZH	SHA	NNG		0	738
#
# ZH	SHA	SZX		0	738
#
# ZH	SHE	CGO		0	320
#
# ZH	SHE	CZX		0	738
#
# ZH	SHE	HGH		0	73G
#
# ZH	SHE	HRB		0	738
#
# ZH	SHE	SZX		0	73G
#
# ZH	SHE	WNZ		0	738
#
# ZH	SHE	WUH		0	738
#
# ZH	SIN	NNG		0	738
#
# ZH	SJW	SHP		0	319
#
# ZH	SYX	SZX		0	738
#
# ZH	SYX	WNZ		0	738
#
# ZH	SZX	BKK		0	320
#
# ZH	SZX	CGD		0	319
#
# ZH	SZX	CGO		0	738
#
# ZH	SZX	CKG		0	738 739
#
# ZH	SZX	CSX		0	319
#
# ZH	SZX	CTU		0	320 738
#
# ZH	SZX	CZX		0	73G
#
# ZH	SZX	DLC		0	73G
#
# ZH	SZX	FOC		0	320
#
# ZH	SZX	HFE		0	320
#
# ZH	SZX	HGH		0	73G
#
# ZH	SZX	HRB		0	738
#
# ZH	SZX	ICN		0	738
#
# ZH	SZX	ICN	*	0	767
#
# ZH	SZX	JDZ		0	738
#
# ZH	SZX	JUZ		0	319
#
# ZH	SZX	KMG		0	73G 319
#
# ZH	SZX	KUL		0	738
#
# ZH	SZX	LJG		0	73G
#
# ZH	SZX	NKG		0	738 739 73G
#
# ZH	SZX	PEK		0	739 738
#
# ZH	SZX	PVG		0	73G 738
#
# ZH	SZX	SGN		0	738
#
# ZH	SZX	SHA		0	738
#
# ZH	SZX	SHE		0	738
#
# ZH	SZX	SJW		0	319
#
# ZH	SZX	SYX		0	738
#
# ZH	SZX	TAO		0	320
#
# ZH	SZX	TNA		0	319
#
# ZH	SZX	TSA		0	738
#
# ZH	SZX	TSN		0	738
#
# ZH	SZX	TXN		0	73G
#
# ZH	SZX	TYN		0	320
#
# ZH	SZX	WNZ		0	738
#
# ZH	SZX	WUH		0	320 738
#
# ZH	SZX	WUS		0	73G
#
# ZH	SZX	WUX		0	738
#
# ZH	SZX	XIY		0	320 738
#
# ZH	SZX	XMN		0	738
#
# ZH	SZX	YCU		0	320
#
# ZH	SZX	YIW		0	320
#
# ZH	TAO	NKG		0	738
#
# ZH	TAO	SZX		0	320
#
# ZH	TNA	CAN		0	738
#
# ZH	TNA	FOC		0	320
#
# ZH	TNA	HRB		0	320
#
# ZH	TNA	SZX		0	319
#
# ZH	TSA	SZX		0	738
#
# ZH	TSN	CGO		0	E90
#
# ZH	TSN	CGQ		0	73G
#
# ZH	TSN	HRB		0	E90
#
# ZH	TSN	NKG		0	73G
#
# ZH	TSN	SZX		0	738
#
# ZH	TXN	SZX		0	73G
#
# ZH	TYN	NKG		0	738
#
# ZH	TYN	SZX		0	320
#
# ZH	URC	CGO		0	738
#
# ZH	WNZ	SHE		0	738
#
# ZH	WNZ	SYX		0	738
#
# ZH	WNZ	SZX		0	738
#
# ZH	WUH	CAN		0	733
#
# ZH	WUH	CGQ		0	733
#
# ZH	WUH	HET		0	320
#
# ZH	WUH	KMG		0	738
#
# ZH	WUH	SHE		0	738
#
# ZH	WUH	SZX		0	320 738
#
# ZH	WUH	WUX		0	738
#
# ZH	WUS	SZX		0	73G
#
# ZH	WUX	CAN		0	733 320
#
# ZH	WUX	CTU		0	738
#
# ZH	WUX	DLC		0	320
#
# ZH	WUX	KIX		0	738
#
# ZH	WUX	MFM		0	738
#
# ZH	WUX	PEK		0	738
#
# ZH	WUX	SZX		0	738
#
# ZH	WUX	WUH		0	738
#
# ZH	XIY	CAN		0	733
#
# ZH	XIY	ENY		0	733
#
# ZH	XIY	INC		0	320
#
# ZH	XIY	SZX		0	320 738
#
# ZH	XIY	XNN		0	320
#
# ZH	XMN	CZX		0	738
#
# ZH	XMN	SZX		0	738
#
# ZH	XNN	CSX		0	733
#
# ZH	XNN	XIY		0	320
#
# ZH	YCU	SZX		0	320
#
# ZH	YIW	NTG		0	320
#
# ZI	AAE	CDG		0	319
#
# ZI	AAE	MRS		0	319
#
# ZI	AAE	ORY		0	320
#
# ZI	AGA	ORY		0	320
#
# ZI	ALG	LIL		0	320
#
# ZI	ALG	LYS		0	320
#
# ZI	ALG	MLH		0	320
#
# ZI	ALG	MRS		0	321
#
# ZI	ALG	ORY		0	321 319
#
# ZI	ALG	TLS		0	320
#
# ZI	BJA	LYS		0	320
#
# ZI	BJA	MRS		0	320
#
# ZI	BJA	ORY		0	321
#
# ZI	BKO	ORY		0	321
#
# ZI	BLJ	ORY		0	320
#
# ZI	BSK	ORY		0	320
#
# ZI	CDG	AAE		0	319
#
# ZI	CDG	HME		0	319
#
# ZI	CDG	ORN		0	321
#
# ZI	CFK	MRS		0	319
#
# ZI	CZL	LYS		0	320
#
# ZI	CZL	MLH		0	320
#
# ZI	CZL	MRS		0	319
#
# ZI	CZL	ORY		0	321
#
# ZI	DJE	ORY		0	320
#
# ZI	FAO	ORY		0	321
#
# ZI	HME	CDG		0	319
#
# ZI	LIL	ALG		0	320
#
# ZI	LIS	ORY		0	320 321
#
# ZI	LYS	ALG		0	320
#
# ZI	LYS	BJA		0	320
#
# ZI	LYS	CZL		0	320
#
# ZI	LYS	ORN		0	320
#
# ZI	LYS	QSF		0	320
#
# ZI	MLH	ALG		0	320
#
# ZI	MLH	CZL		0	320
#
# ZI	MLH	QSF		0	320
#
# ZI	MRS	AAE		0	319
#
# ZI	MRS	ALG		0	319
#
# ZI	MRS	BJA		0	320
#
# ZI	MRS	CFK		0	319
#
# ZI	MRS	CZL		0	319
#
# ZI	MRS	ORN		0	319
#
# ZI	MRS	QSF		0	319
#
# ZI	MRS	TLM		0	319
#
# ZI	OPO	ORY		0	320
#
# ZI	ORN	CDG		0	321
#
# ZI	ORN	LYS		0	320
#
# ZI	ORN	MRS		0	319
#
# ZI	ORN	ORY		0	321
#
# ZI	ORN	TLS		0	320
#
# ZI	ORY	AAE		0	320
#
# ZI	ORY	AGA		0	320
#
# ZI	ORY	ALG		0	321
#
# ZI	ORY	BJA		0	321
#
# ZI	ORY	BKO		0	321
#
# ZI	ORY	BLJ		0	320
#
# ZI	ORY	BSK		0	320
#
# ZI	ORY	CZL		0	321
#
# ZI	ORY	DJE		0	320
#
# ZI	ORY	FAO		0	321
#
# ZI	ORY	LIS		0	320 321
#
# ZI	ORY	OPO		0	320
#
# ZI	ORY	ORN		0	321
#
# ZI	ORY	QSF		0	320
#
# ZI	ORY	TLM		0	321
#
# ZI	QSF	LYS		0	320
#
# ZI	QSF	MLH		0	320
#
# ZI	QSF	MRS		0	319
#
# ZI	QSF	ORY		0	320
#
# ZI	TLM	MRS		0	319
#
# ZI	TLM	ORY		0	321
#
# ZI	TLS	ALG		0	320
#
# ZI	TLS	ORN		0	320
#
# ZK	ABQ	CVN		0	BE1
#
# ZK	ABQ	SVC		0	BE1
#
# ZK	AIA	BFF		0	BE1
#
# ZK	AIA	DEN		0	BE1
#
# ZK	ALS	DEN		0	BE1
#
# ZK	BFF	AIA		0	BE1
#
# ZK	BFF	DEN		0	BE1
#
# ZK	BIL	GCC		0	BE1
#
# ZK	BIL	GDV		0	BE1
#
# ZK	BIL	HVR		0	BE1
#
# ZK	BIL	OLF		0	BE1
#
# ZK	BIL	SDY		0	BE1
#
# ZK	BRL	MCI		0	BE1
#
# ZK	CDR	DEN		0	EM2
#
# ZK	CDR	ISN		0	EM2
#
# ZK	CEZ	DEN		0	BE1
#
# ZK	CGI	STL		0	BE1
#
# ZK	CNY	DEN		0	BE1
#
# ZK	CNY	ELY		0	BE1
#
# ZK	CVN	ABQ		0	BE1
#
# ZK	CYS	DEN		0	BE1 EM2
#
# ZK	DDC	DEN		0	BE1
#
# ZK	DDC	SLN		0	BE1
#
# ZK	DEC	STL		0	BE1
#
# ZK	DEN	ALS		0	BE1
#
# ZK	DEN	BFF		0	BE1
#
# ZK	DEN	CDR		0	EM2
#
# ZK	DEN	CEZ		0	BE1
#
# ZK	DEN	CNY		0	BE1
#
# ZK	DEN	CYS		0	BE1 EM2
#
# ZK	DEN	DDC		0	BE1
#
# ZK	DEN	DIK		0	EM2
#
# ZK	DEN	EAR		0	BE1
#
# ZK	DEN	FMN		0	BE1
#
# ZK	DEN	GCC		0	BE1
#
# ZK	DEN	GCK		0	BE1
#
# ZK	DEN	HYS		0	BE1
#
# ZK	DEN	LAR		0	BE1
#
# ZK	DEN	LBF		0	BE1
#
# ZK	DEN	LBL		0	BE1
#
# ZK	DEN	MCK		0	BE1
#
# ZK	DEN	PIR		0	BE1
#
# ZK	DEN	PUB		0	BE1
#
# ZK	DEN	RIW		0	EM2
#
# ZK	DEN	RKS		0	BE1
#
# ZK	DEN	SHR		0	EM2
#
# ZK	DEN	VEL		0	BE1
#
# ZK	DEN	WRL		0	BE1
#
# ZK	DIK	DEN		0	EM2
#
# ZK	DIK	ISN		0	EM2
#
# ZK	DIK	SDY		0	EM2
#
# ZK	EAR	DEN		0	BE1
#
# ZK	ELY	CNY		0	BE1
#
# ZK	FMN	DEN		0	BE1
#
# ZK	FMN	IGM		0	BE1
#
# ZK	FMN	PGA		0	BE1
#
# ZK	FMN	PRC		0	BE1
#
# ZK	GBD	GCK		0	BE1
#
# ZK	GBD	MCI		0	BE1
#
# ZK	GCC	BIL		0	BE1
#
# ZK	GCC	DEN		0	BE1
#
# ZK	GCC	MLS		0	BE1
#
# ZK	GCK	DEN		0	BE1
#
# ZK	GCK	GBD		0	BE1
#
# ZK	GCK	LBL		0	BE1
#
# ZK	GDV	BIL		0	BE1
#
# ZK	GDV	SDY		0	BE1
#
# ZK	GGW	MLS		0	BE1
#
# ZK	GGW	OLF		0	BE1
#
# ZK	GRI	MCI		0	BE1
#
# ZK	HON	PIR		0	BE1
#
# ZK	HVR	BIL		0	BE1
#
# ZK	HYS	DEN		0	BE1
#
# ZK	HYS	MCI		0	BE1
#
# ZK	IGM	FMN		0	BE1
#
# ZK	IGM	ONT		0	BE1
#
# ZK	ISN	CDR		0	EM2
#
# ZK	ISN	DIK		0	EM2
#
# ZK	IWD	RHI		0	BE1
#
# ZK	JLN	MCI		0	BE1
#
# ZK	LAR	DEN		0	BE1
#
# ZK	LBF	DEN		0	BE1
#
# ZK	LBL	DEN		0	BE1
#
# ZK	LBL	GCK		0	BE1
#
# ZK	LWT	WRL		0	BE1
#
# ZK	MBL	MKE		0	BE1
#
# ZK	MCE	ONT		0	BE1
#
# ZK	MCE	VIS		0	BE1
#
# ZK	MCI	BRL		0	BE1
#
# ZK	MCI	GBD		0	BE1
#
# ZK	MCI	GRI		0	BE1
#
# ZK	MCI	HYS		0	BE1
#
# ZK	MCI	JLN		0	BE1
#
# ZK	MCI	MHK		0	BE1
#
# ZK	MCI	SLN		0	BE1
#
# ZK	MCI	TBN		0	BE1
#
# ZK	MCK	DEN		0	BE1
#
# ZK	MCK	MHK		0	BE1
#
# ZK	MHK	DDC		0	BE1
#
# ZK	MHK	MCI		0	BE1
#
# ZK	MHK	MCK		0	BE1
#
# ZK	MKE	MBL		0	BE1
#
# ZK	MKE	RHI		0	BE1
#
# ZK	MLS	GCC		0	BE1
#
# ZK	MLS	GGW		0	BE1
#
# ZK	MWA	STL		0	BE1
#
# ZK	OLF	BIL		0	BE1
#
# ZK	OLF	GGW		0	BE1
#
# ZK	ONT	IGM		0	BE1
#
# ZK	ONT	MCE		0	BE1
#
# ZK	ONT	PRC		0	BE1
#
# ZK	ONT	VIS		0	BE1
#
# ZK	PGA	FMN		0	BE1
#
# ZK	PGA	PHX		0	BE1
#
# ZK	PHX	PGA		0	BE1
#
# ZK	PHX	SOW		0	BE1
#
# ZK	PIR	DEN		0	BE1
#
# ZK	PIR	HON		0	BE1
#
# ZK	PRC	FMN		0	BE1
#
# ZK	PRC	ONT		0	BE1
#
# ZK	PUB	DEN		0	BE1
#
# ZK	RHI	IWD		0	BE1
#
# ZK	RHI	MKE		0	BE1
#
# ZK	RIW	DEN		0	EM2
#
# ZK	RKS	DEN		0	BE1
#
# ZK	SDY	BIL		0	BE1
#
# ZK	SDY	DIK		0	EM2
#
# ZK	SDY	GDV		0	BE1
#
# ZK	SHR	DEN		0	EM2
#
# ZK	SLN	DDC		0	BE1
#
# ZK	SLN	MCI		0	BE1
#
# ZK	SLN	MHK		0	BE1
#
# ZK	SOW	PHX		0	BE1
#
# ZK	STL	CGI		0	BE1
#
# ZK	STL	DEC		0	BE1
#
# ZK	STL	MWA		0	BE1
#
# ZK	STL	TBN		0	BE1
#
# ZK	STL	UIN		0	BE1
#
# ZK	SVC	ABQ		0	BE1
#
# ZK	TBN	MCI		0	BE1
#
# ZK	TBN	STL		0	BE1
#
# ZK	UIN	STL		0	BE1
#
# ZK	VEL	DEN		0	BE1
#
# ZK	VIS	MCE		0	BE1
#
# ZK	VIS	ONT		0	BE1
#
# ZK	WRL	DEN		0	BE1
#
# ZK	WRL	LWT		0	BE1
#
# ZL	ABX	MEL		0	SF3
#
# ZL	ABX	SYD		0	SF3
#
# ZL	ADL	BHQ		0	SF3
#
# ZL	ADL	CED		0	SF3
#
# ZL	ADL	CPD		0	SF3
#
# ZL	ADL	KGC		0	SF3
#
# ZL	ADL	MGB		0	SF3
#
# ZL	ADL	PLO		0	SF3
#
# ZL	ADL	WYA		0	SF3
#
# ZL	BHQ	ADL		0	SF3
#
# ZL	BHQ	DBO		0	SF3
#
# ZL	BHQ	SYD		0	SF3
#
# ZL	BHS	PKE		0	SF3
#
# ZL	BHS	SYD		0	SF3 340
#
# ZL	BNK	SYD		0	SF3
#
# ZL	BWT	MEL		0	SF3
#
# ZL	CED	ADL		0	SF3
#
# ZL	CPD	ADL		0	SF3
#
# ZL	DBO	BHQ		0	SF3
#
# ZL	DBO	SYD		0	SF3 340
#
# ZL	GFF	NRA		0	SF3
#
# ZL	GFF	SYD		0	SF3
#
# ZL	GFN	TRO		0	SF3
#
# ZL	KGC	ADL		0	SF3
#
# ZL	KNS	MEL		0	SF3
#
# ZL	LSY	SYD		0	SF3
#
# ZL	MEL	ABX		0	SF3
#
# ZL	MEL	BWT		0	SF3
#
# ZL	MEL	KNS		0	SF3
#
# ZL	MEL	MGB		0	SF3
#
# ZL	MEL	MIM		0	SF3
#
# ZL	MEL	MQL		0	SF3
#
# ZL	MEL	WGA		0	SF3
#
# ZL	MGB	ADL		0	SF3
#
# ZL	MGB	MEL		0	SF3
#
# ZL	MIM	MEL		0	SF3
#
# ZL	MIM	MYA		0	SF3
#
# ZL	MIM	SYD		0	SF3
#
# ZL	MQL	MEL		0	SF3
#
# ZL	MYA	MIM		0	SF3
#
# ZL	MYA	SYD		0	SF3
#
# ZL	NRA	GFF		0	SF3
#
# ZL	NRA	SYD		0	SF3
#
# ZL	OAG	SYD		0	SF3
#
# ZL	PKE	BHS		0	SF3
#
# ZL	PKE	SYD		0	SF3
#
# ZL	PLO	ADL		0	SF3
#
# ZL	SYD	ABX		0	SF3
#
# ZL	SYD	BHQ		0	SF3
#
# ZL	SYD	BHS		0	SF3 340
#
# ZL	SYD	BNK		0	SF3
#
# ZL	SYD	DBO		0	SF3 340
#
# ZL	SYD	GFF		0	SF3
#
# ZL	SYD	LSY		0	SF3
#
# ZL	SYD	MIM		0	SF3
#
# ZL	SYD	MYA		0	SF3
#
# ZL	SYD	NRA		0	SF3
#
# ZL	SYD	OAG		0	SF3
#
# ZL	SYD	PKE		0	SF3
#
# ZL	SYD	TRO		0	SF3
#
# ZL	SYD	WGA		0	SF3
#
# ZL	TRO	GFN		0	SF3
#
# ZL	TRO	SYD		0	SF3
#
# ZL	WGA	MEL		0	SF3
#
# ZL	WGA	SYD		0	SF3
#
# ZL	WYA	ADL		0	SF3
#
# ZS	AHB	GIZ		0	733
#
# ZS	AHB	RUH		0	733
#
# ZS	AJF	HAS		0	733
#
# ZS	ALP	JED		0	733
#
# ZS	ALP	RUH		0	733
#
# ZS	ALY	JED		0	733
#
# ZS	ALY	RUH		0	733
#
# ZS	AMM	RUH		0	733
#
# ZS	ATZ	JED		0	733
#
# ZS	AUH	DMM		0	733
#
# ZS	AUH	JED		0	733
#
# ZS	BEY	JED		0	733
#
# ZS	BEY	RUH		0	733
#
# ZS	DAM	JED		0	733
#
# ZS	DAM	RUH		0	733
#
# ZS	DMM	AHB		0	733
#
# ZS	DMM	AUH		0	733
#
# ZS	DMM	DAM		0	733
#
# ZS	DMM	HAS		0	733
#
# ZS	DMM	JED		0	733
#
# ZS	DMM	MED		0	733
#
# ZS	DMM	RUH		0	733
#
# ZS	DMM	SHJ		0	733
#
# ZS	GIZ	DMM		0	733
#
# ZS	GIZ	RUH		0	733
#
# ZS	HAS	AJF		0	733
#
# ZS	HAS	DMM		0	733
#
# ZS	HAS	TUU		0	733
#
# ZS	HAS	URY		0	733
#
# ZS	JED	ALP		0	733
#
# ZS	JED	ALY		0	733
#
# ZS	JED	ATZ		0	733
#
# ZS	JED	AUH		0	733
#
# ZS	JED	BEY		0	733
#
# ZS	JED	DAM		0	733
#
# ZS	JED	DMM		0	733
#
# ZS	JED	RUH		0	733
#
# ZS	JED	SHJ		0	733
#
# ZS	MED	DMM		0	733
#
# ZS	MED	RUH		0	733
#
# ZS	RAE	HAS		0	733
#
# ZS	RUH	AHB		0	733
#
# ZS	RUH	ALP		0	733
#
# ZS	RUH	ALY		0	733
#
# ZS	RUH	AMM		0	733
#
# ZS	RUH	BEY		0	733
#
# ZS	RUH	DAM		0	733
#
# ZS	RUH	DMM		0	733
#
# ZS	RUH	GIZ		0	733
#
# ZS	RUH	JED		0	733
#
# ZS	RUH	MED		0	733
#
# ZS	RUH	SHJ		0	733
#
# ZS	SHJ	DMM		0	733
#
# ZS	SHJ	JED		0	733
#
# ZS	SHJ	RUH		0	733
#
# ZS	URY	HAS		0	733
#
# ZY	BYN	ULN		0	SF3
#
# ZY	COQ	ULN		0	SF3
#
# ZY	DLZ	ULN		0	SF3
#
# ZY	MXV	ULN		0	SF3
#
# ZY	ULN	BYN		0	SF3
#
# ZY	ULN	COQ		0	SF3
#
# ZY	ULN	DLZ		0	SF3
#
# ZY	ULN	MXV		0	SF3

# %%
line=a.readline()

# %%
line
# Out:
# '0B\tAGP\tBBU\t\t0\t733\n'

# %%
# Out:
# ''
