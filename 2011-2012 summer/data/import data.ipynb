# %%
import os

# %%
import numpy

# %%
import sys

# %%
import csv

# %%
import pandas as pd

# %%
csvfile = pd.DataFrame()

# %%
files = os.listdir('.')
#print('files',files)
for filename in files:
    portion = os.path.splitext(filename)
    if portion[1] == ".dat":  

        newname = portion[0] + ".txt"   
        os.rename(filename,newname)

# %%
ls
# Out:
# DAFIFT_0610_ed6.zip*                    distil_dafif.awk*
# Delete useless information-Copy1.ipynb  distil_gad.awk*
# airlines.txt*                           import data.ipynb
# airports-dafif.txt*                     map-2048.png*
# airports.txt*                           map-routes.php*
# arm/                                    merge-airports.sh*
# backup.ftp*                             routes.txt*
# countries.txt*                          timezones.php*

# %%
a = open('routes.txt','r')

# %%
a.close()
a
# Out:
# <_io.TextIOWrapper name='routes.txt' mode='r' encoding='UTF-8'>

# %%
with open('routes.txt', 'r') as a:
    while True:
        line = a.readline()     
        if not line:
            break
        print(line)
# Out:
# 2B,410,CEK,2968,DME,4029,,0,CR2
#
# 2B,410,CEK,2968,KZN,2990,,0,CR2
#
# 2B,410,CEK,2968,OVB,4078,,0,CR2
#
# 2B,410,DME,4029,CEK,2968,,0,CR2
#
# 2B,410,DME,4029,JOK,6161,,0,YK4
#
# 2B,410,DME,4029,KGD,2952,,0,CR2
#
# 2B,410,DME,4029,MQF,2969,,0,CR2
#
# 2B,410,DME,4029,NBC,3769,,0,CR2
#
# 2B,410,DME,4029,PEZ,6165,,0,YK4
#
# 2B,410,DME,4029,TBW,6466,,0,YK4
#
# 2B,410,DME,4029,UUA,6160,,0,CR2
#
# 2B,410,JOK,6161,DME,4029,,0,YK4
#
# 2B,410,KGD,2952,DME,4029,,0,CR2
#
# 2B,410,KZN,2990,CEK,2968,,0,CR2
#
# 2B,410,KZN,2990,UUA,6160,,0,CR2
#
# 2B,410,LED,2948,KZN,2990,,0,CR2
#
# 2B,410,LED,2948,NBC,3769,,0,CR2
#
# 2B,410,LED,2948,PEZ,6165,,0,YK4
#
# 2B,410,LED,2948,UUA,6160,,0,CR2
#
# 2B,410,MQF,2969,DME,4029,,0,CR2
#
# 2B,410,NBC,3769,DME,4029,,0,CR2
#
# 2B,410,NJC,2972,UUA,6160,,0,CR2
#
# 2B,410,OVB,4078,CEK,2968,,0,CR2
#
# 2B,410,PEZ,6165,DME,4029,,0,YK4
#
# 2B,410,PEZ,6165,LED,2948,,0,YK4
#
# 2B,410,TBW,6466,DME,4029,,0,YK4
#
# 2B,410,UUA,6160,DME,4029,,0,CR2
#
# 2B,410,UUA,6160,KZN,2990,,0,CR2
#
# 2B,410,UUA,6160,LED,2948,,0,CR2
#
# 2B,410,UUA,6160,NJC,2972,,0,CR2
#
# 2E,\N,HOM,3664,SOV,\N,,0,CNC
#
# 2E,\N,PGM,\N,SOV,\N,,0,CNC
#
# 2E,\N,SOV,\N,HOM,3664,,0,CNC
#
# 2E,\N,SOV,\N,PGM,\N,,0,CNC
#
# 2I,8359,ANS,2787,LIM,2789,,0,141
#
# 2I,8359,AQP,2802,JUL,2792,,0,142
#
# 2I,8359,AQP,2802,LIM,2789,,0,142 141
#
# 2I,8359,AYP,2786,LIM,2789,,0,142 141
#
# 2I,8359,CIX,2785,LIM,2789,,0,142
#
# 2I,8359,CIX,2785,TRU,2804,,0,142
#
# 2I,8359,CUZ,2812,LIM,2789,,0,141 142
#
# 2I,8359,CUZ,2812,PEM,2808,,0,142
#
# 2I,8359,CUZ,2812,RBR,2609,,0,141
#
# 2I,8359,HUU,6067,LIM,2789,,0,141
#
# 2I,8359,IQT,2801,PCL,2781,,0,143 142
#
# 2I,8359,IQT,2801,TPP,2806,,0,143 142
#
# 2I,8359,JAU,\N,LIM,2789,,0,141 142
#
# 2I,8359,JUL,2792,AQP,2802,,0,142
#
# 2I,8359,LIM,2789,ANS,2787,,0,141
#
# 2I,8359,LIM,2789,AQP,2802,,0,142 141
#
# 2I,8359,LIM,2789,AYP,2786,,0,142 141
#
# 2I,8359,LIM,2789,CIX,2785,,0,142
#
# 2I,8359,LIM,2789,CUZ,2812,,0,141 142
#
# 2I,8359,LIM,2789,HUU,6067,,0,141
#
# 2I,8359,LIM,2789,JAU,\N,,0,141 142
#
# 2I,8359,LIM,2789,PCL,2781,,0,143 142
#
# 2I,8359,LIM,2789,TPP,2806,,0,143 142
#
# 2I,8359,LIM,2789,TRU,2804,,0,142
#
# 2I,8359,PCL,2781,IQT,2801,,0,143 142
#
# 2I,8359,PCL,2781,LIM,2789,,0,143 142
#
# 2I,8359,PCL,2781,TPP,2806,,0,143
#
# 2I,8359,PEM,2808,CUZ,2812,,0,142
#
# 2I,8359,RBR,2609,CUZ,2812,,0,141
#
# 2I,8359,TPP,2806,IQT,2801,,0,143 142
#
# 2I,8359,TPP,2806,LIM,2789,,0,143 142
#
# 2I,8359,TPP,2806,PCL,2781,,0,143
#
# 2I,8359,TRU,2804,CIX,2785,,0,142
#
# 2I,8359,TRU,2804,LIM,2789,,0,142
#
# 2I,8359,TRU,2804,TYL,2810,,0,142
#
# 2I,8359,TYL,2810,TRU,2804,,0,142
#
# 2J,470,ABJ,253,ACC,248,,0,M87
#
# 2J,470,ABJ,253,BOY,247,,0,CRJ
#
# 2J,470,ABJ,253,OUA,246,,0,M87
#
# 2J,470,ACC,248,ABJ,253,,0,M87
#
# 2J,470,ACC,248,OUA,246,,0,M87 CRJ
#
# 2J,470,BKO,1044,DKR,1084,,0,M87
#
# 2J,470,BKO,1044,ORY,1386,Y,0,321
#
# 2J,470,BKO,1044,OUA,246,,0,CRJ M87
#
# 2J,470,BOY,247,ABJ,253,,0,CRJ
#
# 2J,470,BOY,247,OUA,246,,0,CRJ
#
# 2J,470,COO,245,DLA,897,,0,M87
#
# 2J,470,COO,245,LBV,970,,0,M87
#
# 2J,470,COO,245,OUA,246,,0,M87
#
# 2J,470,DKR,1084,BKO,1044,,0,M87
#
# 2J,470,DKR,1084,OUA,246,,0,M87
#
# 2J,470,DLA,897,COO,245,,0,M87
#
# 2J,470,LBV,970,COO,245,,0,M87
#
# 2J,470,LFW,298,OUA,246,,0,CRJ
#
# 2J,470,NIM,280,OUA,246,,0,CRJ M87
#
# 2J,470,ORY,1386,OUA,246,Y,0,321
#
# 2J,470,OUA,246,ABJ,253,,0,M87
#
# 2J,470,OUA,246,ACC,248,,0,CRJ M87
#
# 2J,470,OUA,246,BKO,1044,,0,CRJ M87
#
# 2J,470,OUA,246,BOY,247,,0,CRJ
#
# 2J,470,OUA,246,COO,245,,0,M87
#
# 2J,470,OUA,246,DKR,1084,,0,M87
#
# 2J,470,OUA,246,LFW,298,,0,CRJ
#
# 2J,470,OUA,246,NIM,280,,0,CRJ M87
#
# 2K,1338,BOG,2709,UIO,2688,,0,320 319 733
#
# 2K,1338,CUE,2671,UIO,2688,,0,732 737
#
# 2K,1338,GPS,2672,GYE,2673,,0,320 732 319
#
# 2K,1338,GYE,2673,CUE,2671,,0,732
#
# 2K,1338,GYE,2673,GPS,2672,,0,320 732 319
#
# 2K,1338,GYE,2673,UIO,2688,,0,732 319 320
#
# 2K,1338,MEC,2683,UIO,2688,,0,319 320
#
# 2K,1338,UIO,2688,BOG,2709,,0,320 319 733
#
# 2K,1338,UIO,2688,CUE,2671,,0,732 737
#
# 2K,1338,UIO,2688,GYE,2673,,0,319 320 732 733
#
# 2K,1338,UIO,2688,MEC,2683,,0,319 320
#
# 2L,2750,BDS,1506,BRN,1676,,0,100
#
# 2L,2750,BDS,1506,ZRH,1678,,0,100
#
# 2L,2750,BRI,1501,ZRH,1678,,0,100
#
# 2L,2750,BRN,1676,BDS,1506,,0,100
#
# 2L,2750,BRN,1676,PMI,3998,,0,100
#
# 2L,2750,CWL,488,ZRH,1678,,0,100
#
# 2L,2750,PMI,3998,BRN,1676,,0,100
#
# 2L,2750,RLG,772,ZRH,1678,,0,100
#
# 2L,2750,ZRH,1678,BDS,1506,,0,100
#
# 2L,2750,ZRH,1678,BRI,1501,,0,100
#
# 2L,2750,ZRH,1678,CWL,488,,0,100
#
# 2L,2750,ZRH,1678,RLG,772,,0,100
#
# 2M,3529,BUD,1489,KIV,1735,,0,S20
#
# 2M,3529,KIV,1735,BUD,1489,,0,S20
#
# 2M,3529,KIV,1735,SAW,4317,,0,S20
#
# 2M,3529,SAW,4317,KIV,1735,,0,S20
#
# 2N,5501,AJR,730,LYC,719,,0,ATP
#
# 2N,5501,ARN,737,HFS,5594,,0,BEH
#
# 2N,5501,ARN,737,KRF,718,,0,ATP
#
# 2N,5501,ARN,737,LYC,719,,0,ATP
#
# 2N,5501,ARN,737,MXX,698,,0,BEH
#
# 2N,5501,ARN,737,VBY,746,,0,SF3
#
# 2N,5501,ARN,737,VHM,729,,0,SF3 ATP
#
# 2N,5501,BMA,738,OSD,5593,,0,SF3
#
# 2N,5501,CPH,609,LPI,742,,0,SF3
#
# 2N,5501,EVG,714,MXX,698,,0,BEH
#
# 2N,5501,GEV,715,KRF,718,,0,ATP
#
# 2N,5501,HFS,5594,ARN,737,,0,BEH
#
# 2N,5501,HFS,5594,TYF,5596,,0,BEH
#
# 2N,5501,HMV,5599,VHM,729,,0,SF3 ATP
#
# 2N,5501,KRF,718,ARN,737,,0,ATP
#
# 2N,5501,KRF,718,GEV,715,,0,ATP
#
# 2N,5501,LLA,734,UME,728,,0,SF3
#
# 2N,5501,LPI,742,CPH,609,,0,SF3
#
# 2N,5501,LPI,742,ORB,731,,0,SF3
#
# 2N,5501,LYC,719,AJR,730,,0,ATP
#
# 2N,5501,LYC,719,ARN,737,,0,ATP
#
# 2N,5501,MXX,698,ARN,737,,0,BEH
#
# 2N,5501,MXX,698,EVG,714,,0,BEH
#
# 2N,5501,ORB,731,LPI,742,,0,SF3
#
# 2N,5501,OSD,5593,BMA,738,,0,SF3
#
# 2N,5501,OSD,5593,UME,728,,0,SF3
#
# 2N,5501,TYF,5596,HFS,5594,,0,BEH
#
# 2N,5501,UME,728,LLA,734,,0,SF3
#
# 2N,5501,UME,728,OSD,5593,,0,SF3
#
# 2N,5501,VBY,746,ARN,737,,0,SF3
#
# 2N,5501,VHM,729,ARN,737,,0,SF3 ATP
#
# 2N,5501,VHM,729,HMV,5599,,0,SF3 ATP
#
# 2O,146,ADQ,3531,ALZ,7166,,0,BNI
#
# 2O,146,ADQ,3531,AOS,7167,,0,BNI
#
# 2O,146,ADQ,3531,KKB,7168,,0,BNI
#
# 2O,146,ADQ,3531,KLN,7162,,0,BNI
#
# 2O,146,ADQ,3531,KOZ,7164,,0,BNI
#
# 2O,146,ADQ,3531,KPY,7171,,0,BNI
#
# 2O,146,ADQ,3531,OLH,7163,,0,BNI
#
# 2O,146,KLN,7162,ADQ,3531,,0,BNI
#
# 2O,146,KOZ,7164,ORI,7165,,0,BNI
#
# 2O,146,OLH,7163,ADQ,3531,,0,BNI
#
# 2O,146,ORI,7165,ADQ,3531,,0,BNI
#
# 2P,897,BCD,2423,MNL,2397,,0,320
#
# 2P,897,CEB,4206,DVO,4090,,0,320
#
# 2P,897,CEB,4206,MNL,2397,,0,320
#
# 2P,897,CEB,4206,SIN,3316,,0,320
#
# 2P,897,CGY,2400,MNL,2397,,0,320
#
# 2P,897,DVO,4090,CEB,4206,,0,320
#
# 2P,897,DVO,4090,MNL,2397,,0,320
#
# 2P,897,ILO,2429,MNL,2397,,0,320
#
# 2P,897,KLO,2430,MNL,2397,,0,320
#
# 2P,897,LGP,4203,MNL,2397,,0,320
#
# 2P,897,MNL,2397,BCD,2423,,0,320
#
# 2P,897,MNL,2397,CEB,4206,,0,320
#
# 2P,897,MNL,2397,CGY,2400,,0,320
#
# 2P,897,MNL,2397,DVO,4090,,0,320
#
# 2P,897,MNL,2397,ILO,2429,,0,320
#
# 2P,897,MNL,2397,KLO,2430,,0,320
#
# 2P,897,MNL,2397,LGP,4203,,0,320
#
# 2P,897,MNL,2397,PPS,2433,,0,320
#
# 2P,897,MNL,2397,SIN,3316,,0,320
#
# 2P,897,MNL,2397,TAG,3994,,0,320
#
# 2P,897,MNL,2397,ZAM,2404,,0,320
#
# 2P,897,PPS,2433,MNL,2397,,0,320
#
# 2P,897,SIN,3316,CEB,4206,,0,320
#
# 2P,897,SIN,3316,MNL,2397,,0,320
#
# 2P,897,TAG,3994,MNL,2397,,0,320
#
# 2P,897,ZAM,2404,MNL,2397,,0,320
#
# 2U,909,AMS,580,TLV,1590,,0,757
#
# 2U,909,BCN,1218,TLV,1590,,0,757
#
# 2U,909,CDG,1382,TLV,1590,,0,757 738
#
# 2U,909,CDG,1382,VDA,1602,,0,757
#
# 2U,909,FCO,1555,TLV,1590,,0,757
#
# 2U,909,MAD,1229,TLV,1590,,0,738
#
# 2U,909,MUC,346,FCO,1555,,0,757
#
# 2U,909,OTP,1657,TLV,1590,,0,757
#
# 2U,909,TLV,1590,AMS,580,,0,757
#
# 2U,909,TLV,1590,BCN,1218,,0,757
#
# 2U,909,TLV,1590,BTS,1745,,0,757
#
# 2U,909,TLV,1590,CDG,1382,,0,757 738
#
# 2U,909,TLV,1590,FCO,1555,,0,757
#
# 2U,909,TLV,1590,FRA,340,,0,738
#
# 2U,909,TLV,1590,MAD,1229,,0,738
#
# 2U,909,TLV,1590,MUC,346,,0,757
#
# 2U,909,TLV,1590,OTP,1657,,0,757
#
# 2U,909,TLV,1590,ZAG,1208,,0,757
#
# 2U,909,ZAG,1208,TLV,1590,,0,757
#
# 2W,5401,GRZ,1609,INN,1610,,0,D38
#
# 2W,5401,HAJ,352,INN,1610,,0,D38
#
# 2W,5401,INN,1610,GRZ,1609,,0,D38
#
# 2W,5401,INN,1610,HAJ,352,,0,D38
#
# 2Z,1729,APL,984,MPM,979,,0,AR8
#
# 2Z,1729,BEW,974,MPM,979,,0,AR8
#
# 2Z,1729,JNB,813,MPM,979,,0,AR8
#
# 2Z,1729,MPM,979,APL,984,,0,AR8
#
# 2Z,1729,MPM,979,BEW,974,,0,AR8
#
# 2Z,1729,MPM,979,JNB,813,,0,AR8
#
# 2Z,1729,MPM,979,TET,988,,0,AR8
#
# 2Z,1729,TET,988,MPM,979,,0,AR8
#
# 3B,15953,BRQ,1588,PRG,1587,,0,SF3
#
# 3B,15953,LEJ,348,PRG,1587,,0,SF3
#
# 3B,15953,OSR,1582,PRG,1587,,0,SF3
#
# 3B,15953,OSR,1582,VIE,1613,,0,SF3
#
# 3B,15953,POZ,674,PRG,1587,,0,SF3
#
# 3B,15953,PRG,1587,BRQ,1588,,0,SF3
#
# 3B,15953,PRG,1587,LEJ,348,,0,SF3
#
# 3B,15953,PRG,1587,OSR,1582,,0,SF3
#
# 3B,15953,PRG,1587,POZ,674,,0,SF3
#
# 3B,15953,VIE,1613,OSR,1582,,0,SF3
#
# 3E,10739,BRL,5726,ORD,3830,,0,CNC
#
# 3E,10739,BRL,5726,STL,3678,,0,CNC
#
# 3E,10739,DEC,4042,ORD,3830,,0,CNC
#
# 3E,10739,DEC,4042,STL,3678,,0,CNC
#
# 3E,10739,ORD,3830,BRL,5726,,0,CNC
#
# 3E,10739,ORD,3830,DEC,4042,,0,CNC
#
# 3E,10739,STL,3678,BRL,5726,,0,CNC
#
# 3E,10739,STL,3678,DEC,4042,,0,CNC
#
# 3F,16262,CGA,7144,HYL,7145,,0,DHP
#
# 3F,16262,CGA,7144,KTN,3808,,0,DHP
#
# 3F,16262,HYL,7145,KTN,3808,,0,DHP
#
# 3F,16262,KTB,7147,KTN,3808,,0,DHP
#
# 3F,16262,KTN,3808,CGA,7144,,0,DHP
#
# 3F,16262,KTN,3808,HYL,7145,,0,DHP
#
# 3F,16262,KTN,3808,KTB,7147,,0,DHP
#
# 3F,16262,KTN,3808,MTM,7146,,0,DHP
#
# 3F,16262,MTM,7146,KTN,3808,,0,DHP
#
# 3H,\N,AKV,5506,YIK,5504,,0,DH8
#
# 3H,\N,AKV,5506,YPX,6727,,0,DH8
#
# 3H,\N,XGR,5512,YDP,5488,,0,DHT
#
# 3H,\N,XGR,5512,YVP,154,,0,DHT BET
#
# 3H,\N,YDP,5488,XGR,5512,,0,DHT
#
# 3H,\N,YGL,62,YGW,5496,,0,DHT
#
# 3H,\N,YGL,62,YPX,6727,,0,73M DH8
#
# 3H,\N,YGL,62,YUL,146,,0,73M DH8
#
# 3H,\N,YGW,5496,YGL,62,,0,DHT
#
# 3H,\N,YGW,5496,YSK,5529,,0,DH8 DHT
#
# 3H,\N,YGW,5496,YUD,5515,,0,DH8
#
# 3H,\N,YGW,5496,YUL,146,,0,DH8
#
# 3H,\N,YIK,5504,AKV,5506,,0,DH8
#
# 3H,\N,YIK,5504,YZG,5535,,0,DH8
#
# 3H,\N,YKG,5481,YPJ,5508,,0,DHT DH8
#
# 3H,\N,YKG,5481,YQC,5499,,0,DH8
#
# 3H,\N,YKG,5481,YVP,154,,0,DH8 DHT
#
# 3H,\N,YKL,80,YQB,111,,0,DH8
#
# 3H,\N,YKL,80,YVP,154,,0,DH8 BET
#
# 3H,\N,YKL,80,YWK,161,,0,BET
#
# 3H,\N,YKL,80,YZV,202,,0,BET
#
# 3H,\N,YPH,5520,YPX,6727,,0,DH8 BET
#
# 3H,\N,YPH,5520,YUD,5515,,0,DH8
#
# 3H,\N,YPH,5520,YVP,154,,0,BET
#
# 3H,\N,YPJ,5508,YKG,5481,,0,DHT DH8
#
# 3H,\N,YPJ,5508,YTQ,6728,,0,DHT DH8
#
# 3H,\N,YPJ,5508,YVP,154,,0,DHT
#
# 3H,\N,YPX,6727,AKV,5506,,0,DH8
#
# 3H,\N,YPX,6727,YGL,62,,0,73M DH8
#
# 3H,\N,YPX,6727,YPH,5520,,0,DH8
#
# 3H,\N,YPX,6727,YVP,154,,0,BET
#
# 3H,\N,YPX,6727,YZG,5535,,0,DH8
#
# 3H,\N,YQB,111,YKL,80,,0,DH8
#
# 3H,\N,YQB,111,YUL,146,,0,DH8
#
# 3H,\N,YQC,5499,YKG,5481,,0,DH8
#
# 3H,\N,YQC,5499,YWB,7253,,0,DH8
#
# 3H,\N,YSK,5529,YGW,5496,,0,DH8 DHT
#
# 3H,\N,YSK,5529,YUD,5515,,0,DH8
#
# 3H,\N,YTE,140,YZG,5535,,0,DH8
#
# 3H,\N,YTQ,6728,YPJ,5508,,0,DHT DH8
#
# 3H,\N,YTQ,6728,YVP,154,,0,DHT DH8
#
# 3H,\N,YUD,5515,YGW,5496,,0,DH8
#
# 3H,\N,YUD,5515,YPH,5520,,0,DH8
#
# 3H,\N,YUD,5515,YSK,5529,,0,DH8
#
# 3H,\N,YUL,146,YGL,62,,0,73M DH8
#
# 3H,\N,YUL,146,YGW,5496,,0,DH8
#
# 3H,\N,YUL,146,YQB,111,,0,DH8
#
# 3H,\N,YVP,154,XGR,5512,,0,DHT BET
#
# 3H,\N,YVP,154,YKG,5481,,0,DH8
#
# 3H,\N,YVP,154,YKL,80,,0,DH8 BET
#
# 3H,\N,YVP,154,YPH,5520,,0,BET
#
# 3H,\N,YVP,154,YPX,6727,,0,BET
#
# 3H,\N,YVP,154,YTQ,6728,,0,DHT DH8
#
# 3H,\N,YWB,7253,YQC,5499,,0,DH8
#
# 3H,\N,YWB,7253,YZG,5535,,0,DH8
#
# 3H,\N,YWK,161,YKL,80,,0,BET
#
# 3H,\N,YWK,161,YZV,202,,0,BET
#
# 3H,\N,YZG,5535,YIK,5504,,0,DH8
#
# 3H,\N,YZG,5535,YPX,6727,,0,DH8
#
# 3H,\N,YZG,5535,YTE,140,,0,DH8
#
# 3H,\N,YZG,5535,YWB,7253,,0,DH8
#
# 3H,\N,YZV,202,YKL,80,,0,BET
#
# 3H,\N,YZV,202,YWK,161,,0,BET
#
# 3K,3021,AKL,2006,SIN,3316,Y,0,332
#
# 3K,3021,BKK,3885,SIN,3316,,0,320
#
# 3K,3021,HAK,4120,SIN,3316,,0,320
#
# 3K,3021,HGH,3386,SIN,3316,,0,320
#
# 3K,3021,HKG,3077,SIN,3316,,0,320
#
# 3K,3021,HKT,3179,SIN,3316,,0,320
#
# 3K,3021,KIX,3992,TPE,2276,,0,320
#
# 3K,3021,KUL,3304,SIN,3316,,0,320
#
# 3K,3021,KWL,3372,SIN,3316,,0,320
#
# 3K,3021,MFM,3121,SIN,3316,,0,320
#
# 3K,3021,MNL,2397,SIN,3316,,0,320
#
# 3K,3021,PEN,3308,SIN,3316,,0,320
#
# 3K,3021,PER,3351,SIN,3316,,0,320
#
# 3K,3021,PNH,3034,SIN,3316,,0,320
#
# 3K,3021,REP,3035,PNH,3034,,0,320
#
# 3K,3021,RGN,3239,SIN,3316,,0,320
#
# 3K,3021,SGN,3205,SIN,3316,,0,320
#
# 3K,3021,SIN,3316,AKL,2006,Y,0,332
#
# 3K,3021,SIN,3316,BKK,3885,,0,320
#
# 3K,3021,SIN,3316,HAK,4120,,0,320
#
# 3K,3021,SIN,3316,HGH,3386,,0,320
#
# 3K,3021,SIN,3316,HKG,3077,,0,320
#
# 3K,3021,SIN,3316,HKT,3179,,0,320
#
# 3K,3021,SIN,3316,KUL,3304,,0,320
#
# 3K,3021,SIN,3316,KWL,3372,,0,320
#
# 3K,3021,SIN,3316,MFM,3121,,0,320
#
# 3K,3021,SIN,3316,MNL,2397,,0,320
#
# 3K,3021,SIN,3316,PEN,3308,,0,320
#
# 3K,3021,SIN,3316,PER,3351,,0,320
#
# 3K,3021,SIN,3316,PNH,3034,,0,320
#
# 3K,3021,SIN,3316,REP,3035,,0,320
#
# 3K,3021,SIN,3316,RGN,3239,,0,320
#
# 3K,3021,SIN,3316,SGN,3205,,0,320
#
# 3K,3021,SIN,3316,SWA,4302,,0,320
#
# 3K,3021,SIN,3316,TPE,2276,,0,320
#
# 3K,3021,SWA,4302,SIN,3316,,0,320
#
# 3K,3021,TPE,2276,KIX,3992,,0,320
#
# 3K,3021,TPE,2276,SIN,3316,,0,320
#
# 3L,2916,DUS,345,FDH,382,,0,DH3
#
# 3L,2916,EBA,1558,FDH,382,,0,DH3
#
# 3L,2916,FDH,382,DUS,345,,0,DH3
#
# 3L,2916,FDH,382,EBA,1558,,0,DH3
#
# 3L,2916,FDH,382,GRZ,1609,,0,DH3
#
# 3L,2916,FDH,382,HAM,342,,0,DH3
#
# 3L,2916,FDH,382,OLB,1520,,0,DH3
#
# 3L,2916,FDH,382,TXL,351,,0,DH3
#
# 3L,2916,FDH,382,VIE,1613,,0,DH3
#
# 3L,2916,GRZ,1609,FDH,382,,0,DH3
#
# 3L,2916,HAM,342,FDH,382,,0,DH3
#
# 3L,2916,OLB,1520,FDH,382,,0,DH3
#
# 3L,2916,TXL,351,FDH,382,,0,DH3
#
# 3L,2916,VIE,1613,FDH,382,,0,DH3
#
# 3M,\N,DUJ,5734,FKL,4058,,0,BE1
#
# 3O,9818,AMS,580,CMN,1074,,0,320
#
# 3O,9818,AMS,580,NDR,5673,,0,320
#
# 3O,9818,AMS,580,OUD,1070,,0,320
#
# 3O,9818,AMS,580,TNG,1080,,0,320
#
# 3O,9818,BCN,1218,CMN,1074,,0,320
#
# 3O,9818,BGY,1525,CMN,1074,,0,320
#
# 3O,9818,BLQ,1538,CMN,1074,,0,320
#
# 3O,9818,BRU,302,CMN,1074,,0,320
#
# 3O,9818,BRU,302,FEZ,1066,,0,320
#
# 3O,9818,BRU,302,NDR,5673,,0,320
#
# 3O,9818,CDG,1382,CMN,1074,,0,320
#
# 3O,9818,CDG,1382,FEZ,1066,,0,320
#
# 3O,9818,CDG,1382,NDR,5673,,0,320
#
# 3O,9818,CDG,1382,OUD,1070,,0,320
#
# 3O,9818,CGN,344,CMN,1074,,0,320
#
# 3O,9818,CMN,1074,AMS,580,,0,320
#
# 3O,9818,CMN,1074,BCN,1218,,0,320
#
# 3O,9818,CMN,1074,BGY,1525,,0,320
#
# 3O,9818,CMN,1074,BLQ,1538,,0,320
#
# 3O,9818,CMN,1074,BRU,302,,0,320
#
# 3O,9818,CMN,1074,CDG,1382,,0,320
#
# 3O,9818,CMN,1074,CGN,344,,0,320
#
# 3O,9818,CMN,1074,CUF,1534,,0,320
#
# 3O,9818,CMN,1074,FEZ,1066,,0,320
#
# 3O,9818,CMN,1074,LYS,1335,,0,320
#
# 3O,9818,CMN,1074,MPL,1359,,0,320
#
# 3O,9818,CMN,1074,NDR,5673,,0,320
#
# 3O,9818,CMN,1074,SAW,4317,,0,320
#
# 3O,9818,CMN,1074,TNG,1080,,0,320
#
# 3O,9818,CMN,1074,TSF,1539,,0,320
#
# 3O,9818,CMN,1074,TUN,287,,0,320
#
# 3O,9818,CUF,1534,CMN,1074,,0,320
#
# 3O,9818,FEZ,1066,BRU,302,,0,320
#
# 3O,9818,FEZ,1066,CDG,1382,,0,320
#
# 3O,9818,FEZ,1066,MPL,1359,,0,320
#
# 3O,9818,LYS,1335,CMN,1074,,0,320
#
# 3O,9818,MPL,1359,CMN,1074,,0,320
#
# 3O,9818,MPL,1359,FEZ,1066,,0,320
#
# 3O,9818,MPL,1359,NDR,5673,,0,320
#
# 3O,9818,MPL,1359,OUD,1070,,0,320
#
# 3O,9818,MPL,1359,TNG,1080,,0,320
#
# 3O,9818,NDR,5673,AMS,580,,0,320
#
# 3O,9818,NDR,5673,BRU,302,,0,320
#
# 3O,9818,NDR,5673,CDG,1382,,0,320
#
# 3O,9818,NDR,5673,CGN,344,,0,320
#
# 3O,9818,NDR,5673,MPL,1359,,0,320
#
# 3O,9818,OUD,1070,AMS,580,,0,320
#
# 3O,9818,OUD,1070,CDG,1382,,0,320
#
# 3O,9818,OUD,1070,MPL,1359,,0,320
#
# 3O,9818,SAW,4317,CMN,1074,,0,320
#
# 3O,9818,TNG,1080,AMS,580,,0,320
#
# 3O,9818,TNG,1080,MPL,1359,,0,320
#
# 3O,9818,TSF,1539,CMN,1074,,0,320
#
# 3O,9818,TUN,287,CMN,1074,,0,320
#
# 3P,5002,AUA,2895,BON,2896,,0,SH6
#
# 3P,5002,AUA,2895,CUR,2897,,0,SH6
#
# 3P,5002,AUA,2895,LSP,2844,,0,SH6
#
# 3P,5002,AUA,2895,MAR,2848,,0,SH6
#
# 3P,5002,AUA,2895,RCH,2746,,0,SH6
#
# 3P,5002,BON,2896,AUA,2895,,0,SH6
#
# 3P,5002,CUR,2897,AUA,2895,,0,SH6
#
# 3P,5002,LSP,2844,AUA,2895,,0,SH6
#
# 3P,5002,MAR,2848,AUA,2895,,0,SH6
#
# 3P,5002,RCH,2746,AUA,2895,,0,SH6
#
# 3R,3545,AZN,6148,DME,4029,,0,73G
#
# 3R,3545,BHK,2980,DME,4029,,0,73G
#
# 3R,3545,DME,4029,AZN,6148,,0,73G
#
# 3R,3545,DME,4029,BHK,2980,,0,73G
#
# 3R,3545,DME,4029,FEG,6149,,0,73G
#
# 3R,3545,DME,4029,KSQ,6153,,0,73G
#
# 3R,3545,DME,4029,KVD,6089,,0,73G
#
# 3R,3545,DME,4029,NMA,6150,,0,73G
#
# 3R,3545,DME,4029,NVI,6485,,0,73G
#
# 3R,3545,DME,4029,SKD,2981,,0,73G
#
# 3R,3545,DME,4029,TIV,1743,,0,73G
#
# 3R,3545,DME,4029,TMJ,6154,,0,73G
#
# 3R,3545,FEG,6149,DME,4029,,0,73G
#
# 3R,3545,KSQ,6153,DME,4029,,0,73G
#
# 3R,3545,KVD,6089,DME,4029,,0,73G
#
# 3R,3545,NMA,6150,DME,4029,,0,73G
#
# 3R,3545,NVI,6485,DME,4029,,0,73G
#
# 3R,3545,SKD,2981,DME,4029,,0,73G
#
# 3R,3545,TIV,1743,DME,4029,,0,73G
#
# 3R,3545,TMJ,6154,DME,4029,,0,73G
#
# 3S,11741,FDF,2878,PTP,2881,,0,AT5
#
# 3S,11741,JBQ,5811,PAP,1897,,0,AT5
#
# 3S,11741,JBQ,5811,PTP,2881,,0,AT5
#
# 3S,11741,PAP,1897,JBQ,5811,,0,AT5
#
# 3S,11741,PTP,2881,FDF,2878,,0,AT5
#
# 3S,11741,PTP,2881,JBQ,5811,,0,AT5
#
# 3S,11741,PTP,2881,SBH,6460,,0,DHT
#
# 3S,11741,PTP,2881,SFG,2879,,0,AT5 DHT
#
# 3S,11741,SBH,6460,PTP,2881,,0,DHT
#
# 3S,11741,SBH,6460,SFG,2879,,0,DHT
#
# 3S,11741,SFG,2879,PTP,2881,,0,AT5 DHT
#
# 3S,11741,SFG,2879,SBH,6460,,0,DHT
#
# 3T,5187,GYD,2922,MRV,2962,,0,TU5
#
# 3T,5187,GYD,2922,SGC,2974,,0,TU5
#
# 3T,5187,GYD,2922,SVX,2975,,0,TU5
#
# 3T,5187,MRV,2962,GYD,2922,,0,TU5
#
# 3T,5187,SGC,2974,GYD,2922,,0,TU5
#
# 3T,5187,SVX,2975,GYD,2922,,0,TU5
#
# 3U,4608,BHY,6351,HKG,3077,,0,320
#
# 3U,4608,CAN,3370,CKG,3393,,0,320
#
# 3U,4608,CAN,3370,CTU,3395,,0,320 319
#
# 3U,4608,CGO,3375,CGQ,4380,,0,319
#
# 3U,4608,CGO,3375,CTU,3395,,0,319
#
# 3U,4608,CGO,3375,HET,6345,,0,320
#
# 3U,4608,CGO,3375,HGH,3386,,0,320
#
# 3U,4608,CGO,3375,HRB,3400,,0,320
#
# 3U,4608,CGO,3375,KMG,3382,,0,320
#
# 3U,4608,CGO,3375,URC,3399,,0,320
#
# 3U,4608,CGQ,4380,CGO,3375,,0,319
#
# 3U,4608,CGQ,4380,TNA,4108,,0,320
#
# 3U,4608,CIF,6342,HET,6345,,0,320
#
# 3U,4608,CKG,3393,CAN,3370,,0,320
#
# 3U,4608,CKG,3393,CSX,3371,,0,320
#
# 3U,4608,CKG,3393,CTU,3395,,0,ERJ
#
# 3U,4608,CKG,3393,CZX,4109,,0,320
#
# 3U,4608,CKG,3393,DLC,3404,,0,320
#
# 3U,4608,CKG,3393,HAK,4120,,0,321
#
# 3U,4608,CKG,3393,HAN,3199,,0,320
#
# 3U,4608,CKG,3393,HGH,3386,,0,320
#
# 3U,4608,CKG,3393,HKT,3179,,0,320
#
# 3U,4608,CKG,3393,INC,4085,,0,320
#
# 3U,4608,CKG,3393,JIQ,\N,,0,ERJ
#
# 3U,4608,CKG,3393,JZH,4301,,0,319
#
# 3U,4608,CKG,3393,KHN,3384,,0,320
#
# 3U,4608,CKG,3393,KMG,3382,,0,320
#
# 3U,4608,CKG,3393,KWL,3372,,0,320
#
# 3U,4608,CKG,3393,LXA,4097,,0,319
#
# 3U,4608,CKG,3393,MIG,6400,,0,ERJ
#
# 3U,4608,CKG,3393,NGB,3387,,0,320 319
#
# 3U,4608,CKG,3393,NKG,3388,,0,320
#
# 3U,4608,CKG,3393,PEK,3364,,0,320 330 319
#
# 3U,4608,CKG,3393,PVG,3406,,0,320
#
# 3U,4608,CKG,3393,SYX,4030,,0,320
#
# 3U,4608,CKG,3393,SZX,3374,,0,320
#
# 3U,4608,CKG,3393,TNA,4108,,0,319
#
# 3U,4608,CKG,3393,TSA,2275,,0,320
#
# 3U,4608,CKG,3393,URC,3399,,0,320
#
# 3U,4608,CKG,3393,WNZ,6392,,0,320
#
# 3U,4608,CKG,3393,WUH,3376,,0,320
#
# 3U,4608,CKG,3393,WUX,6390,,0,320
#
# 3U,4608,CKG,3393,XIY,3379,,0,320 ERJ
#
# 3U,4608,CKG,3393,XNN,6366,,0,320
#
# 3U,4608,CKG,3393,YIH,6361,,0,320
#
# 3U,4608,CSX,3371,CKG,3393,,0,320
#
# 3U,4608,CSX,3371,CTU,3395,,0,320
#
# 3U,4608,CSX,3371,FOC,3385,,0,320
#
# 3U,4608,CSX,3371,MIG,6400,,0,ERJ
#
# 3U,4608,CSX,3371,XMN,3383,,0,320
#
# 3U,4608,CTU,3395,CAN,3370,,0,320 319
#
# 3U,4608,CTU,3395,CGO,3375,,0,319
#
# 3U,4608,CTU,3395,CKG,3393,,0,ERJ
#
# 3U,4608,CTU,3395,CSX,3371,,0,320
#
# 3U,4608,CTU,3395,HAK,4120,,0,320
#
# 3U,4608,CTU,3395,HET,6345,,0,320
#
# 3U,4608,CTU,3395,HFE,3389,,0,320
#
# 3U,4608,CTU,3395,HGH,3386,,0,320
#
# 3U,4608,CTU,3395,HKG,3077,,0,320
#
# 3U,4608,CTU,3395,HKT,3179,,0,321
#
# 3U,4608,CTU,3395,INC,4085,,0,320
#
# 3U,4608,CTU,3395,JZH,4301,,0,319
#
# 3U,4608,CTU,3395,KHN,3384,,0,320
#
# 3U,4608,CTU,3395,KMG,3382,,0,320
#
# 3U,4608,CTU,3395,KOW,6379,,0,319 320
#
# 3U,4608,CTU,3395,KWE,3394,,0,320 319
#
# 3U,4608,CTU,3395,KWL,3372,,0,320 319
#
# 3U,4608,CTU,3395,LHW,6431,,0,320
#
# 3U,4608,CTU,3395,LJG,4033,,0,319
#
# 3U,4608,CTU,3395,LXA,4097,,0,319
# 3U,4608,CTU,3395,LYI,6385,,0,319
#
# 3U,4608,CTU,3395,NKG,3388,,0,320
#
# 3U,4608,CTU,3395,NNG,3373,,0,320
#
# 3U,4608,CTU,3395,PEK,3364,,0,330 320 321
#
# 3U,4608,CTU,3395,PVG,3406,,0,330 321
#
# 3U,4608,CTU,3395,RMQ,\N,,0,321
#
# 3U,4608,CTU,3395,SJW,6347,,0,319
#
# 3U,4608,CTU,3395,SYX,4030,,0,320
#
# 3U,4608,CTU,3395,SZX,3374,,0,320 319
#
# 3U,4608,CTU,3395,TAO,3390,,0,320
#
# 3U,4608,CTU,3395,TNA,4108,,0,320
#
# 3U,4608,CTU,3395,TSA,2275,,0,321
#
# 3U,4608,CTU,3395,TSN,3368,,0,320
#
# 3U,4608,CTU,3395,TYN,3369,,0,321
#
# 3U,4608,CTU,3395,URC,3399,,0,319
#
# 3U,4608,CTU,3395,WNZ,6392,,0,319
#
# 3U,4608,CTU,3395,WUH,3376,,0,319
#
# 3U,4608,CTU,3395,WUX,6390,,0,320
#
# 3U,4608,CTU,3395,XIC,3396,,0,320
#
# 3U,4608,CTU,3395,XIY,3379,,0,320 319
#
# 3U,4608,CTU,3395,XMN,3383,,0,320
#
# 3U,4608,CTU,3395,XNN,6366,,0,319
#
# 3U,4608,CTU,3395,XUZ,4149,,0,319
#
# 3U,4608,CTU,3395,YIH,6361,,0,320
#
# 3U,4608,CZX,4109,CKG,3393,,0,320
#
# 3U,4608,CZX,4109,DYG,6353,,0,320
#
# 3U,4608,CZX,4109,KWL,3372,,0,320
#
# 3U,4608,CZX,4109,ZUH,6355,,0,320
#
# 3U,4608,DLC,3404,CKG,3393,,0,320
#
# 3U,4608,DLC,3404,HGH,3386,,0,320
#
# 3U,4608,DLC,3404,HRB,3400,,0,320
#
# 3U,4608,DLC,3404,TNA,4108,,0,320
#
# 3U,4608,DLC,3404,XUZ,4149,,0,319
#
# 3U,4608,DYG,6353,CZX,4109,,0,320
#
# 3U,4608,FOC,3385,CSX,3371,,0,320
#
# 3U,4608,FOC,3385,KHN,3384,,0,320
#
# 3U,4608,HAK,4120,CKG,3393,,0,321
#
# 3U,4608,HAK,4120,CTU,3395,,0,320
#
# 3U,4608,HAN,3199,CKG,3393,,0,320
#
# 3U,4608,HET,6345,CGO,3375,,0,320
#
# 3U,4608,HET,6345,CIF,6342,,0,320
#
# 3U,4608,HET,6345,CTU,3395,,0,320
#
# 3U,4608,HET,6345,KHN,3384,,0,319
#
# 3U,4608,HET,6345,TNA,4108,,0,319
#
# 3U,4608,HFE,3389,CTU,3395,,0,320
#
# 3U,4608,HGH,3386,CGO,3375,,0,320
#
# 3U,4608,HGH,3386,CKG,3393,,0,320
#
# 3U,4608,HGH,3386,CTU,3395,,0,320
#
# 3U,4608,HGH,3386,DLC,3404,,0,320
#
# 3U,4608,HKG,3077,BHY,6351,,0,320
#
# 3U,4608,HKG,3077,CTU,3395,,0,320
#
# 3U,4608,HKT,3179,CKG,3393,,0,320
#
# 3U,4608,HKT,3179,CTU,3395,,0,321
#
# 3U,4608,HRB,3400,CGO,3375,,0,320
#
# 3U,4608,HRB,3400,DLC,3404,,0,320
#
# 3U,4608,HRB,3400,NKG,3388,,0,320
#
# 3U,4608,HRB,3400,SJW,6347,,0,319
#
# 3U,4608,HRB,3400,TNA,4108,,0,320
#
# 3U,4608,HRB,3400,WNZ,6392,,0,320
#
# 3U,4608,HRB,3400,WUH,3376,,0,319
#
# 3U,4608,HRB,3400,XUZ,4149,,0,320
#
# 3U,4608,INC,4085,CKG,3393,,0,320
#
# 3U,4608,INC,4085,CTU,3395,,0,320
#
# 3U,4608,INC,4085,KWL,3372,,0,320
#
# 3U,4608,INC,4085,XIY,3379,,0,319
#
# 3U,4608,JIQ,\N,CKG,3393,,0,ERJ
#
# 3U,4608,JJN,6386,KWE,3394,,0,ERJ
#
# 3U,4608,JZH,4301,CKG,3393,,0,319
#
# 3U,4608,JZH,4301,CTU,3395,,0,319
#
# 3U,4608,KHN,3384,CKG,3393,,0,320
#
# 3U,4608,KHN,3384,CTU,3395,,0,320
#
# 3U,4608,KHN,3384,FOC,3385,,0,320
#
# 3U,4608,KHN,3384,HET,6345,,0,319
#
# 3U,4608,KHN,3384,NGB,3387,,0,320
#
# 3U,4608,KHN,3384,SYX,4030,,0,319
#
# 3U,4608,KMG,3382,CGO,3375,,0,320
#
# 3U,4608,KMG,3382,CKG,3393,,0,320
#
# 3U,4608,KMG,3382,CTU,3395,,0,320
#
# 3U,4608,KMG,3382,KWE,3394,,0,320
#
# 3U,4608,KMG,3382,NGB,3387,,0,320
#
# 3U,4608,KMG,3382,TNA,4108,,0,320
#
# 3U,4608,KMG,3382,TPE,2276,,0,320
#
# 3U,4608,KMG,3382,WXN,6403,,0,320
#
# 3U,4608,KMG,3382,XMN,3383,,0,320
#
# 3U,4608,KMG,3382,XNN,6366,,0,320
#
# 3U,4608,KMG,3382,XUZ,4149,,0,320
#
# 3U,4608,KOW,6379,CTU,3395,,0,319 320
#
# 3U,4608,KOW,6379,XMN,3383,,0,319 320
#
# 3U,4608,KWE,3394,CTU,3395,,0,320 319
#
# 3U,4608,KWE,3394,JJN,6386,,0,ERJ
#
# 3U,4608,KWE,3394,KMG,3382,,0,320
#
# 3U,4608,KWE,3394,MIG,6400,,0,ERJ
#
# 3U,4608,KWE,3394,NNG,3373,,0,ERJ
#
# 3U,4608,KWE,3394,WNZ,6392,,0,320
#
# 3U,4608,KWL,3372,CKG,3393,,0,320
#
# 3U,4608,KWL,3372,CTU,3395,,0,320 319
#
# 3U,4608,KWL,3372,CZX,4109,,0,320
#
# 3U,4608,KWL,3372,INC,4085,,0,320
#
# 3U,4608,KWL,3372,SYX,4030,,0,320
#
# 3U,4608,LHW,6431,CTU,3395,,0,320
#
# 3U,4608,LHW,6431,LXA,4097,,0,319
#
# 3U,4608,LHW,6431,MIG,6400,,0,ERJ
#
# 3U,4608,LHW,6431,XIY,3379,,0,319
#
# 3U,4608,LJG,4033,CTU,3395,,0,319
#
# 3U,4608,LXA,4097,CKG,3393,,0,319
#
# 3U,4608,LXA,4097,CTU,3395,,0,319
#
# 3U,4608,LXA,4097,LHW,6431,,0,319
#
# 3U,4608,LXA,4097,XNN,6366,,0,319
#
# 3U,4608,LYI,6385,CTU,3395,,0,319
#
# 3U,4608,LYI,6385,TNA,4108,,0,319
#
# 3U,4608,MIG,6400,CKG,3393,,0,ERJ
#
# 3U,4608,MIG,6400,CSX,3371,,0,ERJ
#
# 3U,4608,MIG,6400,KWE,3394,,0,ERJ
#
# 3U,4608,MIG,6400,LHW,6431,,0,ERJ
#
# 3U,4608,MIG,6400,SJW,6347,,0,ERJ
#
# 3U,4608,MIG,6400,TYN,3369,,0,ERJ
#
# 3U,4608,MIG,6400,WUH,3376,,0,ERJ
#
# 3U,4608,NGB,3387,CKG,3393,,0,320 319
#
# 3U,4608,NGB,3387,KHN,3384,,0,320
#
# 3U,4608,NGB,3387,KMG,3382,,0,320
#
# 3U,4608,NKG,3388,CKG,3393,,0,320
#
# 3U,4608,NKG,3388,CTU,3395,,0,320
#
# 3U,4608,NKG,3388,HRB,3400,,0,320
#
# 3U,4608,NNG,3373,CTU,3395,,0,320
#
# 3U,4608,NNG,3373,KWE,3394,,0,ERJ
#
# 3U,4608,NNG,3373,SGN,3205,,0,320
#
# 3U,4608,NNG,3373,WUH,3376,,0,319
#
# 3U,4608,NTG,5475,WUH,3376,,0,319
#
# 3U,4608,PEK,3364,CKG,3393,,0,319 330 321 320
#
# 3U,4608,PEK,3364,CTU,3395,,0,320 321 330
#
# 3U,4608,PEK,3364,WXN,6403,,0,320
#
# 3U,4608,PEK,3364,ZHY,\N,,0,320
#
# 3U,4608,PVG,3406,CKG,3393,,0,320
#
# 3U,4608,PVG,3406,CTU,3395,,0,330 321
#
# 3U,4608,RMQ,\N,CTU,3395,,0,321
#
# 3U,4608,SGN,3205,NNG,3373,,0,320
#
# 3U,4608,SHE,4144,TSN,3368,,0,320
#
# 3U,4608,SHE,4144,TYN,3369,,0,ERJ
#
# 3U,4608,SJW,6347,CTU,3395,,0,319
#
# 3U,4608,SJW,6347,HRB,3400,,0,319
#
# 3U,4608,SJW,6347,MIG,6400,,0,ERJ
#
# 3U,4608,SYX,4030,CKG,3393,,0,320
#
# 3U,4608,SYX,4030,CTU,3395,,0,320
#
# 3U,4608,SYX,4030,KHN,3384,,0,319
#
# 3U,4608,SYX,4030,KWL,3372,,0,320
#
# 3U,4608,SYX,4030,TNA,4108,,0,320
#
# 3U,4608,SYX,4030,WNZ,6392,,0,320
#
# 3U,4608,SYX,4030,ZUH,6355,,0,320
#
# 3U,4608,SZX,3374,CKG,3393,,0,320
#
# 3U,4608,SZX,3374,CTU,3395,,0,320 319
#
# 3U,4608,TAO,3390,CTU,3395,,0,320
#
# 3U,4608,THQ,\N,XIY,3379,,0,ERJ
#
# 3U,4608,TNA,4108,CGQ,4380,,0,320
#
# 3U,4608,TNA,4108,CKG,3393,,0,319
#
# 3U,4608,TNA,4108,CTU,3395,,0,320
#
# 3U,4608,TNA,4108,DLC,3404,,0,320
#
# 3U,4608,TNA,4108,HET,6345,,0,319
#
# 3U,4608,TNA,4108,HRB,3400,,0,320
#
# 3U,4608,TNA,4108,KMG,3382,,0,320
#
# 3U,4608,TNA,4108,LYI,6385,,0,319
#
# 3U,4608,TNA,4108,SYX,4030,,0,320
#
# 3U,4608,TPE,2276,KMG,3382,,0,320
#
# 3U,4608,TSA,2275,CKG,3393,,0,320
#
# 3U,4608,TSA,2275,CTU,3395,,0,321
#
# 3U,4608,TSN,3368,CTU,3395,,0,320
#
# 3U,4608,TSN,3368,SHE,4144,,0,320
#
# 3U,4608,TYN,3369,CTU,3395,,0,321
#
# 3U,4608,TYN,3369,MIG,6400,,0,ERJ
#
# 3U,4608,TYN,3369,SHE,4144,,0,ERJ
#
# 3U,4608,URC,3399,CGO,3375,,0,320
#
# 3U,4608,URC,3399,CKG,3393,,0,320
#
# 3U,4608,URC,3399,CTU,3395,,0,319
#
# 3U,4608,WNZ,6392,CKG,3393,,0,320
#
# 3U,4608,WNZ,6392,CTU,3395,,0,319
#
# 3U,4608,WNZ,6392,HRB,3400,,0,320
#
# 3U,4608,WNZ,6392,KWE,3394,,0,320
#
# 3U,4608,WNZ,6392,SYX,4030,,0,320
#
# 3U,4608,WUH,3376,CKG,3393,,0,320
#
# 3U,4608,WUH,3376,CTU,3395,,0,319
#
# 3U,4608,WUH,3376,HRB,3400,,0,319
#
# 3U,4608,WUH,3376,MIG,6400,,0,ERJ
#
# 3U,4608,WUH,3376,NNG,3373,,0,319
#
# 3U,4608,WUH,3376,NTG,5475,,0,319
#
# 3U,4608,WUX,6390,CKG,3393,,0,320
#
# 3U,4608,WUX,6390,CTU,3395,,0,320
#
# 3U,4608,WXN,6403,KMG,3382,,0,320
#
# 3U,4608,WXN,6403,PEK,3364,,0,320
#
# 3U,4608,XIC,3396,CTU,3395,,0,320
#
# 3U,4608,XIY,3379,CKG,3393,,0,320 ERJ
#
# 3U,4608,XIY,3379,CTU,3395,,0,320 319
#
# 3U,4608,XIY,3379,INC,4085,,0,319
#
# 3U,4608,XIY,3379,LHW,6431,,0,319
#
# 3U,4608,XIY,3379,THQ,\N,,0,ERJ
#
# 3U,4608,XIY,3379,XNN,6366,,0,319
#
# 3U,4608,XIY,3379,ZHY,\N,,0,320
#
# 3U,4608,XMN,3383,CSX,3371,,0,320
#
# 3U,4608,XMN,3383,CTU,3395,,0,320
#
# 3U,4608,XMN,3383,KMG,3382,,0,320
#
# 3U,4608,XMN,3383,KOW,6379,,0,319 320
#
# 3U,4608,XNN,6366,CKG,3393,,0,320
#
# 3U,4608,XNN,6366,CTU,3395,,0,319
#
# 3U,4608,XNN,6366,KMG,3382,,0,320
#
# 3U,4608,XNN,6366,LXA,4097,,0,319
#
# 3U,4608,XNN,6366,XIY,3379,,0,319
#
# 3U,4608,XUZ,4149,CTU,3395,,0,319
#
# 3U,4608,XUZ,4149,DLC,3404,,0,319
#
# 3U,4608,XUZ,4149,HRB,3400,,0,320
#
# 3U,4608,XUZ,4149,KMG,3382,,0,320
#
# 3U,4608,YIH,6361,CKG,3393,,0,320
#
# 3U,4608,YIH,6361,CTU,3395,,0,320
#
# 3U,4608,ZHY,\N,PEK,3364,,0,320
#
# 3U,4608,ZHY,\N,XIY,3379,,0,320
#
# 3U,4608,ZUH,6355,CZX,4109,,0,320
#
# 3U,4608,ZUH,6355,SYX,4030,,0,320
#
# 3W,2246,BGW,4130,VIE,1613,,0,M80
#
# 3W,2246,VIE,1613,BGW,4130,,0,M80
#
# 3Z,\N,AET,6839,FAI,3832,,0,PAG
#
# 3Z,\N,AKP,6712,AET,6839,,0,PAG
#
# 3Z,\N,ARC,6729,WBQ,7115,,0,PAG
#
# 3Z,\N,BTT,3417,AKP,6712,,0,PAG
#
# 3Z,\N,EAA,7106,FAI,3832,,0,PAG
#
# 3Z,\N,FAI,3832,BTT,3417,,0,PAG
#
# 3Z,\N,FAI,3832,EAA,7106,,0,PAG
#
# 3Z,\N,FAI,3832,FYU,3420,,0,PAG
#
# 3Z,\N,FAI,3832,LMA,\N,,0,PAG
#
# 3Z,\N,FYU,3420,VEE,7114,,0,PAG
#
# 3Z,\N,LMA,\N,FAI,3832,,0,PAG
#
# 3Z,\N,VEE,7114,ARC,6729,,0,PAG
#
# 3Z,\N,WBQ,7115,FAI,3832,,0,PAG
#
# 4C,411,ADZ,2749,BOG,2709,,0,73W
#
# 4C,411,APO,5476,EOH,2729,,0,DH2
#
# 4C,411,AXM,2705,BOG,2709,,0,DH2
#
# 4C,411,BAQ,2710,BOG,2709,,0,73W
#
# 4C,411,BGA,2708,BOG,2709,,0,DH4 73W
#
# 4C,411,BGA,2708,CUC,2713,,0,DH2
#
# 4C,411,BGA,2708,EOH,2729,,0,DH2
#
# 4C,411,BOG,2709,ADZ,2749,,0,73W
#
# 4C,411,BOG,2709,AXM,2705,,0,DH2
#
# 4C,411,BOG,2709,BAQ,2710,,0,73W
#
# 4C,411,BOG,2709,BGA,2708,,0,DH4 73W
#
# 4C,411,BOG,2709,CLO,2715,,0,73W
#
# 4C,411,BOG,2709,CTG,2714,,0,73W
#
# 4C,411,BOG,2709,CUC,2713,,0,DH4
#
# 4C,411,BOG,2709,EYP,6055,,0,DH4
#
# 4C,411,BOG,2709,FLA,2719,,0,DH2
#
# 4C,411,BOG,2709,FLL,3533,,0,73W
#
# 4C,411,BOG,2709,IBE,2724,,0,DH2
#
# 4C,411,BOG,2709,LET,2728,,0,73W
#
# 4C,411,BOG,2709,MDE,2745,,0,73W
#
# 4C,411,BOG,2709,MTR,2731,,0,73W
#
# 4C,411,BOG,2709,MZL,2733,,0,DH2
#
# 4C,411,BOG,2709,NVA,2734,,0,DH2 DH4
#
# 4C,411,BOG,2709,PEI,2739,,0,DH2 DH4
#
# 4C,411,BOG,2709,PPN,2741,,0,DH4
#
# 4C,411,BOG,2709,PUU,2706,,0,DH2
#
# 4C,411,BOG,2709,SMR,2748,,0,73W
#
# 4C,411,BOG,2709,UIB,2753,,0,DH4
#
# 4C,411,BOG,2709,VUP,2755,,0,73W
#
# 4C,411,BOG,2709,VVC,2756,,0,DH2
#
# 4C,411,CLO,2715,BOG,2709,,0,73W
#
# 4C,411,CTG,2714,BOG,2709,,0,73W
#
# 4C,411,CUC,2713,BGA,2708,,0,DH2
#
# 4C,411,CUC,2713,BOG,2709,,0,DH4
#
# 4C,411,EOH,2729,APO,5476,,0,DH2
#
# 4C,411,EOH,2729,BGA,2708,,0,DH2
#
# 4C,411,EOH,2729,IBE,2724,,0,DH2
#
# 4C,411,EOH,2729,MTR,2731,,0,DH2
#
# 4C,411,EOH,2729,PEI,2739,,0,DH2
#
# 4C,411,EOH,2729,UIB,2753,,0,DH2
#
# 4C,411,EYP,6055,BOG,2709,,0,DH4
#
# 4C,411,FLA,2719,BOG,2709,,0,DH2
#
# 4C,411,FLL,3533,BOG,2709,,0,73W
#
# 4C,411,IBE,2724,BOG,2709,,0,DH2
#
# 4C,411,IBE,2724,EOH,2729,,0,DH2
#
# 4C,411,LET,2728,BOG,2709,,0,73W
#
# 4C,411,MDE,2745,BOG,2709,,0,73W
#
# 4C,411,MTR,2731,BOG,2709,,0,73W
#
# 4C,411,MTR,2731,EOH,2729,,0,DH2
#
# 4C,411,MZL,2733,BOG,2709,,0,DH2
#
# 4C,411,NVA,2734,BOG,2709,,0,DH2 DH4
#
# 4C,411,PEI,2739,BOG,2709,,0,DH2 DH4
#
# 4C,411,PEI,2739,EOH,2729,,0,DH2
#
# 4C,411,PPN,2741,BOG,2709,,0,DH4
#
# 4C,411,PUU,2706,BOG,2709,,0,DH2
#
# 4C,411,SMR,2748,BOG,2709,,0,73W
#
# 4C,411,UIB,2753,BOG,2709,,0,DH4
#
# 4C,411,UIB,2753,EOH,2729,,0,DH2
#
# 4C,411,VUP,2755,BOG,2709,,0,73W
#
# 4C,411,VVC,2756,BOG,2709,,0,DH2
#
# 4D,442,CAI,1128,TLV,1590,,0,735
#
# 4D,442,TLV,1590,CAI,1128,,0,735
#
# 4E,\N,MCG,5965,NIB,7214,,0,PAG
#
# 4E,\N,MCG,5965,TCT,7215,,0,PAG
#
# 4E,\N,NIB,7214,MCG,5965,,0,PAG
#
# 4E,\N,TCT,7215,TLJ,3423,,0,PAG
#
# 4E,\N,TLJ,3423,MCG,5965,,0,PAG
#
# 4G,2524,EGO,6156,NUX,4364,,0,TU5
#
# 4G,2524,EYK,\N,VKO,2988,,0,YK2
#
# 4G,2524,KUF,4118,NUX,4364,,0,YK2
#
# 4G,2524,KUF,4118,VKO,2988,,0,YK2
#
# 4G,2524,LED,2948,VKO,2988,,0,YK2
#
# 4G,2524,NCU,6151,VKO,2988,,0,73G
#
# 4G,2524,NUX,4364,EGO,6156,,0,TU5
#
# 4G,2524,NUX,4364,KUF,4118,,0,YK2
#
# 4G,2524,NUX,4364,VKO,2988,,0,73G YK2
#
# 4G,2524,NYM,6143,OVS,6140,,0,YK4
#
# 4G,2524,NYM,6143,VKO,2988,,0,73G
#
# 4G,2524,OVS,6140,NYM,6143,,0,YK4
#
# 4G,2524,OVS,6140,VKO,2988,,0,YK2
#
# 4G,2524,UCT,4368,VKO,2988,,0,YK2
#
# 4G,2524,ULV,\N,VKO,2988,,0,YK2
#
# 4G,2524,VKO,2988,EYK,\N,,0,YK2
#
# 4G,2524,VKO,2988,KUF,4118,,0,YK2
#
# 4G,2524,VKO,2988,LED,2948,,0,YK2
#
# 4G,2524,VKO,2988,NCU,6151,,0,73G
#
# 4G,2524,VKO,2988,NUX,4364,,0,73G YK2
#
# 4G,2524,VKO,2988,NYM,6143,,0,73G
#
# 4G,2524,VKO,2988,OVS,6140,,0,YK2
#
# 4G,2524,VKO,2988,UCT,4368,,0,YK2
#
# 4G,2524,VKO,2988,ULV,\N,,0,YK2
#
# 4H,8463,BKK,3885,DAC,3076,,0,M83
#
# 4H,8463,CCU,3043,CGP,3069,,0,M83
#
# 4H,8463,CCU,3043,DAC,3076,,0,DH8
#
# 4H,8463,CGP,3069,CCU,3043,,0,M83
#
# 4H,8463,CGP,3069,DAC,3076,,0,DH8
#
# 4H,8463,CXB,3068,DAC,3076,,0,DH8
#
# 4H,8463,DAC,3076,BKK,3885,,0,M83
#
# 4H,8463,DAC,3076,CCU,3043,,0,DH8
#
# 4H,8463,DAC,3076,CGP,3069,,0,DH8
#
# 4H,8463,DAC,3076,CXB,3068,,0,DH8
#
# 4H,8463,DAC,3076,DXB,2188,,0,M83
#
# 4H,8463,DAC,3076,JSR,3071,,0,DH8
#
# 4H,8463,DAC,3076,KTM,3125,,0,M83
#
# 4H,8463,DAC,3076,KUL,3304,,0,M83
#
# 4H,8463,DAC,3076,ZYL,3074,,0,DH8
#
# 4H,8463,DXB,2188,DAC,3076,,0,M83
#
# 4H,8463,DXB,2188,LGW,502,,0,M83
#
# 4H,8463,JSR,3071,DAC,3076,,0,DH8
#
# 4H,8463,KTM,3125,DAC,3076,,0,M83
#
# 4H,8463,KUL,3304,DAC,3076,,0,M83
#
# 4H,8463,LGW,502,DXB,2188,,0,M83
#
# 4H,8463,ZYL,3074,DAC,3076,,0,DH8
#
# 4J,\N,ALA,2908,DYU,2979,,0,738
#
# 4J,\N,DME,4029,DYU,2979,Y,0,738
#
# 4J,\N,DME,4029,TJU,7563,,0,738
#
# 4J,\N,DXB,2188,DYU,2979,,0,738
#
# 4J,\N,DXB,2188,JED,2072,,0,738
#
# 4J,\N,DYU,2979,ALA,2908,,0,738
#
# 4J,\N,DYU,2979,DME,4029,Y,0,738
#
# 4J,\N,DYU,2979,DXB,2188,,0,738
#
# 4J,\N,DYU,2979,FRU,2912,,0,738
#
# 4J,\N,DYU,2979,IST,1701,,0,738
#
# 4J,\N,DYU,2979,KJA,4374,,0,738
#
# 4J,\N,DYU,2979,KRR,2960,,0,738
#
# 4J,\N,DYU,2979,KUF,4118,,0,738
#
# 4J,\N,DYU,2979,KZN,2990,,0,738
#
# 4J,\N,DYU,2979,LED,2948,,0,738
#
# 4J,\N,DYU,2979,OVB,4078,,0,738
#
# 4J,\N,DYU,2979,REN,2991,,0,738
#
# 4J,\N,DYU,2979,SIP,2942,,0,738
#
# 4J,\N,DYU,2979,SVX,2975,,0,738
#
# 4J,\N,DYU,2979,URC,3399,,0,738
#
# 4J,\N,FRA,340,DYU,2979,,0,738
#
# 4J,\N,FRU,2912,DYU,2979,,0,738
#
# 4J,\N,FRU,2912,LED,2948,,0,738
#
# 4J,\N,HMA,6138,LBD,6147,,0,738
#
# 4J,\N,IST,1701,DYU,2979,,0,738
#
# 4J,\N,JED,2072,DXB,2188,,0,738
#
# 4J,\N,KJA,4374,DYU,2979,,0,738
#
# 4J,\N,KJA,4374,LBD,6147,,0,738
#
# 4J,\N,KUF,4118,DYU,2979,,0,738
#
# 4J,\N,KUF,4118,LBD,6147,,0,738
#
# 4J,\N,KZN,2990,DYU,2979,,0,738
#
# 4J,\N,KZN,2990,LBD,6147,,0,738
#
# 4J,\N,LBD,6147,HMA,6138,,0,738
#
# 4J,\N,LBD,6147,IKT,2937,,0,738
#
# 4J,\N,LBD,6147,KJA,4374,,0,738
#
# 4J,\N,LBD,6147,KUF,4118,,0,738
#
# 4J,\N,LBD,6147,KZN,2990,,0,738
#
# 4J,\N,LBD,6147,LED,2948,,0,738
#
# 4J,\N,LBD,6147,NJC,2972,,0,738
#
# 4J,\N,LBD,6147,OVB,4078,,0,738
#
# 4J,\N,LBD,6147,PEE,2973,,0,738
#
# 4J,\N,LBD,6147,REN,2991,,0,738
#
# 4J,\N,LBD,6147,SGC,2974,,0,738
#
# 4J,\N,LBD,6147,SVX,2975,,0,738
#
# 4J,\N,LBD,6147,TJM,4111,,0,738
#
# 4J,\N,LBD,6147,TJU,7563,,0,738
#
# 4J,\N,LED,2948,DYU,2979,,0,738
#
# 4J,\N,LED,2948,LBD,6147,,0,738
#
# 4J,\N,NJC,2972,LBD,6147,,0,738
#
# 4J,\N,OVB,4078,DYU,2979,,0,738
#
# 4J,\N,OVB,4078,LBD,6147,,0,738
#
# 4J,\N,PEE,2973,LBD,6147,,0,738
#
# 4J,\N,REN,2991,LBD,6147,,0,738
#
# 4J,\N,SGC,2974,LBD,6147,,0,738
#
# 4J,\N,SIP,2942,DYU,2979,,0,738
#
# 4J,\N,SVX,2975,DYU,2979,,0,738
#
# 4J,\N,SVX,2975,LBD,6147,,0,738
#
# 4J,\N,TJM,4111,LBD,6147,,0,738
#
# 4J,\N,TJU,7563,DME,4029,,0,738
#
# 4J,\N,TJU,7563,LBD,6147,,0,738
#
# 4J,\N,URC,3399,DYU,2979,,0,738
#
# 4K,29,YGZ,5498,YRB,128,,0,DHT
#
# 4K,29,YRB,128,YGZ,5498,,0,DHT
#
# 4L,11873,BUS,3971,HRK,6105,,0,SF3
#
# 4L,11873,GYD,2922,TBS,3973,,0,SFB
#
# 4L,11873,HRK,6105,BUS,3971,,0,SF3
#
# 4L,11873,HRK,6105,KUT,3972,,0,SF3
#
# 4L,11873,HRK,6105,TBS,3973,,0,SF3
#
# 4L,11873,IST,1701,TBS,3973,,0,F70
#
# 4L,11873,KUT,3972,HRK,6105,,0,SF3
#
# 4L,11873,SCO,4367,TBS,3973,,0,SF3
#
# 4L,11873,TBS,3973,DOK,2940,,0,SF3
#
# 4L,11873,TBS,3973,GYD,2922,,0,SFB
#
# 4L,11873,TBS,3973,HRK,6105,,0,SF3
#
# 4L,11873,TBS,3973,IST,1701,,0,F70
#
# 4L,11873,TBS,3973,SCO,4367,,0,SF3
#
# 4L,11873,TBS,3973,TZX,1726,,0,SFB
#
# 4L,11873,TZX,1726,TBS,3973,,0,SFB
#
# 4M,3201,DFW,3670,EZE,3988,Y,0,777
#
# 4M,3201,EZE,3988,DFW,3670,Y,0,777
#
# 4M,3201,EZE,3988,JFK,3797,Y,0,777
#
# 4M,3201,EZE,3988,MIA,3576,,0,763
#
# 4M,3201,EZE,3988,PUJ,1760,,0,763
#
# 4M,3201,JFK,3797,EZE,3988,Y,0,777
#
# 4M,3201,MIA,3576,EZE,3988,,0,763
#
# 4M,3201,MIA,3576,PUJ,1760,,0,763
#
# 4M,3201,PUJ,1760,EZE,3988,,0,763
#
# 4M,3201,PUJ,1760,MIA,3576,,0,763
#
# 4N,341,YDA,42,YEV,54,,0,HS7
#
# 4N,341,YDA,42,YOC,97,,0,HS7
#
# 4N,341,YDA,42,YXY,176,,0,HS7
#
# 4N,341,YEG,49,YXY,176,,0,737
#
# 4N,341,YEV,54,YDA,42,,0,HS7
#
# 4N,341,YEV,54,YOC,97,,0,HS7
#
# 4N,341,YOC,97,YDA,42,,0,HS7
#
# 4N,341,YOC,97,YEV,54,,0,HS7
#
# 4N,341,YVR,156,YXY,176,,0,737
#
# 4N,341,YXY,176,YDA,42,,0,HS7
#
# 4N,341,YXY,176,YVR,156,,0,737
#
# 4N,341,YXY,176,YYC,178,,0,737
#
# 4N,341,YYC,178,YEG,49,,0,737
#
# 4O,\N,ACA,1783,MEX,1824,,0,320
#
# 4O,\N,ACA,1783,TLC,1850,,0,320
#
# 4O,\N,CEN,1794,MEX,1824,,0,320
#
# 4O,\N,CJS,1796,MEX,1824,,0,320
#
# 4O,\N,CME,1789,MEX,1824,,0,320
#
# 4O,\N,CTM,1793,MEX,1824,,0,320
#
# 4O,\N,CUL,1792,MEX,1824,,0,320
#
# 4O,\N,CUN,1852,GDL,1804,,0,320
#
# 4O,\N,CUN,1852,MEX,1824,,0,320
#
# 4O,\N,CUN,1852,MTY,1825,,0,320
#
# 4O,\N,CUN,1852,TLC,1850,,0,320
#
# 4O,\N,CUU,1797,MEX,1824,,0,320
#
# 4O,\N,GDL,1804,CUN,1852,,0,320
#
# 4O,\N,GDL,1804,MEX,1824,,0,320
#
# 4O,\N,GDL,1804,MTY,1825,,0,320
#
# 4O,\N,GDL,1804,SJD,1840,,0,320
#
# 4O,\N,GDL,1804,TIJ,1847,,0,320
#
# 4O,\N,GDL,1804,TLC,1850,,0,320
#
# 4O,\N,HMO,1807,MEX,1824,,0,320
#
# 4O,\N,HUX,1786,MEX,1824,,0,320
#
# 4O,\N,LMM,1814,MEX,1824,,0,320
#
# 4O,\N,MEX,1824,ACA,1783,,0,320
#
# 4O,\N,MEX,1824,CEN,1794,,0,320
#
# 4O,\N,MEX,1824,CJS,1796,,0,320
#
# 4O,\N,MEX,1824,CME,1789,,0,320
#
# 4O,\N,MEX,1824,CTM,1793,,0,320
#
# 4O,\N,MEX,1824,CUL,1792,,0,320
#
# 4O,\N,MEX,1824,CUN,1852,,0,320
#
# 4O,\N,MEX,1824,CUU,1797,,0,320
#
# 4O,\N,MEX,1824,GDL,1804,,0,320
#
# 4O,\N,MEX,1824,HMO,1807,,0,320
#
# 4O,\N,MEX,1824,HUX,1786,,0,320
#
# 4O,\N,MEX,1824,LMM,1814,,0,320
#
# 4O,\N,MEX,1824,MID,1819,,0,320
#
# 4O,\N,MEX,1824,MTY,1825,,0,320
#
# 4O,\N,MEX,1824,PVR,1836,,0,320
#
# 4O,\N,MEX,1824,SJD,1840,,0,320
#
# 4O,\N,MEX,1824,TAM,1848,,0,320
#
# 4O,\N,MEX,1824,TGZ,1846,,0,320
#
# 4O,\N,MEX,1824,TIJ,1847,,0,320
#
# 4O,\N,MEX,1824,VER,1854,,0,320
#
# 4O,\N,MEX,1824,VSA,1853,,0,320
#
# 4O,\N,MEX,1824,ZIH,1856,,0,320
#
# 4O,\N,MID,1819,MEX,1824,,0,320
#
# 4O,\N,MTY,1825,CUN,1852,,0,320
#
# 4O,\N,MTY,1825,GDL,1804,,0,320
#
# 4O,\N,MTY,1825,MEX,1824,,0,320
#
# 4O,\N,MTY,1825,TLC,1850,,0,320
#
# 4O,\N,PVR,1836,MEX,1824,,0,320
#
# 4O,\N,PVR,1836,TLC,1850,,0,320
#
# 4O,\N,SJD,1840,GDL,1804,,0,320
#
# 4O,\N,SJD,1840,MEX,1824,,0,320
#
# 4O,\N,SJD,1840,TLC,1850,,0,320
#
# 4O,\N,TAM,1848,MEX,1824,,0,320
#
# 4O,\N,TGZ,1846,MEX,1824,,0,320
#
# 4O,\N,TIJ,1847,GDL,1804,,0,320
#
# 4O,\N,TIJ,1847,MEX,1824,,0,320
#
# 4O,\N,TLC,1850,ACA,1783,,0,320
#
# 4O,\N,TLC,1850,CUN,1852,,0,320
#
# 4O,\N,TLC,1850,GDL,1804,,0,320
#
# 4O,\N,TLC,1850,MTY,1825,,0,320
#
# 4O,\N,TLC,1850,PVR,1836,,0,320
#
# 4O,\N,TLC,1850,SJD,1840,,0,320
#
# 4O,\N,TLC,1850,ZIH,1856,,0,320
#
# 4O,\N,VER,1854,MEX,1824,,0,320
#
# 4O,\N,VSA,1853,MEX,1824,,0,320
#
# 4O,\N,ZIH,1856,MEX,1824,,0,320
#
# 4O,\N,ZIH,1856,TLC,1850,,0,320
#
# 4Q,10758,DXB,2188,KBL,2050,,0,320
#
# 4Q,10758,FRA,340,KBL,2050,,0,343
#
# 4Q,10758,KBL,2050,DXB,2188,,0,320
#
# 4Q,10758,KBL,2050,FRA,340,,0,343
#
# 4T,1401,BSL,4053,HRG,1130,,0,320
#
# 4T,1401,BSL,4053,RMF,4197,,0,320
#
# 4T,1401,BSL,4053,SSH,4057,,0,320
#
# 4T,1401,GVA,1665,PRN,1742,,0,320
#
# 4T,1401,HRG,1130,BSL,4053,,0,320
#
# 4T,1401,HRG,1130,SSH,4057,,0,320
#
# 4T,1401,HRG,1130,ZRH,1678,,0,320
#
# 4T,1401,PRN,1742,GVA,1665,,0,320
#
# 4T,1401,PRN,1742,ZRH,1678,,0,320
#
# 4T,1401,RMF,4197,SSH,4057,,0,320
#
# 4T,1401,RMF,4197,ZRH,1678,,0,320
#
# 4T,1401,SSH,4057,BSL,4053,,0,320
#
# 4T,1401,SSH,4057,ZRH,1678,,0,320
#
# 4T,1401,ZRH,1678,HRG,1130,,0,320
#
# 4T,1401,ZRH,1678,PRN,1742,,0,320
#
# 4T,1401,ZRH,1678,RMF,4197,,0,320
#
# 4T,1401,ZRH,1678,SSH,4057,,0,320
#
# 4U,2548,AGP,1230,STR,350,,0,319
#
# 4U,2548,ARN,737,CGN,344,,0,319
#
# 4U,2548,ARN,737,SXF,337,,0,319
#
# 4U,2548,ATH,3941,CGN,344,,0,319
#
# 4U,2548,ATH,3941,STR,350,,0,319
#
# 4U,2548,AYT,1688,CGN,344,,0,319
#
# 4U,2548,BBU,1650,CGN,344,,0,319
#
# 4U,2548,BBU,1650,STR,350,,0,319
#
# 4U,2548,BBU,1650,SXF,337,,0,319
#
# 4U,2548,BCN,1218,CGN,344,,0,319
#
# 4U,2548,BCN,1218,HAJ,352,,0,319
#
# 4U,2548,BCN,1218,STR,350,,0,319
#
# 4U,2548,BEG,1739,CGN,344,,0,319
#
# 4U,2548,BEG,1739,STR,350,,0,319
#
# 4U,2548,BIA,1321,CGN,344,,0,319
#
# 4U,2548,BIA,1321,SXF,337,,0,319
#
# 4U,2548,BLQ,1538,CGN,344,,0,319
#
# 4U,2548,BRI,1501,CGN,344,,0,319
#
# 4U,2548,BRI,1501,HAJ,352,,0,319
#
# 4U,2548,BRI,1501,STR,350,,0,319
#
# 4U,2548,BUD,1489,CGN,344,,0,319
#
# 4U,2548,BUD,1489,STR,350,,0,319
#
# 4U,2548,CAG,1519,CGN,344,,0,319
#
# 4U,2548,CAG,1519,STR,350,,0,319
#
# 4U,2548,CGN,344,ARN,737,,0,319
#
# 4U,2548,CGN,344,ATH,3941,,0,319
#
# 4U,2548,CGN,344,AYT,1688,,0,319
#
# 4U,2548,CGN,344,BBU,1650,,0,319
#
# 4U,2548,CGN,344,BCN,1218,,0,319
#
# 4U,2548,CGN,344,BEG,1739,,0,319
#
# 4U,2548,CGN,344,BIA,1321,,0,319
#
# 4U,2548,CGN,344,BLQ,1538,,0,319
#
# 4U,2548,CGN,344,BRI,1501,,0,319
#
# 4U,2548,CGN,344,BUD,1489,,0,319
#
# 4U,2548,CGN,344,CAG,1519,,0,319
#
# 4U,2548,CGN,344,CLY,1322,,0,319
#
# 4U,2548,CGN,344,CPH,609,,0,319
#
# 4U,2548,CGN,344,DBV,1200,,0,319
#
# 4U,2548,CGN,344,DRS,338,,0,319
#
# 4U,2548,CGN,344,DUB,599,,0,319
#
# 4U,2548,CGN,344,EDI,535,,0,319
#
# 4U,2548,CGN,344,FAO,1626,,0,319
#
# 4U,2548,CGN,344,FCO,1555,,0,319
#
# 4U,2548,CGN,344,FDH,382,,0,319
#
# 4U,2548,CGN,344,HER,1452,,0,319
#
# 4U,2548,CGN,344,IBZ,1225,,0,319
#
# 4U,2548,CGN,344,KLU,4322,,0,319
#
# 4U,2548,CGN,344,KVA,1462,,0,319
#
# 4U,2548,CGN,344,LEJ,348,,0,319
#
# 4U,2548,CGN,344,LIS,1638,,0,319
#
# 4U,2548,CGN,344,LPA,1054,,0,319
#
# 4U,2548,CGN,344,MAN,478,,0,319
#
# 4U,2548,CGN,344,MRS,1353,,0,319
#
# 4U,2548,CGN,344,MUC,346,,0,319
#
# 4U,2548,CGN,344,MXP,1524,,0,319
#
# 4U,2548,CGN,344,NCE,1354,,0,319
#
# 4U,2548,CGN,344,PMI,3998,,0,319
#
# 4U,2548,CGN,344,PRG,1587,,0,319
#
# 4U,2548,CGN,344,PSA,1562,,0,319
#
# 4U,2548,CGN,344,RLG,772,,0,319
#
# 4U,2548,CGN,344,SAW,4317,,0,319
#
# 4U,2548,CGN,344,SJJ,1646,,0,319
#
# 4U,2548,CGN,344,SKG,1486,,0,319
#
# 4U,2548,CGN,344,SOF,1194,,0,319
#
# 4U,2548,CGN,344,SPU,1206,,0,319
#
# 4U,2548,CGN,344,STN,548,,0,319
#
# 4U,2548,CGN,344,SUF,1508,,0,319
#
# 4U,2548,CGN,344,SXF,337,,0,319
#
# 4U,2548,CGN,344,SZG,1612,,0,319
#
# 4U,2548,CGN,344,TFS,1056,,0,319
#
# 4U,2548,CGN,344,TLV,1590,,0,319
#
# 4U,2548,CGN,344,TSF,1539,,0,319
#
# 4U,2548,CGN,344,VIE,1613,,0,319
#
# 4U,2548,CGN,344,VKO,2988,,0,319
#
# 4U,2548,CGN,344,VRN,1550,,0,319
#
# 4U,2548,CGN,344,ZAD,1209,,0,319
#
# 4U,2548,CGN,344,ZAG,1208,,0,319
#
# 4U,2548,CGN,344,ZRH,1678,,0,319
#
# 4U,2548,CLY,1322,CGN,344,,0,319
#
# 4U,2548,CPH,609,CGN,344,,0,319
#
# 4U,2548,CTA,1509,HAJ,352,,0,319
#
# 4U,2548,DBV,1200,CGN,344,,0,319
#
# 4U,2548,DBV,1200,HAJ,352,,0,319
#
# 4U,2548,DBV,1200,SXF,337,,0,319
#
# 4U,2548,DRS,338,CGN,344,,0,319
#
# 4U,2548,DRS,338,STR,350,,0,319
#
# 4U,2548,DTM,373,MUC,346,,0,319
#
# 4U,2548,DTM,373,PMI,3998,,0,319
#
# 4U,2548,DTM,373,SPU,1206,,0,319
#
# 4U,2548,DUB,599,CGN,344,,0,319
#
# 4U,2548,EDI,535,CGN,344,,0,319
#
# 4U,2548,FAO,1626,CGN,344,,0,319
#
# 4U,2548,FAO,1626,STR,350,,0,319
#
# 4U,2548,FCO,1555,CGN,344,,0,319
#
# 4U,2548,FCO,1555,HAJ,352,,0,319
#
# 4U,2548,FCO,1555,STR,350,,0,319
#
# 4U,2548,FDH,382,CGN,344,,0,319
#
# 4U,2548,HAJ,352,BCN,1218,,0,319
#
# 4U,2548,HAJ,352,BRI,1501,,0,319
#
# 4U,2548,HAJ,352,CTA,1509,,0,319
#
# 4U,2548,HAJ,352,DBV,1200,,0,319
#
# 4U,2548,HAJ,352,FCO,1555,,0,319
#
# 4U,2548,HAJ,352,HER,1452,,0,319
#
# 4U,2548,HAJ,352,MXP,1524,,0,319
#
# 4U,2548,HAJ,352,NAP,1561,,0,319
#
# 4U,2548,HAJ,352,PMI,3998,,0,319
#
# 4U,2548,HAJ,352,PRN,1742,,0,319
#
# 4U,2548,HAJ,352,SPU,1206,,0,319
#
# 4U,2548,HAJ,352,STN,548,,0,319
#
# 4U,2548,HAJ,352,STR,350,,0,319
#
# 4U,2548,HAJ,352,TSF,1539,,0,319
#
# 4U,2548,HAJ,352,VIE,1613,,0,319
#
# 4U,2548,HAJ,352,VKO,2988,,0,319
#
# 4U,2548,HER,1452,CGN,344,,0,319
#
# 4U,2548,HER,1452,HAJ,352,,0,319
#
# 4U,2548,HER,1452,STR,350,,0,319
#
# 4U,2548,HER,1452,SXF,337,,0,319
#
# 4U,2548,IBZ,1225,CGN,344,,0,319
#
# 4U,2548,IBZ,1225,STR,350,,0,319
#
# 4U,2548,KLU,4322,CGN,344,,0,319
#
# 4U,2548,KRK,669,STR,350,,0,319
#
# 4U,2548,KVA,1462,CGN,344,,0,319
#
# 4U,2548,KVA,1462,STR,350,,0,319
#
# 4U,2548,LEJ,348,CGN,344,,0,319
#
# 4U,2548,LEJ,348,STR,350,,0,319
#
# 4U,2548,LIS,1638,CGN,344,,0,319
#
# 4U,2548,LIS,1638,STR,350,,0,319
#
# 4U,2548,LPA,1054,CGN,344,,0,319
#
# 4U,2548,MAN,478,CGN,344,,0,319
#
# 4U,2548,MRS,1353,CGN,344,,0,319
#
# 4U,2548,MST,582,SXF,337,,0,319
#
# 4U,2548,MUC,346,CGN,344,,0,319
#
# 4U,2548,MUC,346,DTM,373,,0,319
#
# 4U,2548,MUC,346,SXF,337,,0,319
#
# 4U,2548,MXP,1524,CGN,344,,0,319
#
# 4U,2548,MXP,1524,HAJ,352,,0,319
#
# 4U,2548,NAP,1561,HAJ,352,,0,319
#
# 4U,2548,NCE,1354,CGN,344,,0,319
#
# 4U,2548,PMI,3998,CGN,344,,0,319
#
# 4U,2548,PMI,3998,DTM,373,,0,319
#
# 4U,2548,PMI,3998,HAJ,352,,0,319
#
# 4U,2548,PMI,3998,STR,350,,0,319
#
# 4U,2548,PRG,1587,CGN,344,,0,319
#
# 4U,2548,PRN,1742,HAJ,352,,0,319
#
# 4U,2548,PRN,1742,STR,350,,0,319
#
# 4U,2548,PRN,1742,SXF,337,,0,319
#
# 4U,2548,PSA,1562,CGN,344,,0,319
#
# 4U,2548,RLG,772,CGN,344,,0,319
#
# 4U,2548,RLG,772,STR,350,,0,319
#
# 4U,2548,SAW,4317,CGN,344,,0,319
#
# 4U,2548,SAW,4317,STR,350,,0,319
#
# 4U,2548,SJJ,1646,CGN,344,,0,319
#
# 4U,2548,SJJ,1646,STR,350,,0,319
#
# 4U,2548,SKG,1486,CGN,344,,0,319
#
# 4U,2548,SKG,1486,STR,350,,0,319
#
# 4U,2548,SOF,1194,CGN,344,,0,319
#
# 4U,2548,SPU,1206,CGN,344,,0,319
#
# 4U,2548,SPU,1206,DTM,373,,0,319
#
# 4U,2548,SPU,1206,HAJ,352,,0,319
#
# 4U,2548,SPU,1206,STR,350,,0,319
#
# 4U,2548,SPU,1206,SXF,337,,0,319
#
# 4U,2548,STN,548,CGN,344,,0,319
#
# 4U,2548,STN,548,HAJ,352,,0,319
#
# 4U,2548,STN,548,STR,350,,0,319
#
# 4U,2548,STR,350,AGP,1230,,0,319
#
# 4U,2548,STR,350,ATH,3941,,0,319
#
# 4U,2548,STR,350,BBU,1650,,0,319
#
# 4U,2548,STR,350,BCN,1218,,0,319
#
# 4U,2548,STR,350,BEG,1739,,0,319
#
# 4U,2548,STR,350,BRI,1501,,0,319
#
# 4U,2548,STR,350,BUD,1489,,0,319
#
# 4U,2548,STR,350,CAG,1519,,0,319
#
# 4U,2548,STR,350,DRS,338,,0,319
#
# 4U,2548,STR,350,FAO,1626,,0,319
#
# 4U,2548,STR,350,FCO,1555,,0,319
#
# 4U,2548,STR,350,HAJ,352,,0,319
#
# 4U,2548,STR,350,HER,1452,,0,319
#
# 4U,2548,STR,350,IBZ,1225,,0,319
#
# 4U,2548,STR,350,KRK,669,,0,319
#
# 4U,2548,STR,350,KVA,1462,,0,319
#
# 4U,2548,STR,350,LEJ,348,,0,319
#
# 4U,2548,STR,350,LIS,1638,,0,319
#
# 4U,2548,STR,350,PMI,3998,,0,319
#
# 4U,2548,STR,350,PRN,1742,,0,319
#
# 4U,2548,STR,350,RLG,772,,0,319
#
# 4U,2548,STR,350,SAW,4317,,0,319
#
# 4U,2548,STR,350,SJJ,1646,,0,319
#
# 4U,2548,STR,350,SKG,1486,,0,319
#
# 4U,2548,STR,350,SPU,1206,,0,319
#
# 4U,2548,STR,350,STN,548,,0,319
#
# 4U,2548,STR,350,SUF,1508,,0,319
#
# 4U,2548,STR,350,SXF,337,,0,319
#
# 4U,2548,STR,350,VIE,1613,,0,319
#
# 4U,2548,STR,350,VKO,2988,,0,319
#
# 4U,2548,STR,350,ZAG,1208,,0,319
#
# 4U,2548,SUF,1508,CGN,344,,0,319
#
# 4U,2548,SUF,1508,STR,350,,0,319
#
# 4U,2548,SXF,337,ARN,737,,0,319
#
# 4U,2548,SXF,337,BBU,1650,,0,319
#
# 4U,2548,SXF,337,BIA,1321,,0,319
#
# 4U,2548,SXF,337,CGN,344,,0,319
#
# 4U,2548,SXF,337,DBV,1200,,0,319
#
# 4U,2548,SXF,337,HER,1452,,0,319
#
# 4U,2548,SXF,337,MST,582,,0,319
#
# 4U,2548,SXF,337,MUC,346,,0,319
#
# 4U,2548,SXF,337,PRN,1742,,0,319
#
# 4U,2548,SXF,337,SPU,1206,,0,319
#
# 4U,2548,SXF,337,STR,350,,0,319
#
# 4U,2548,SXF,337,VKO,2988,,0,319
#
# 4U,2548,SXF,337,ZAG,1208,,0,319
#
# 4U,2548,SZG,1612,CGN,344,,0,319
#
# 4U,2548,TFS,1056,CGN,344,,0,319
#
# 4U,2548,TLV,1590,CGN,344,,0,319
#
# 4U,2548,TSF,1539,CGN,344,,0,319
#
# 4U,2548,TSF,1539,HAJ,352,,0,319
#
# 4U,2548,VIE,1613,CGN,344,,0,319
#
# 4U,2548,VIE,1613,HAJ,352,,0,319
#
# 4U,2548,VIE,1613,STR,350,,0,319
#
# 4U,2548,VKO,2988,CGN,344,,0,319
#
# 4U,2548,VKO,2988,HAJ,352,,0,319
#
# 4U,2548,VKO,2988,STR,350,,0,319
#
# 4U,2548,VKO,2988,SXF,337,,0,319
#
# 4U,2548,VRN,1550,CGN,344,,0,319
#
# 4U,2548,ZAD,1209,CGN,344,,0,319
#
# 4U,2548,ZAG,1208,CGN,344,,0,319
#
# 4U,2548,ZAG,1208,STR,350,,0,319
#
# 4U,2548,ZAG,1208,SXF,337,,0,319
#
# 4U,2548,ZRH,1678,CGN,344,,0,319
#
# 4V,\N,BDT,1027,MDK,1026,,0,737
#
# 4V,\N,FBM,1038,FIH,1020,,0,737
#
# 4V,\N,FBM,1038,KGA,1042,,0,737
#
# 4V,\N,FBM,1038,MJM,1043,,0,M82 737
#
# 4V,\N,FIH,1020,FBM,1038,,0,M82
#
# 4V,\N,FIH,1020,FKI,1031,,0,737
#
# 4V,\N,FIH,1020,KGA,1042,,0,737
#
# 4V,\N,FIH,1020,KND,1037,,0,737
#
# 4V,\N,FIH,1020,MDK,1026,,0,737
#
# 4V,\N,FIH,1020,MJM,1043,,0,M82 737
#
# 4V,\N,FKI,1031,FIH,1020,,0,737
#
# 4V,\N,FKI,1031,GOM,1036,,0,737
#
# 4V,\N,GMA,1028,BDT,1027,,0,737
#
# 4V,\N,GOM,1036,FKI,1031,,0,737
#
# 4V,\N,KGA,1042,FBM,1038,,0,737
#
# 4V,\N,KGA,1042,FIH,1020,,0,737
#
# 4V,\N,KND,1037,FKI,1031,,0,737
#
# 4V,\N,MDK,1026,FIH,1020,,0,737
#
# 4V,\N,MDK,1026,GMA,1028,,0,737
#
# 4V,\N,MJM,1043,FBM,1038,,0,M82 737
#
# 4V,\N,MJM,1043,FIH,1020,,0,M82 737
#
# 4W,\N,AET,6839,AKP,6712,,0,PAG
#
# 4W,\N,AET,6839,HUS,7107,,0,PAG
#
# 4W,\N,AKP,6712,BTT,3417,,0,PAG
#
# 4W,\N,AKP,6712,FAI,3832,,0,PAG
#
# 4W,\N,BTT,3417,FAI,3832,,0,PAG
#
# 4W,\N,CEM,7116,IRC,7236,,0,PAG
#
# 4W,\N,CIK,7105,FYU,3420,,0,PAG
#
# 4W,\N,FAI,3832,AET,6839,,0,PAG
#
# 4W,\N,FAI,3832,AKP,6712,,0,PAG
#
# 4W,\N,FAI,3832,CEM,7116,,0,PAG
#
# 4W,\N,FAI,3832,FYU,3420,,0,PAG
#
# 4W,\N,FAI,3832,GAL,3764,,0,PAG
#
# 4W,\N,FAI,3832,HSL,7108,,0,PAG
#
# 4W,\N,FAI,3832,HUS,7107,,0,PAG
#
# 4W,\N,FAI,3832,MLY,7246,,0,CNA
#
# 4W,\N,FAI,3832,RBY,6722,,0,PAG
#
# 4W,\N,FAI,3832,RMP,7112,,0,CNA
#
# 4W,\N,FAI,3832,SVS,\N,,0,CNA
#
# 4W,\N,FAI,3832,TAL,7113,,0,PAG
#
# 4W,\N,FAI,3832,WBQ,7115,,0,CNA
#
# 4W,\N,FYU,3420,CIK,7105,,0,PAG
#
# 4W,\N,FYU,3420,FAI,3832,,0,PAG
#
# 4W,\N,GAL,3764,FAI,3832,,0,PAG
#
# 4W,\N,GAL,3764,HSL,7108,,0,PAG
#
# 4W,\N,GAL,3764,KAL,6717,,0,PAG
#
# 4W,\N,GAL,3764,KYU,7208,,0,PAG
#
# 4W,\N,GAL,3764,RBY,6722,,0,PAG
#
# 4W,\N,HSL,7108,FAI,3832,,0,PAG
#
# 4W,\N,HSL,7108,GAL,3764,,0,PAG
#
# 4W,\N,HSL,7108,HUS,7107,,0,PAG
#
# 4W,\N,HUS,7107,FAI,3832,,0,PAG
#
# 4W,\N,HUS,7107,HSL,7108,,0,PAG
#
# 4W,\N,IRC,7236,FAI,3832,,0,PAG
#
# 4W,\N,KAL,6717,NUL,7111,,0,PAG
#
# 4W,\N,KYU,7208,GAL,3764,,0,PAG
#
# 4W,\N,KYU,7208,NUL,7111,,0,PAG
#
# 4W,\N,MLY,7246,MNT,7110,,0,CNA
#
# 4W,\N,MNT,7110,FAI,3832,,0,CNA
#
# 4W,\N,NUL,7111,KAL,6717,,0,PAG
#
# 4W,\N,NUL,7111,KYU,7208,,0,PAG
#
# 4W,\N,RBY,6722,FAI,3832,,0,100
#
# 4W,\N,RBY,6722,GAL,3764,,0,PAG
#
# 4W,\N,RBY,6722,TAL,7113,,0,PAG
#
# 4W,\N,RMP,7112,FAI,3832,,0,CNA
#
# 4W,\N,SVS,\N,FAI,3832,,0,CNA
#
# 4W,\N,SVS,\N,WBQ,7115,,0,CNA
#
# 4W,\N,TAL,7113,FAI,3832,,0,PAG
#
# 4W,\N,TAL,7113,RBY,6722,,0,PAG
#
# 4W,\N,VEE,7114,FAI,3832,,0,CNA
#
# 4W,\N,WBQ,7115,VEE,7114,,0,CNA
#
# 4Y,1173,AKI,7217,BET,3599,,0,CNA
#
# 4Y,1173,AKI,7217,TLT,7218,,0,CNA
#
# 4Y,1173,ATT,4385,KUK,7094,,0,CNA
#
# 4Y,1173,BET,3599,ATT,4385,,0,CNA
#
# 4Y,1173,BET,3599,EEK,7093,,0,CNA
#
# 4Y,1173,BET,3599,GNU,\N,,0,CNA
#
# 4Y,1173,BET,3599,KKH,7213,,0,CNA
#
# 4Y,1173,BET,3599,KKI,\N,,0,CNA
#
# 4Y,1173,BET,3599,KLG,5964,,0,CNA
#
# 4Y,1173,BET,3599,KPN,7201,,0,CNA
#
# 4Y,1173,BET,3599,KWT,7095,,0,CNA
#
# 4Y,1173,BET,3599,NME,\N,,0,CNA
#
# 4Y,1173,BET,3599,RSH,7098,,0,CNA
#
# 4Y,1173,BET,3599,WNA,\N,,0,CNA
#
# 4Y,1173,BET,3599,WTL,7099,,0,CNA
#
# 4Y,1173,CYF,6960,BET,3599,,0,CNA
#
# 4Y,1173,EEK,7093,KWN,7206,,0,CNA
#
# 4Y,1173,GNU,\N,PTU,3430,,0,CNA
#
# 4Y,1173,KKH,7213,KWK,7096,,0,CNA
#
# 4Y,1173,KKI,\N,AKI,7217,,0,CNA
#
# 4Y,1173,KKI,\N,TLT,7218,,0,CNA
#
# 4Y,1173,KLG,5964,BET,3599,,0,CNA
#
# 4Y,1173,KLG,5964,RSH,7098,,0,CNA
#
# 4Y,1173,KPN,7201,CYF,6960,,0,CNA
#
# 4Y,1173,KUK,7094,NUP,7212,,0,CNA
#
# 4Y,1173,KWK,7096,BET,3599,,0,CNA
#
# 4Y,1173,KWN,7206,BET,3599,,0,CNA
#
# 4Y,1173,KWT,7095,AKI,7217,,0,CNA
#
# 4Y,1173,KWT,7095,KKI,\N,,0,CNA
#
# 4Y,1173,NME,\N,OOK,\N,,0,CNA
#
# 4Y,1173,NUP,7212,BET,3599,,0,CNA
#
# 4Y,1173,OOK,\N,TNK,\N,,0,CNA
#
# 4Y,1173,PKA,\N,BET,3599,,0,CNA
#
# 4Y,1173,PTU,3430,BET,3599,,0,CNA
#
# 4Y,1173,RSH,7098,BET,3599,,0,CNA
#
# 4Y,1173,RSH,7098,KLG,5964,,0,CNA
#
# 4Y,1173,TLT,7218,BET,3599,,0,CNA
#
# 4Y,1173,TNK,\N,WWT,\N,,0,CNA
#
# 4Y,1173,WNA,\N,PKA,\N,,0,CNA
#
# 4Y,1173,WTL,7099,BET,3599,,0,CNA
#
# 4Y,1173,WTL,7099,KKH,7213,,0,CNA
#
# 4Y,1173,WWT,\N,BET,3599,,0,CNA
#
# 5C,1581,BOC,1865,SYQ,5848,,0,DHT
#
# 5C,1581,DRK,6945,SYQ,5848,,0,DHT
#
# 5C,1581,FON,6731,SYQ,5848,,0,DHT
#
# 5C,1581,FON,6731,XQP,1889,,0,DHT
#
# 5C,1581,GLF,1879,PJM,5847,,0,DHT
#
# 5C,1581,GLF,1879,SYQ,5848,,0,DHT
#
# 5C,1581,LIR,1881,MGA,1863,,0,DHT
#
# 5C,1581,LIR,1881,SYQ,5848,,0,DHT
#
# 5C,1581,LIR,1881,TNO,5844,,0,DHT
#
# 5C,1581,MGA,1863,LIR,1881,,0,DHT
#
# 5C,1581,NOB,1884,SYQ,5848,,0,DHT
#
# 5C,1581,PBP,5845,NOB,1884,,0,DHT
#
# 5C,1581,PJM,5847,GLF,1879,,0,DHT
#
# 5C,1581,PJM,5847,SYQ,5848,,0,DHT
#
# 5C,1581,PJM,5847,XQP,1889,,0,DHT
#
# 5C,1581,PMZ,1887,XQP,1889,,0,DHT
#
# 5C,1581,SYQ,5848,BOC,1865,,0,DHT
#
# 5C,1581,SYQ,5848,DRK,6945,,0,DHT
#
# 5C,1581,SYQ,5848,FON,6731,,0,DHT
#
# 5C,1581,SYQ,5848,GLF,1879,,0,DHT
#
# 5C,1581,SYQ,5848,LIR,1881,,0,DHT
#
# 5C,1581,SYQ,5848,PBP,5845,,0,DHT
#
# 5C,1581,SYQ,5848,PJM,5847,,0,DHT
#
# 5C,1581,SYQ,5848,TMU,6732,,0,DHT
#
# 5C,1581,SYQ,5848,TNO,5844,,0,DHT
#
# ...
#
# AA,24,DSM,3729,ORD,3830,Y,0,ER4 ERD
#
# AA,24,DTW,3645,DFW,3670,,0,M80
#
# AA,24,DTW,3645,LGA,3697,Y,0,ER3
#
# AA,24,DTW,3645,MIA,3576,,0,738
#
# AA,24,DTW,3645,ORD,3830,Y,0,ER4 ERD
#
# AA,24,DUB,599,ORD,3830,,0,763
#
# AA,24,DUS,345,JFK,3797,Y,0,330
#
# AA,24,DUS,345,MIA,3576,Y,0,330
#
# AA,24,DUS,345,RSW,3793,Y,0,330
#
# AA,24,EIS,2903,SJU,2890,Y,0,AT7
#
# AA,24,ELH,1943,MIA,3576,Y,0,AT7
#
# AA,24,ELP,3559,DFW,3670,,0,M80
#
# AA,24,ELP,3559,LAX,3484,Y,0,ERD
#
# AA,24,ELP,3559,ORD,3830,Y,0,CR7
#
# AA,24,EVV,4018,DFW,3670,Y,0,ER4
#
# AA,24,EVV,4018,ORD,3830,Y,0,ER4 ERD
#
# AA,24,EWR,3494,DFW,3670,,0,M80 M83
#
# AA,24,EWR,3494,LAX,3484,,0,738
#
# AA,24,EWR,3494,LHR,507,Y,0,777 767
#
# AA,24,EWR,3494,MIA,3576,,0,757
#
# AA,24,EWR,3494,ORD,3830,,0,M83 M80
#
# AA,24,EWR,3494,SEA,3577,Y,0,737
#
# AA,24,EYW,3875,MIA,3576,Y,0,AT7
#
# AA,24,EZE,3988,DFW,3670,,0,763
#
# AA,24,EZE,3988,JFK,3797,,0,777
#
# AA,24,EZE,3988,MIA,3576,,0,777
#
# AA,24,FAR,4292,ORD,3830,Y,0,ER4
#
# AA,24,FAT,3687,DFW,3670,,0,M80
#
# AA,24,FAT,3687,LAX,3484,Y,0,ERD
#
# AA,24,FAY,5738,DFW,3670,Y,0,ERD
#
# AA,24,FCO,1555,JFK,3797,,0,763
#
# AA,24,FCO,1555,ORD,3830,,0,763
#
# AA,24,FDF,2878,SJU,2890,Y,0,AT7
#
# AA,24,FLL,3533,DFW,3670,,0,738
#
# AA,24,FLL,3533,JFK,3797,,0,738
#
# AA,24,FLL,3533,ORD,3830,,0,738
#
# AA,24,FLL,3533,PAP,1897,,0,738
#
# AA,24,FNT,4089,ORD,3830,Y,0,ERD
#
# AA,24,FPO,1948,MIA,3576,Y,0,AT7
#
# AA,24,FRA,340,DFW,3670,,0,763
#
# AA,24,FSD,4009,DFW,3670,Y,0,ER4
#
# AA,24,FSD,4009,ORD,3830,Y,0,ERD ER4
#
# AA,24,FSM,3437,DFW,3670,Y,0,ER4 AT7
#
# AA,24,FWA,4041,DFW,3670,Y,0,ER4
#
# AA,24,FWA,4041,ORD,3830,Y,0,ER4 ERD
#
# AA,24,GCM,1926,MIA,3576,,0,738
#
# AA,24,GDL,1804,DFW,3670,,0,M80
#
# AA,24,GDL,1804,LAX,3484,Y,0,737
#
# AA,24,GDL,1804,SJC,3748,Y,0,737
#
# AA,24,GDL,1804,SMF,3817,Y,0,737
#
# AA,24,GGG,3465,DFW,3670,Y,0,ER4 AT7
#
# AA,24,GGT,1941,MIA,3576,Y,0,AT7
#
# AA,24,GIG,2560,DFW,3670,,0,763
#
# AA,24,GIG,2560,JFK,3797,,0,763
#
# AA,24,GIG,2560,MIA,3576,,0,763
#
# AA,24,GJT,4063,DFW,3670,Y,0,ER4
#
# AA,24,GND,2882,MIA,3576,,0,738
#
# AA,24,GND,2882,SJU,2890,Y,0,AT7
#
# AA,24,GNV,3472,MIA,3576,Y,0,AT7
#
# AA,24,GPT,4038,DFW,3670,Y,0,ER4
#
# AA,24,GRB,3653,MQT,6838,Y,0,ER4
#
# AA,24,GRB,3653,ORD,3830,Y,0,ER4 ERD
#
# AA,24,GRK,3775,DFW,3670,Y,0,AT7
#
# AA,24,GRR,3685,DFW,3670,Y,0,ER4
#
# AA,24,GRR,3685,ORD,3830,Y,0,ERD ER4
#
# AA,24,GRU,2564,DFW,3670,,0,777
#
# AA,24,GRU,2564,JFK,3797,,0,777
#
# AA,24,GRU,2564,MIA,3576,,0,777 763
#
# AA,24,GSO,4008,DFW,3670,Y,0,ER4 ERD
#
# AA,24,GSO,4008,MIA,3576,Y,0,ER4
#
# AA,24,GSP,4034,DFW,3670,Y,0,ER4 ERD
#
# AA,24,GUA,1767,DFW,3670,,0,738
#
# AA,24,GUA,1767,MIA,3576,,0,738
#
# AA,24,GYE,2673,MIA,3576,,0,763 738
#
# AA,24,HEL,421,JFK,3797,Y,0,330
#
# AA,24,HKG,3077,JFK,3797,Y,0,773
#
# AA,24,HKG,3077,LAX,3484,Y,0,773
#
# AA,24,HKG,3077,SFO,3469,Y,0,744
#
# AA,24,HND,2359,HNL,3728,Y,0,777
#
# AA,24,HND,2359,SFO,3469,Y,0,777
#
# AA,24,HNL,3728,DFW,3670,,0,763
#
# AA,24,HNL,3728,HND,2359,Y,0,777
#
# AA,24,HNL,3728,KIX,3992,Y,0,767
#
# AA,24,HNL,3728,LAX,3484,,0,757
#
# AA,24,HNL,3728,NRT,2279,Y,0,767
#
# AA,24,HNL,3728,ORD,3830,,0,763
#
# AA,24,HNL,3728,SFO,3469,,0,757
#
# AA,24,HNL,3728,SYD,3361,Y,0,763
#
# AA,24,HOU,3566,DFW,3670,Y,0,ER4 ERD
#
# AA,24,HPN,3589,ORD,3830,Y,0,ERD
#
# AA,24,HSV,4113,DFW,3670,,0,M83 M80
#
# AA,24,HSV,4113,ORD,3830,Y,0,ER4 ERD
#
# AA,24,HYD,3141,DEL,3093,Y,0,737
#
# AA,24,IAD,3714,DFW,3670,,0,M80
#
# AA,24,IAD,3714,LAX,3484,,0,738
#
# AA,24,IAD,3714,LHR,507,Y,0,777 767 744
#
# AA,24,IAD,3714,MIA,3576,,0,738
#
# AA,24,IAH,3550,DFW,3670,,0,M80 M83
#
# AA,24,IAH,3550,LAX,3484,Y,0,CR7
#
# AA,24,IAH,3550,LHR,507,Y,0,777 744
#
# AA,24,IAH,3550,MIA,3576,,0,738
#
# AA,24,IAH,3550,ORD,3830,Y,0,CR7
#
# AA,24,ICT,3457,DFW,3670,,0,M80 M83
#
# AA,24,ICT,3457,ORD,3830,Y,0,ER4
#
# AA,24,IND,3585,DFW,3670,,0,M83 M80
#
# AA,24,IND,3585,JFK,3797,Y,0,ER4
#
# AA,24,IND,3585,MIA,3576,Y,0,ER4
#
# AA,24,IND,3585,ORD,3830,Y,0,ERD ER4
#
# AA,24,JAN,3580,DFW,3670,Y,0,ERD ER4
#
# AA,24,JAX,3712,DFW,3670,,0,M80 M83
#
# AA,24,JAX,3712,MIA,3576,Y,0,AT7 ER4
#
# AA,24,JAX,3712,ORD,3830,Y,0,ER4
#
# AA,24,JFK,3797,AMM,2170,Y,0,340
#
# AA,24,JFK,3797,AUA,2895,,0,757
#
# AA,24,JFK,3797,AUH,2179,Y,0,340
#
# AA,24,JFK,3797,AUS,3673,,0,738
#
# AA,24,JFK,3797,BCN,1218,,0,763
#
# AA,24,JFK,3797,BDA,4069,,0,757
#
# AA,24,JFK,3797,BGI,2875,,0,757
#
# AA,24,JFK,3797,BNA,3690,Y,0,ER4
#
# AA,24,JFK,3797,BOS,3448,Y,0,CR7 ERD
#
# AA,24,JFK,3797,BRU,302,,0,757
#
# AA,24,JFK,3797,BUD,1489,,0,763
#
# AA,24,JFK,3797,BWI,3849,Y,0,ER4
#
# AA,24,JFK,3797,CCS,2851,,0,757
#
# AA,24,JFK,3797,CDG,1382,,0,763 757
#
# AA,24,JFK,3797,CLE,3486,Y,0,ER4
#
# AA,24,JFK,3797,CMH,3759,Y,0,ER4 CR7
#
# AA,24,JFK,3797,CUN,1852,,0,757
#
# AA,24,JFK,3797,CVG,3488,Y,0,ER4
#
# AA,24,JFK,3797,DCA,3520,Y,0,ERD CR7
#
# AA,24,JFK,3797,DFW,3670,,0,738
#
# AA,24,JFK,3797,DUS,345,Y,0,330
#
# AA,24,JFK,3797,EZE,3988,,0,777
#
# AA,24,JFK,3797,FCO,1555,,0,763
#
# AA,24,JFK,3797,FLL,3533,,0,738
#
# AA,24,JFK,3797,GIG,2560,,0,763
#
# AA,24,JFK,3797,GRU,2564,,0,777
#
# AA,24,JFK,3797,HEL,421,Y,0,330
#
# AA,24,JFK,3797,HKG,3077,Y,0,773
#
# AA,24,JFK,3797,IND,3585,Y,0,ER4
#
# AA,24,JFK,3797,LAS,3877,,0,738
#
# AA,24,JFK,3797,LAX,3484,,0,762
#
# AA,24,JFK,3797,LCY,503,Y,0,318
#
# AA,24,JFK,3797,LHR,507,,0,777
#
# AA,24,JFK,3797,LIM,2789,Y,0,763
#
# AA,24,JFK,3797,MAD,1229,,0,757
#
# AA,24,JFK,3797,MAN,478,,0,757
#
# AA,24,JFK,3797,MBJ,1780,,0,757
#
# AA,24,JFK,3797,MCO,3878,,0,757
#
# AA,24,JFK,3797,MIA,3576,,0,738 762 757 763
#
# AA,24,JFK,3797,MXP,1524,,0,763
#
# AA,24,JFK,3797,NRT,2279,,0,777
#
# AA,24,JFK,3797,ORD,3830,Y,0,CR7
#
# AA,24,JFK,3797,ORF,3611,Y,0,ER4
#
# AA,24,JFK,3797,PAP,1897,,0,763
#
# AA,24,JFK,3797,PIT,3570,Y,0,ER4
#
# AA,24,JFK,3797,PLS,1754,,0,757
#
# AA,24,JFK,3797,PUJ,1760,,0,757
#
# AA,24,JFK,3797,RDU,3626,Y,0,ERD
#
# AA,24,JFK,3797,SAN,3731,,0,738
#
# AA,24,JFK,3797,SCL,2650,Y,0,763
#
# AA,24,JFK,3797,SDQ,1762,,0,763
#
# AA,24,JFK,3797,SEA,3577,,0,757
#
# AA,24,JFK,3797,SFO,3469,,0,762 763
#
# AA,24,JFK,3797,SJU,2890,,0,738 757
#
# AA,24,JFK,3797,SKB,2891,,0,757
#
# AA,24,JFK,3797,STI,1764,,0,763
#
# AA,24,JFK,3797,STL,3678,Y,0,ERD
#
# AA,24,JFK,3797,STT,2883,,0,757
#
# AA,24,JFK,3797,SXM,2899,,0,757
#
# AA,24,JFK,3797,TPA,3646,,0,738
#
# AA,24,JFK,3797,YHZ,73,Y,0,ERD
#
# AA,24,JFK,3797,YUL,146,Y,0,ERD
#
# AA,24,JFK,3797,YYZ,193,Y,0,CR7
#
# AA,24,JFK,3797,ZRH,1678,,0,763
#
# AA,24,JLN,4354,DFW,3670,Y,0,AT7
#
# AA,24,KIN,1779,MIA,3576,,0,738
#
# AA,24,KIX,3992,HNL,3728,Y,0,767
#
# AA,24,KOA,3514,LAX,3484,,0,757
#
# AA,24,LAS,3877,DFW,3670,,0,M80 738 M83 757
#
# AA,24,LAS,3877,JFK,3797,,0,738
#
# AA,24,LAS,3877,LAX,3484,,0,738 M80
#
# AA,24,LAS,3877,LHR,507,Y,0,777
#
# AA,24,LAS,3877,MIA,3576,,0,738 757
#
# AA,24,LAS,3877,ORD,3830,,0,M83 757
#
# AA,24,LAW,4256,DFW,3670,Y,0,AT7
#
# AA,24,LAX,3484,ABQ,4019,Y,0,ERD CR7
#
# AA,24,LAX,3484,AKL,2006,Y,0,330
#
# AA,24,LAX,3484,AUS,3673,,0,738
#
# AA,24,LAX,3484,BNA,3690,,0,738
#
# AA,24,LAX,3484,BNE,3320,Y,0,744
#
# AA,24,LAX,3484,BOI,3495,Y,0,ERD
#
# AA,24,LAX,3484,BOS,3448,,0,757 738
#
# AA,24,LAX,3484,DEN,3751,Y,0,CR7
#
# AA,24,LAX,3484,DFW,3670,,0,738 757 763 M80 M83
#
# AA,24,LAX,3484,ELP,3559,Y,0,ERD
#
# AA,24,LAX,3484,EWR,3494,,0,738
#
# AA,24,LAX,3484,FAT,3687,Y,0,ERD
#
# AA,24,LAX,3484,GDL,1804,Y,0,737
#
# AA,24,LAX,3484,HKG,3077,Y,0,773
#
# AA,24,LAX,3484,HNL,3728,,0,757
#
# AA,24,LAX,3484,IAD,3714,,0,738
#
# AA,24,LAX,3484,IAH,3550,Y,0,CR7
#
# AA,24,LAX,3484,JFK,3797,,0,762
#
# AA,24,LAX,3484,KOA,3514,,0,757
#
# AA,24,LAX,3484,LAS,3877,,0,738 M80
#
# AA,24,LAX,3484,LHR,507,,0,777
#
# AA,24,LAX,3484,LIH,3602,,0,757
#
# AA,24,LAX,3484,LIM,2789,Y,0,763
#
# AA,24,LAX,3484,MAD,1229,Y,0,340
#
# AA,24,LAX,3484,MCO,3878,,0,757 738
#
# AA,24,LAX,3484,MEL,3339,Y,0,744 380
#
# AA,24,LAX,3484,MEX,1824,Y,0,737
#
# AA,24,LAX,3484,MFR,4101,Y,0,DH4
#
# AA,24,LAX,3484,MIA,3576,,0,757 763 777 738
#
# AA,24,LAX,3484,MMH,7081,Y,0,DH4
#
# AA,24,LAX,3484,MRY,3948,Y,0,ERD
#
# AA,24,LAX,3484,NRT,2279,,0,777
#
# AA,24,LAX,3484,OGG,3456,,0,757
#
# AA,24,LAX,3484,OKC,3863,Y,0,CR7
#
# AA,24,LAX,3484,ORD,3830,,0,738 757 763
#
# AA,24,LAX,3484,PDX,3720,Y,0,737
#
# AA,24,LAX,3484,PHX,3462,Y,0,CR7
#
# AA,24,LAX,3484,PVG,3406,,0,777
#
# AA,24,LAX,3484,RNO,3807,Y,0,ERD
#
# AA,24,LAX,3484,SAF,3784,Y,0,ERD
#
# AA,24,LAX,3484,SAL,1892,,0,757
#
# AA,24,LAX,3484,SAN,3731,Y,0,ERD CR7
#
# AA,24,LAX,3484,SBA,3949,Y,0,ERD
#
# AA,24,LAX,3484,SEA,3577,Y,0,737
#
# AA,24,LAX,3484,SFO,3469,,0,738
#
# AA,24,LAX,3484,SJC,3748,Y,0,ERD
#
# AA,24,LAX,3484,SJD,1840,,0,738
#
# AA,24,LAX,3484,SJU,2890,,0,757
#
# AA,24,LAX,3484,SLC,3536,Y,0,ERD
#
# AA,24,LAX,3484,SMF,3817,Y,0,ERD
#
# AA,24,LAX,3484,STL,3678,,0,M83
#
# AA,24,LAX,3484,SYD,3361,Y,0,380 744
#
# AA,24,LAX,3484,TPE,2276,Y,0,777
#
# AA,24,LAX,3484,TUS,3636,Y,0,ERD
#
# AA,24,LAX,3484,YVR,156,Y,0,737
#
# AA,24,LAX,3484,YYZ,193,,0,738
#
# AA,24,LBB,3829,DFW,3670,Y,0,ER4 ERD
#
# AA,24,LCH,3513,DFW,3670,Y,0,ERD ER3
#
# AA,24,LEX,4017,DFW,3670,Y,0,ERD ER3
#
# AA,24,LEX,4017,ORD,3830,Y,0,ERD ER4
#
# AA,24,LFT,3493,DFW,3670,Y,0,ERD ER4
#
# AA,24,LGA,3697,ATL,3682,Y,0,CR7
#
# AA,24,LGA,3697,BNA,3690,,0,M80
#
# AA,24,LGA,3697,BOS,3448,Y,0,ER3
#
# AA,24,LGA,3697,CLE,3486,Y,0,ER3 CR7
#
# AA,24,LGA,3697,CLT,3876,Y,0,CR7
#
# AA,24,LGA,3697,CMH,3759,Y,0,ER3 CR7
#
# AA,24,LGA,3697,CRW,4285,Y,0,ER3
#
# AA,24,LGA,3697,DFW,3670,,0,738 M80
#
# AA,24,LGA,3697,DTW,3645,Y,0,ER3
#
# AA,24,LGA,3697,MIA,3576,,0,757 738
#
# AA,24,LGA,3697,MSP,3858,Y,0,CR7
#
# AA,24,LGA,3697,ORD,3830,,0,M83 M80 738 757
#
# AA,24,LGA,3697,RDU,3626,Y,0,ER3 CR7
#
# AA,24,LGA,3697,STL,3678,,0,M80
#
# AA,24,LGA,3697,XNA,4356,Y,0,ER3
#
# AA,24,LGA,3697,YUL,146,Y,0,ER3
#
# AA,24,LGA,3697,YYZ,193,Y,0,CR7
#
# AA,24,LGB,3582,SEA,3577,Y,0,CR7
#
# AA,24,LGW,502,MCO,3878,Y,0,777
#
# AA,24,LGW,502,TPA,3646,Y,0,777
#
# AA,24,LHR,507,ATL,3682,Y,0,777
#
# AA,24,LHR,507,BOS,3448,,0,757
#
# AA,24,LHR,507,BWI,3849,Y,0,767
#
# AA,24,LHR,507,DEN,3751,Y,0,777
#
# AA,24,LHR,507,DFW,3670,,0,777
#
# AA,24,LHR,507,EWR,3494,Y,0,777 767
#
# AA,24,LHR,507,IAD,3714,Y,0,777 767 744
#
# AA,24,LHR,507,IAH,3550,Y,0,777 744
#
# AA,24,LHR,507,JFK,3797,,0,777
#
# AA,24,LHR,507,LAS,3877,Y,0,777
#
# AA,24,LHR,507,LAX,3484,,0,777
#
# AA,24,LHR,507,MIA,3576,,0,777
#
# AA,24,LHR,507,ORD,3830,,0,777 763
#
# AA,24,LHR,507,PHL,3752,Y,0,777 767
#
# AA,24,LHR,507,PHX,3462,Y,0,744
#
# AA,24,LHR,507,RDU,3626,,0,763
#
# AA,24,LHR,507,SEA,3577,Y,0,744
#
# AA,24,LHR,507,SFO,3469,Y,0,744
#
# AA,24,LHR,507,YUL,146,Y,0,777
#
# AA,24,LHR,507,YVR,156,Y,0,744
#
# AA,24,LHR,507,YYC,178,Y,0,767
#
# AA,24,LHR,507,YYZ,193,Y,0,767 777
#
# AA,24,LIH,3602,LAX,3484,,0,757
#
# AA,24,LIM,2789,JFK,3797,Y,0,763
#
# AA,24,LIM,2789,LAX,3484,Y,0,763
#
# AA,24,LIM,2789,MIA,3576,,0,757
#
# AA,24,LIM,2789,SFO,3469,Y,0,763
#
# AA,24,LIR,1881,DFW,3670,,0,738
#
# AA,24,LIR,1881,MIA,3576,,0,738
#
# AA,24,LIT,3660,DFW,3670,,0,M80
#
# AA,24,LIT,3660,ORD,3830,Y,0,ER4
#
# AA,24,LPB,2762,VVI,2771,,0,757
#
# AA,24,LRD,3691,DFW,3670,Y,0,ER4 ERD
#
# AA,24,LRM,1759,MIA,3576,Y,0,ER4
#
# AA,24,LSE,4044,ORD,3830,Y,0,ERD
#
# AA,24,MAA,3144,DEL,3093,Y,0,737
#
# AA,24,MAD,1229,BOS,3448,Y,0,340
#
# AA,24,MAD,1229,BUD,1489,Y,0,737
#
# AA,24,MAD,1229,DFW,3670,,0,763
#
# AA,24,MAD,1229,JFK,3797,,0,757
#
# AA,24,MAD,1229,LAX,3484,Y,0,340
#
# AA,24,MAD,1229,MIA,3576,,0,763
#
# AA,24,MAD,1229,ORD,3830,Y,0,340
#
# AA,24,MAD,1229,SJU,2890,Y,0,340
#
# AA,24,MAF,3652,DFW,3670,Y,0,ER4 AT7 ERD
#
# AA,24,MAN,478,JFK,3797,,0,757
#
# AA,24,MAN,478,ORD,3830,,0,757
#
# AA,24,MAR,2848,MIA,3576,,0,757
#
# AA,24,MBJ,1780,DFW,3670,,0,738
#
# AA,24,MBJ,1780,JFK,3797,,0,757
#
# AA,24,MBJ,1780,MIA,3576,,0,738 757
#
# AA,24,MBJ,1780,ORD,3830,,0,738
#
# AA,24,MCI,3458,DFW,3670,,0,M80
#
# AA,24,MCI,3458,ORD,3830,,0,M83
#
# AA,24,MCO,3878,DFW,3670,,0,M83 M80 757
#
# AA,24,MCO,3878,JFK,3797,,0,757
#
# AA,24,MCO,3878,LAX,3484,,0,738 757
#
# AA,24,MCO,3878,LGW,502,Y,0,777
#
# AA,24,MCO,3878,MIA,3576,,0,757 738
#
# AA,24,MCO,3878,ORD,3830,,0,M83 738 M80
#
# AA,24,MDE,2745,MIA,3576,,0,738
#
# AA,24,MDT,3542,ORD,3830,Y,0,ER4
#
# AA,24,MEL,3339,AKL,2006,Y,0,737
#
# AA,24,MEL,3339,LAX,3484,Y,0,744 380
#
# AA,24,MEM,3473,DFW,3670,,0,M80
#
# AA,24,MEM,3473,MIA,3576,Y,0,ER4
#
# AA,24,MEM,3473,ORD,3830,Y,0,ERD ER4
#
# AA,24,MEX,1824,DFW,3670,,0,M83 M80
#
# AA,24,MEX,1824,LAX,3484,Y,0,737
#
# AA,24,MEX,1824,MIA,3576,,0,738
#
# AA,24,MEX,1824,ORD,3830,,0,738
#
# AA,24,MFE,3826,DFW,3670,,0,M80 M83
#
# AA,24,MFR,4101,LAX,3484,Y,0,DH4
#
# AA,24,MGA,1863,MIA,3576,,0,738 757
#
# AA,24,MGM,4115,DFW,3670,Y,0,ER4
#
# AA,24,MHH,1930,MIA,3576,Y,0,AT7
#
# AA,24,MHK,4050,DFW,3670,Y,0,ER4 ERD
#
# AA,24,MHK,4050,ORD,3830,Y,0,ER4
#
# AA,24,MIA,3576,ANU,2874,,0,738
#
# AA,24,MIA,3576,ATL,3682,,0,738
#
# AA,24,MIA,3576,AUA,2895,,0,757
#
# AA,24,MIA,3576,BCN,1218,Y,0,340
#
# AA,24,MIA,3576,BDA,4069,,0,738
#
# AA,24,MIA,3576,BDL,3825,,0,738
#
# AA,24,MIA,3576,BGI,2875,,0,757
#
# AA,24,MIA,3576,BHM,3811,Y,0,ER4
#
# AA,24,MIA,3576,BNA,3690,Y,0,ER4
#
# AA,24,MIA,3576,BOG,2709,,0,757
#
# AA,24,MIA,3576,BOS,3448,,0,757
#
# AA,24,MIA,3576,BSB,2531,,0,757
#
# AA,24,MIA,3576,BWI,3849,,0,738
#
# AA,24,MIA,3576,BZE,1957,,0,738
#
# AA,24,MIA,3576,CCS,2851,,0,757
#
# AA,24,MIA,3576,CDG,1382,,0,763
#
# AA,24,MIA,3576,CHS,3806,Y,0,ER4
#
# AA,24,MIA,3576,CLE,3486,Y,0,ER4
#
# AA,24,MIA,3576,CLO,2715,,0,738
#
# AA,24,MIA,3576,CLT,3876,Y,0,ER4
#
# AA,24,MIA,3576,CMH,3759,Y,0,ER4
#
# AA,24,MIA,3576,CNF,2537,,0,763
#
# AA,24,MIA,3576,CUN,1852,,0,738 757
#
# AA,24,MIA,3576,CUR,2897,,0,738
#
# AA,24,MIA,3576,CVG,3488,Y,0,ER4
#
# AA,24,MIA,3576,DCA,3520,,0,738
#
# AA,24,MIA,3576,DEN,3751,,0,757
#
# AA,24,MIA,3576,DFW,3670,,0,757 738
#
# AA,24,MIA,3576,DTW,3645,,0,738
#
# AA,24,MIA,3576,DUS,345,Y,0,330
#
# AA,24,MIA,3576,ELH,1943,Y,0,AT7
#
# AA,24,MIA,3576,EWR,3494,,0,757
#
# AA,24,MIA,3576,EYW,3875,Y,0,AT7
#
# AA,24,MIA,3576,EZE,3988,,0,777
#
# AA,24,MIA,3576,FPO,1948,Y,0,AT7
#
# AA,24,MIA,3576,GCM,1926,,0,738
#
# AA,24,MIA,3576,GGT,1941,Y,0,AT7
#
# AA,24,MIA,3576,GIG,2560,,0,763
#
# AA,24,MIA,3576,GND,2882,,0,738
#
# AA,24,MIA,3576,GNV,3472,Y,0,AT7
#
# AA,24,MIA,3576,GRU,2564,,0,763 777
#
# AA,24,MIA,3576,GSO,4008,Y,0,ER4
#
# AA,24,MIA,3576,GUA,1767,,0,738
#
# AA,24,MIA,3576,GYE,2673,,0,738 763
#
# AA,24,MIA,3576,IAD,3714,,0,738
#
# AA,24,MIA,3576,IAH,3550,,0,738
#
# AA,24,MIA,3576,IND,3585,Y,0,ER4
#
# AA,24,MIA,3576,JAX,3712,Y,0,AT7 ER4
#
# AA,24,MIA,3576,JFK,3797,,0,763 762 757 738
#
# AA,24,MIA,3576,KIN,1779,,0,738
#
# AA,24,MIA,3576,LAS,3877,,0,738 757
#
# AA,24,MIA,3576,LAX,3484,,0,777 757 738 763
#
# AA,24,MIA,3576,LGA,3697,,0,757 738
#
# AA,24,MIA,3576,LHR,507,,0,777
#
# AA,24,MIA,3576,LIM,2789,,0,757
#
# AA,24,MIA,3576,LIR,1881,,0,738
#
# AA,24,MIA,3576,LPB,2762,,0,757
#
# AA,24,MIA,3576,LRM,1759,Y,0,ER4
#
# AA,24,MIA,3576,MAD,1229,,0,763
#
# AA,24,MIA,3576,MAR,2848,,0,757
#
# AA,24,MIA,3576,MBJ,1780,,0,738 757
#
# AA,24,MIA,3576,MCO,3878,,0,757 738
#
# AA,24,MIA,3576,MDE,2745,,0,738
#
# AA,24,MIA,3576,MEM,3473,Y,0,ER4
#
# AA,24,MIA,3576,MEX,1824,,0,738
#
# AA,24,MIA,3576,MGA,1863,,0,757 738
#
# AA,24,MIA,3576,MHH,1930,Y,0,AT7
#
# AA,24,MIA,3576,MSP,3858,,0,738
#
# AA,24,MIA,3576,MSY,3861,,0,738
#
# AA,24,MIA,3576,MVD,2816,,0,763
#
# AA,24,MIA,3576,NAS,1953,Y,0,AT7
#
# AA,24,MIA,3576,ORD,3830,,0,757 763
#
# AA,24,MIA,3576,ORF,3611,Y,0,ER4
#
# AA,24,MIA,3576,PAP,1897,,0,738 763 757
#
# AA,24,MIA,3576,PHL,3752,,0,738
#
# AA,24,MIA,3576,PHX,3462,,0,738
#
# AA,24,MIA,3576,PIT,3570,Y,0,ER4
#
# AA,24,MIA,3576,PLS,1754,,0,738
#
# AA,24,MIA,3576,PNS,3564,Y,0,ER4
#
# AA,24,MIA,3576,POP,1761,,0,738
#
# AA,24,MIA,3576,POS,2902,,0,763 757
#
# AA,24,MIA,3576,PTY,1871,,0,738
#
# AA,24,MIA,3576,PUJ,1760,,0,738
#
# AA,24,MIA,3576,RDU,3626,,0,738
#
# AA,24,MIA,3576,RIC,3608,Y,0,ER4
#
# AA,24,MIA,3576,RSW,3793,Y,0,ER4 AT7
#
# AA,24,MIA,3576,SAL,1892,,0,738
#
# AA,24,MIA,3576,SAP,1772,,0,738
#
# AA,24,MIA,3576,SAV,3613,Y,0,AT7
#
# AA,24,MIA,3576,SCL,2650,,0,763
#
# AA,24,MIA,3576,SDF,4014,Y,0,ER4
#
# AA,24,MIA,3576,SDQ,1762,,0,757 763
#
# AA,24,MIA,3576,SEA,3577,Y,0,737
#
# AA,24,MIA,3576,SFO,3469,,0,757
#
# AA,24,MIA,3576,SJO,1885,,0,757 738
#
# AA,24,MIA,3576,SJU,2890,,0,757 738
#
# AA,24,MIA,3576,SKB,2891,,0,738
#
# AA,24,MIA,3576,SSA,2621,,0,757
#
# AA,24,MIA,3576,STI,1764,,0,738
#
# AA,24,MIA,3576,STL,3678,,0,757
#
# AA,24,MIA,3576,STT,2883,,0,757
#
# AA,24,MIA,3576,STX,2884,,0,738
#
# AA,24,MIA,3576,SXM,2899,,0,738
#
# AA,24,MIA,3576,TCB,1934,Y,0,AT7
#
# AA,24,MIA,3576,TGU,1776,,0,757
#
# AA,24,MIA,3576,TLH,3698,Y,0,ER4
#
# AA,24,MIA,3576,TPA,3646,,0,738 757
#
# AA,24,MIA,3576,TXL,351,Y,0,330
#
# AA,24,MIA,3576,TYS,3676,Y,0,ER4
#
# AA,24,MIA,3576,UIO,2688,,0,757
#
# AA,24,MIA,3576,UVF,2894,,0,757
#
# AA,24,MIA,3576,YUL,146,,0,738
#
# AA,24,MIA,3576,YYZ,193,,0,738
#
# AA,24,MKE,3717,DFW,3670,,0,M80 M83
#
# AA,24,MKE,3717,ORD,3830,Y,0,ERD ER4
#
# AA,24,MLI,4072,DFW,3670,Y,0,ER4 ERD
#
# AA,24,MLI,4072,ORD,3830,Y,0,ER4 ERD
#
# AA,24,MLU,3732,DFW,3670,Y,0,AT7
#
# AA,24,MMH,7081,LAX,3484,Y,0,DH4
#
# AA,24,MMH,7081,SJC,3748,Y,0,DH4
#
# AA,24,MOB,3782,DFW,3670,Y,0,ER4 ERD
#
# AA,24,MQT,6838,GRB,3653,Y,0,ER4
#
# AA,24,MQT,6838,ORD,3830,Y,0,ER4
#
# AA,24,MQT,6838,TVC,4023,Y,0,ER4
#
# AA,24,MRY,3948,LAX,3484,Y,0,ERD
#
# AA,24,MSN,3459,DFW,3670,Y,0,ER4
#
# AA,24,MSN,3459,ORD,3830,Y,0,ER4 ERD
#
# AA,24,MSP,3858,DFW,3670,,0,M80 738
#
# AA,24,MSP,3858,LGA,3697,Y,0,CR7
#
# AA,24,MSP,3858,MIA,3576,,0,738
#
# AA,24,MSP,3858,ORD,3830,,0,M83 M80
#
# AA,24,MSY,3861,DFW,3670,,0,M80 M83

# %%
line=a.readline()

# %%
line

# %%
# Out:
# ''
